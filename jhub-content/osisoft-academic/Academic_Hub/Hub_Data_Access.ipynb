# %% [markdown]
# # Academic Hub Data Access and Plotting Example
#
# This notebook is an introduction to the Academic Hub data access API.
#
# The source of data below is an always-running LabVIEW sample application sending OMF data to the Hub. The LabVIEW block diagram of this application is shown below:
#
# ![](https://apimgmtstelkv30lahnuj362.blob.core.windows.net/content/MediaLibrary/hub_images/hub_sample_signals_block_mod.png)

# %% [markdown]
# More specifically, this notebook shows how to:
#
# 1. Access Hub PIWebAPI pluggin and fill a panda dataframe with fresh 2 minutes of data from a LabVIEW sample application
# 2. Plot the data above with simple Plotly (https://plot.ly/)
# 3. Same a step 1 but for 10 minutes
# 4. Create a plot of data above with a range slider to move around
#
# ## Import and Hub Access credentials

# %%
# import 
import requests
import io
import pandas as pd

# Use your university credentials
username = 'reader0'
password = 'OSIsoft2017'

# %% [markdown]
# ## Set element path, start and end time for Hub data requests
#
# Data is always fresh coming from a long running LabVIEW application described above.

# %%
# --- Absolute start/end time ---
# elem_path = '\\\\PIAF-ACAD\\LabVIEW\\LabVIEW\\ocs_migration\\acs_sample_signals'
# start_time = '2018-08-01T11:54:37'
# end_time = '2018-08-09T13:54:37'

# --- Relative time, here last 2 minutes
elem_path = '\\\\PIAF-ACAD\\LabVIEW\\LabVIEW\\osi_unitops1\\hub_dan_signals'
start_time = '*-2m'
end_time = '*'
hub_endpoint = 'https://academicpi.azure-api.net/hub/api/'

# %% [markdown]
# ## Perform the data request and store directly into a panda dataframe
#
# This API endpoint returns a CSV formatted table of the recorded data for an element specified by its AF path. The internal PI Web API calls and formatting is performed by Academic Hub PIWebAPI plugin.
#
# Note: the 'Timestamp' column is converted to the right panda **datetime** data type. The dataframe content is displayed as a result of running the next cell.

# %%
reply = requests.get(hub_endpoint + 
                     'Csv/ElementRecorded?path=%s&startTime=%s&endTime=%s&maxCount=40000' % (elem_path, start_time, end_time), 
                     auth=(username,password))
df = pd.read_csv(io.StringIO(reply.text), parse_dates=['Timestamp'])
df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/tools/datetimes.py:314: UserWarning: Discarding nonzero nanoseconds in conversion
#   for ts in result]
#               Element        Attribute                        Timestamp  \
# 0     hub_dan_signals  Triangle Signal 2019-04-03 12:23:41.974395+00:00
# 1     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.074401+00:00
# 2     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.174407+00:00
# 3     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.275405+00:00
# 4     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.374420+00:00
# 5     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.474426+00:00
# 6     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.574432+00:00
# 7     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.674438+00:00
# 8     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.774444+00:00
# 9     hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.874450+00:00
# 10    hub_dan_signals  Triangle Signal 2019-04-03 12:23:42.974456+00:00
# 11    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.075454+00:00
# 12    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.173461+00:00
# 13    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.273468+00:00
# 14    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.373474+00:00
# 15    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.473480+00:00
# 16    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.573486+00:00
# 17    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.673492+00:00
# 18    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.773498+00:00
# 19    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.874496+00:00
# 20    hub_dan_signals  Triangle Signal 2019-04-03 12:23:43.973510+00:00
# 21    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.073516+00:00
# 22    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.173522+00:00
# 23    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.274520+00:00
# 24    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.373535+00:00
# 25    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.473541+00:00
# 26    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.573547+00:00
# 27    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.679550+00:00
# 28    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.777557+00:00
# 29    hub_dan_signals  Triangle Signal 2019-04-03 12:23:44.877563+00:00
# ...               ...              ...                              ...
# 3405  hub_dan_signals     Combo Signal 2019-04-03 12:25:33.517776+00:00
# 3406  hub_dan_signals     Combo Signal 2019-04-03 12:25:33.617782+00:00
# 3407  hub_dan_signals     Combo Signal 2019-04-03 12:25:33.717788+00:00
# 3408  hub_dan_signals     Combo Signal 2019-04-03 12:25:33.818786+00:00
# 3409  hub_dan_signals     Combo Signal 2019-04-03 12:25:33.917800+00:00
# 3410  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.017807+00:00
# 3411  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.117813+00:00
# 3412  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.217819+00:00
# 3413  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.317825+00:00
# 3414  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.417816+00:00
# 3415  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.517822+00:00
# 3416  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.617828+00:00
# 3417  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.718841+00:00
# 3418  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.817840+00:00
# 3419  hub_dan_signals     Combo Signal 2019-04-03 12:25:34.917846+00:00
# 3420  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.017852+00:00
# 3421  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.117858+00:00
# 3422  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.217864+00:00
# 3423  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.317871+00:00
# 3424  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.417877+00:00
# 3425  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.518890+00:00
# 3426  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.617889+00:00
# 3427  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.717895+00:00
# 3428  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.817901+00:00
# 3429  hub_dan_signals     Combo Signal 2019-04-03 12:25:35.917907+00:00
# 3430  hub_dan_signals     Combo Signal 2019-04-03 12:25:36.017913+00:00
# 3431  hub_dan_signals     Combo Signal 2019-04-03 12:25:36.117919+00:00
# 3432  hub_dan_signals     Combo Signal 2019-04-03 12:25:36.217926+00:00
# 3433  hub_dan_signals     Combo Signal 2019-04-03 12:25:36.317932+00:00
# 3434  hub_dan_signals     Combo Signal 2019-04-03 12:25:36.418945+00:00
#
#          Value
# 0     0.802000
# 1     0.602000
# 2     0.402000
# 3     0.202000
# 4     0.002000
# 5    -0.198000
# 6    -0.398000
# 7    -0.598000
# 8    -0.798000
# 9    -0.998000
# 10   -1.198000
# 11   -1.398000
# 12   -1.598000
# 13   -1.798000
# 14   -1.998000
# 15   -1.802000
# 16   -1.602000
# 17   -1.402000
# 18   -1.202000
# 19   -1.002000
# 20   -0.802000
# 21   -0.602000
# 22   -0.402000
# 23   -0.202000
# 24   -0.002000
# 25    0.198000
# 26    0.398000
# 27    0.598000
# 28    0.798000
# 29    0.998000
# ...        ...
# 3405  4.507342
# 3406  4.333709
# 3407  4.159967
# 3408  3.986117
# 3409  3.812157
# 3410  3.638086
# 3411  3.463903
# 3412  3.289607
# 3413  3.115197
# 3414  2.940672
# 3415  2.766031
# 3416  2.591273
# 3417  2.416397
# 3418  2.241402
# 3419  2.066287
# 3420  1.891051
# 3421  1.715693
# 3422  1.540212
# 3423  1.364607
# 3424  1.188878
# 3425  1.409022
# 3426  1.633040
# 3427  1.856930
# 3428  2.080692
# 3429  2.304324
# 3430  2.527825
# 3431  2.751195
# 3432  2.974432
# 3433  3.197537
# 3434  3.420507
#
# [3435 rows x 4 columns]

# %% [markdown]
# ## Plot of current dataframe with 2 minutes of data
#
# Data is sent at a frequency of 10Hz.To zoom in/out, pan, etc., click in the plot and explore the plotly menu bar on the right upper corner of the plot.

# %%
import plotly.graph_objs as go

data = []
for sensor, color in [('Triangle Signal', 'red'), ('Sine Signal', 'blue'), ('Combo Signal', 'green')]:
    dftemp = df[df.Attribute == sensor]
    trace = go.Scatter(x = dftemp['Timestamp'], y = dftemp['Value'], mode='markers', name=sensor, marker=dict(color=color))
    data.append(trace)
    
fig = go.FigureWidget(data=data)
fig
# Out:
# FigureWidget({
#     'data': [{'marker': {'color': 'red'},
#               'mode': 'markers',
#               'name'…

# %% [markdown]
# ## Get last 10 minutes of data

# %%
start_time = '*-10m'
end_time = '*'
hub_endpoint = 'https://academicpi.azure-api.net/hub/api/'
reply = requests.get(hub_endpoint + 
                     'Csv/ElementRecorded?path=%s&startTime=%s&endTime=%s&maxCount=40000' % (elem_path, start_time, end_time), 
                     auth=(username,password))
df = pd.read_csv(io.StringIO(reply.text), parse_dates=['Timestamp'])
df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/tools/datetimes.py:314: UserWarning:
#
# Discarding nonzero nanoseconds in conversion
#                Element        Attribute                        Timestamp  \
# 0      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.088256+00:00
# 1      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.188262+00:00
# 2      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.288269+00:00
# 3      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.388275+00:00
# 4      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.488281+00:00
# 5      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.588287+00:00
# 6      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.688293+00:00
# 7      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.789306+00:00
# 8      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.888305+00:00
# 9      hub_dan_signals  Triangle Signal 2019-04-03 12:16:05.988311+00:00
# 10     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.088317+00:00
# 11     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.188323+00:00
# 12     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.288330+00:00
# 13     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.388336+00:00
# 14     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.488342+00:00
# 15     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.588348+00:00
# 16     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.688354+00:00
# 17     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.788360+00:00
# 18     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.888366+00:00
# 19     hub_dan_signals  Triangle Signal 2019-04-03 12:16:06.988372+00:00
# 20     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.088378+00:00
# 21     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.188385+00:00
# 22     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.288391+00:00
# 23     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.388397+00:00
# 24     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.488403+00:00
# 25     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.588409+00:00
# 26     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.688415+00:00
# 27     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.788421+00:00
# 28     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.888427+00:00
# 29     hub_dan_signals  Triangle Signal 2019-04-03 12:16:07.988433+00:00
# ...                ...              ...                              ...
# 17832  hub_dan_signals     Combo Signal 2019-04-03 12:25:57.820159+00:00
# 17833  hub_dan_signals     Combo Signal 2019-04-03 12:25:57.920166+00:00
# 17834  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.020172+00:00
# 17835  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.120178+00:00
# 17836  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.220184+00:00
# 17837  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.320190+00:00
# 17838  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.420196+00:00
# 17839  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.521209+00:00
# 17840  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.620208+00:00
# 17841  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.720214+00:00
# 17842  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.820220+00:00
# 17843  hub_dan_signals     Combo Signal 2019-04-03 12:25:58.920227+00:00
# 17844  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.020233+00:00
# 17845  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.120239+00:00
# 17846  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.220245+00:00
# 17847  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.321243+00:00
# 17848  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.420257+00:00
# 17849  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.520263+00:00
# 17850  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.620269+00:00
# 17851  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.720275+00:00
# 17852  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.821273+00:00
# 17853  hub_dan_signals     Combo Signal 2019-04-03 12:25:59.920288+00:00
# 17854  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.021286+00:00
# 17855  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.121292+00:00
# 17856  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.221298+00:00
# 17857  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.320312+00:00
# 17858  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.420303+00:00
# 17859  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.520324+00:00
# 17860  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.620330+00:00
# 17861  hub_dan_signals     Combo Signal 2019-04-03 12:26:00.720321+00:00
#
#           Value
# 0      1.998000
# 1      1.802000
# 2      1.602000
# 3      1.402000
# 4      1.202000
# 5      1.002000
# 6      0.802000
# 7      0.602000
# 8      0.402000
# 9      0.202000
# 10     0.002000
# 11    -0.198000
# 12    -0.398000
# 13    -0.598000
# 14    -0.798000
# 15    -0.998000
# 16    -1.198000
# 17    -1.398000
# 18    -1.598000
# 19    -1.798000
# 20    -1.998000
# 21    -1.802000
# 22    -1.602000
# 23    -1.402000
# 24    -1.202000
# 25    -1.002000
# 26    -0.802000
# 27    -0.602000
# 28    -0.402000
# 29    -0.202000
# ...         ...
# 17832  5.521775
# 17833  5.305870
# 17834  5.089795
# 17835  4.873550
# 17836  4.657137
# 17837  4.440556
# 17838  4.223808
# 17839  4.006893
# 17840  3.789812
# 17841  3.572565
# 17842  3.355154
# 17843  3.137579
# 17844  2.919841
# 17845  2.701940
# 17846  2.483878
# 17847  2.265654
# 17848  2.047270
# 17849  2.224726
# 17850  2.406023
# 17851  2.587162
# 17852  2.768143
# 17853  2.948968
# 17854  3.129636
# 17855  3.310150
# 17856  3.490509
# 17857  3.670714
# 17858  3.850766
# 17859  4.030667
# 17860  4.210416
# 17861  4.390014
#
# [17862 rows x 4 columns]

# %% [markdown]
# ## Second plot with 10 minutes of data + range slider
#
# Note that this plot stays very fluid when zooming/panning with nearly 18,000 rows of data.

# %%
data = []
for sensor, color in [('Triangle Signal', 'red'), ('Sine Signal', 'blue'), ('Combo Signal', 'green')]:
    dftemp = df[df.Attribute == sensor]
    trace = go.Scattergl(x = dftemp['Timestamp'], y = dftemp['Value'], mode='markers', name=sensor, marker=dict(color=color))
    data.append(trace)

layout = dict(
    title='Time Series with Rangeslider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='minute',
                     stepmode='backward'),
                dict(count=2,
                     label='2m',
                     step='minute',
                     stepmode='backward'),
                dict(count=5,
                     label='5s',
                     step='second'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)
fig = go.FigureWidget(data=data, layout=layout)
fig
# Out:
# FigureWidget({
#     'data': [{'marker': {'color': 'red'},
#               'mode': 'markers',
#               'name'…

# %% [markdown]
# # Check PI Vision display of real-time data
#
# **NOTE: You need an Academic Hub to see the PI Vision display below. Contact hubsupport@osisoft.com if needed.**
#
# https://academicpi.osisoft.com/PIVision/#/Displays/100/Hub_Sample_Signals?asset=%5C%5CPIAF-ACAD%5CLabVIEW%5CLabVIEW%5Cosi_unitops1%5Chub_dan_signals
#
# Here is a recent screenshot:
#
# ![](../images/hub-signals-pivision.png)

# %% [markdown]
# ## Some panda dataframe operation
#
# ### List of unique values from the Attribute column, here the sensor names of the LabVIEW application

# %%
df.Attribute.unique()
# Out:
# array(['Triangle Signal', 'Sine Signal', 'Combo Signal'], dtype=object)

# %% [markdown]
# ### Name of colums (always the same for calls to ElementRecorded endpoint)

# %%
df.columns
# Out:
# Index(['Element', 'Attribute', 'Timestamp', 'Value'], dtype='object')

# %% [markdown]
# ### Data type of each columns
#
# Note datetime64 for Timestamp (3rd) column

# %%
for c in df.columns:
    print(c, ':', df[c].dtype)
# Out:
# Element : object
# Attribute : object
# Timestamp : datetime64[ns]
# Value : float64
