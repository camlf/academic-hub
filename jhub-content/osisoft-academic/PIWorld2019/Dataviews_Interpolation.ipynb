# %% [markdown]
# # PI World 2019: *** OCS Interpolation Investigation ***
#
# ## Instruction: execute cells until reaching the Dataviews / PI Web API plugin comparison (starting at cell [14])
#
# ![PIWorld 2019](./images/piworld-2019.png)

# %% [markdown]
# ![Hub Overview](./images/hub-overview.png)

# %% [markdown]
# # Learning module developed in partnership with Deschutes Brewery and Lehigh University
#
# ![Partnership with Deschutes and Lehigh University](./images/lehigh-deschute-partnership.png)

# %% [markdown]
# ![CHE_396](./images/lehigh-che-396.png)

# %% [markdown]
# ![Learning Outcomes](./images/learning-outcomes.png)

# %% [markdown]
# ![Problem Setting](./images/adf-problem-settings.png)

# %% [markdown]
# ![Segmented](./images/lehigh-fitted-model-slide.png)

# %% [markdown]
# ## Imports
#
# Standard python modules import plus OCS specific module

# %%
# For interaction with OCS
from ocs_datascience import OCSClient
# For HTTP request
import requests
# Pandas dataframe to manipulate table data
import pandas as pd
# Utilities from Python standard library 
import configparser
import datetime as dt
from dateutil import parser 
import json
import io
# For plots 
import plotly.graph_objs as go
import plotly_express as px

# %% [markdown]
# # Learning Outcome: Data access from cloud server using web service calls

# %% [markdown]
# ![Tenant, namespace concepts](https://apimgmtstelkv30lahnuj362.blob.core.windows.net/content/MediaLibrary/lehigh/ocs/tenant-namespace2.png)

# %% [markdown]
# ## Content of file `config.ini`

# %% [raw]
#     ; IMPORTANT: replace these values with those provided by OSIsoft
#     [Configurations]
#     Namespace = fermenter_vessels
#
#     [Access]
#     Resource = https://dat-b.osisoft.com
#     Tenant = 65292b6c-ec16-414a-b583-ce7ae04046d4
#     ApiVersion = v1-preview
#
#     [Credentials]
#     ClientId = 1415f83d-5940-4fb7-a2c7-ea158558a6bc
#     ClientSecret = USISiAvuBJ1dMp/KvFPTGyUXyuvAQFPfN1j2Lr6TMBk=

# %% [markdown]
# ## Read in configuration file and create OCS client object

# %%
config = configparser.ConfigParser()
config.read('config.ini')

ocs_client = OCSClient(config.get('Access', 'ApiVersion'),config.get('Access', 'Tenant'), config.get('Access', 'Resource'), 
                     config.get('Credentials', 'ClientId'), config.get('Credentials', 'ClientSecret'))

namespace_id = config.get('Configurations', 'Namespace')

# %% [markdown]
# ## Get an the autorization header with bearer token for access to OCS API

# %%
headers = ocs_client.authorization_headers()
headers
# Out:
# {'Authorization': 'bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjJDQjI4MzFEREJFRDc1NzAyM0NCMTM5OUVBRjRDMjkxQzE3MkQ5RjQiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJMTEtESGR2dGRYQWp5eE9aNnZUQ2tjRnkyZlEifQ..GCIs9ARiEQFt12eGhvilec3Gl9Lw23EQsy1HI7OkgHTUPt1_YCBPK9UYKiZd-wb2qnOlo0dNv-RBKYC_KnfDTC4qkt-EAG6LH6MzLvbiQlSlIcKeOmnNjsFr-rt5FzDmHrlYHuJ7sg3O-7VPNQaAI8emLrjqA1UyUTkmGtu0YrD1GhrNa9JnRg7NycW-ftgUr6JM4Txd4QN-HPLiw25FEDE9s2nFfcAnezuTbdz_H0BHxua8u5XNP-KlPtqBQwCcoPpi1A_HR586taHclBDWP0gUzs93yGB9Ug4f4U7fPCzHhnNwEkIZ4vHWUv3ofPr763rwZ1sbfe0pHcloruSgJQ',
#  'Content-type': 'application/json',
#  'Accept': 'text/plain',
#  'Request-Timeout': '60000'}

# %% [markdown]
# ### URL to access `fermenter_vessels` namespace and its dataviews

# %%
# Endpoint for dataview access
namespace_url = ocs_client.namespace_url(namespace_id)  
dataview_url = namespace_url + '/dataviews/'
namespace_url
# Out:
# 'https://dat-b.osisoft.com/api/v1-preview/Tenants/65292b6c-ec16-414a-b583-ce7ae04046d4/Namespaces/fermenter__vessels'

# %% [markdown]
# ## Get the list of all data streams for Fermenter Vessel #31 and extract information for Bottom Temperature data stream

# %% [markdown]
# #### 1) Build a stream query URL

# %%
streams_url = namespace_url + '/Streams?query=name:*FV31*'
print('Stream Query URL:', streams_url)
# Out:
# Stream Query URL: https://dat-b.osisoft.com/api/v1-preview/Tenants/65292b6c-ec16-414a-b583-ce7ae04046d4/Namespaces/fermenter__vessels/Streams?query=name:*FV31*

# %% [markdown]
# #### 2) Make a web request using URL and authorization header

# %%
fv31_streams = requests.get(streams_url, headers=headers)

# %% [markdown]
# #### 3) Verify that request status code indicates success (should be 200 for GET)

# %%
fv31_streams.status_code
# Out:
# 200

# %% [markdown]
# #### 4) Display information about Bottom Temperature Control Value data stream

# %%
print([stream for stream in fv31_streams.json() if 'Bottom Temperature Control Value' in stream['Description']])
# Out:
# [{'TypeId': 'PI-Float32', 'Id': 'PI_acad-pida-vm0_2593', 'Name': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV', 'Description': 'FV31 Bottom Temperature Control Value', 'InterpolationMode': 0, 'ExtrapolationMode': 2}]

# %% [markdown]
# # Learning Outcome: Build a URL query to get back data from a data stream

# %% [markdown]
# ### Get data for Bottom Temperature Sensor of Fermentor Vessel 31

# %%
start_index = 'startIndex=2017-03-17T00:00'
end_index =     'endIndex=2017-03-17T02:00' # 2 hours later
fv31_bottom_temp_url = namespace_url + f'/Streams/PI_acad-pida-vm0_2593/Data?{start_index}&{end_index}'
fv31_bottom_temp_url
# Out:
# 'https://dat-b.osisoft.com/api/v1-preview/Tenants/65292b6c-ec16-414a-b583-ce7ae04046d4/Namespaces/fermenter__vessels/Streams/PI_acad-pida-vm0_2593/Data?startIndex=2017-03-17T00:00&endIndex=2017-03-17T02:00'

# %% [markdown]
# #### Perform web service for stream data and check status

# %%
fv31_bottom_temp = requests.get(fv31_bottom_temp_url, headers=headers)
fv31_bottom_temp.status_code
# Out:
# 200

# %% [markdown]
# #### 7) Check raw data in JSON format

# %%
fv31_bottom_temp.json()
# Out:
# [{'Timestamp': '2017-03-17T00:14:07Z', 'Value': 30.5642},
#  {'Timestamp': '2017-03-17T00:22:36Z', 'Value': 30.2},
#  {'Timestamp': '2017-03-17T00:53:25Z', 'Value': 30.2},
#  {'Timestamp': '2017-03-17T00:57:55Z', 'Value': 30.06531},
#  {'Timestamp': '2017-03-17T00:58:48Z', 'Value': 29.7681},
#  {'Timestamp': '2017-03-17T00:59:00Z', 'Value': 29.73208},
#  {'Timestamp': '2017-03-17T01:00:00Z', 'Value': 29.67508},
#  {'Timestamp': '2017-03-17T01:01:01Z', 'Value': 29.54451},
#  {'Timestamp': '2017-03-17T01:02:00Z', 'Value': 29.55049},
#  {'Timestamp': '2017-03-17T01:03:00Z', 'Value': 29.65275},
#  {'Timestamp': '2017-03-17T01:04:00Z', 'Value': 29.755},
#  {'Timestamp': '2017-03-17T01:05:00Z', 'Value': 29.72754},
#  {'Timestamp': '2017-03-17T01:06:01Z', 'Value': 29.83604},
#  {'Timestamp': '2017-03-17T01:07:00Z', 'Value': 29.93986},
#  {'Timestamp': '2017-03-17T01:08:00Z', 'Value': 30.04601},
#  {'Timestamp': '2017-03-17T01:09:00Z', 'Value': 30.09564},
#  {'Timestamp': '2017-03-17T01:10:00Z', 'Value': 30.06812},
#  {'Timestamp': '2017-03-17T01:11:01Z', 'Value': 30.03995},
#  {'Timestamp': '2017-03-17T01:12:00Z', 'Value': 30.01307},
#  {'Timestamp': '2017-03-17T01:13:00Z', 'Value': 30.01005},
#  {'Timestamp': '2017-03-17T01:14:00Z', 'Value': 30.03569},
#  {'Timestamp': '2017-03-17T01:15:00Z', 'Value': 30.06132},
#  {'Timestamp': '2017-03-17T01:16:01Z', 'Value': 30.08748},
#  {'Timestamp': '2017-03-17T01:17:00Z', 'Value': 30.03358},
#  {'Timestamp': '2017-03-17T01:18:00Z', 'Value': 30.14889},
#  {'Timestamp': '2017-03-17T01:19:00Z', 'Value': 30.2},
#  {'Timestamp': '2017-03-17T01:20:00Z', 'Value': 30.2},
#  {'Timestamp': '2017-03-17T01:21:01Z', 'Value': 30.31062},
#  {'Timestamp': '2017-03-17T01:22:00Z', 'Value': 30.37359},
#  {'Timestamp': '2017-03-17T01:23:02Z', 'Value': 30.36814},
#  {'Timestamp': '2017-03-17T01:27:53Z', 'Value': 30.30647},
#  {'Timestamp': '2017-03-17T01:28:28Z', 'Value': 30.3744},
#  {'Timestamp': '2017-03-17T01:34:13Z', 'Value': 30.40107},
#  {'Timestamp': '2017-03-17T01:34:59Z', 'Value': 30.48236},
#  {'Timestamp': '2017-03-17T01:41:04Z', 'Value': 30.45669},
#  {'Timestamp': '2017-03-17T01:46:16Z', 'Value': 30.39139},
#  {'Timestamp': '2017-03-17T01:51:06Z', 'Value': 30.27349},
#  {'Timestamp': '2017-03-17T01:54:48Z', 'Value': 30.19674},
#  {'Timestamp': '2017-03-17T01:55:12Z', 'Value': 30.19313},
#  {'Timestamp': '2017-03-17T01:56:38Z', 'Value': 30.18885},
#  {'Timestamp': '2017-03-17T01:57:04Z', 'Value': 30.18661},
#  {'Timestamp': '2017-03-17T01:58:00Z', 'Value': 30.18306}]

# %% [markdown]
# #### 8) Store result as a Panda dataframe for further manipulations

# %%
df = pd.DataFrame(fv31_bottom_temp.json())
df
# Out:
#                Timestamp     Value
# 0   2017-03-17T00:14:07Z  30.56420
# 1   2017-03-17T00:22:36Z  30.20000
# 2   2017-03-17T00:53:25Z  30.20000
# 3   2017-03-17T00:57:55Z  30.06531
# 4   2017-03-17T00:58:48Z  29.76810
# 5   2017-03-17T00:59:00Z  29.73208
# 6   2017-03-17T01:00:00Z  29.67508
# 7   2017-03-17T01:01:01Z  29.54451
# 8   2017-03-17T01:02:00Z  29.55049
# 9   2017-03-17T01:03:00Z  29.65275
# 10  2017-03-17T01:04:00Z  29.75500
# 11  2017-03-17T01:05:00Z  29.72754
# 12  2017-03-17T01:06:01Z  29.83604
# 13  2017-03-17T01:07:00Z  29.93986
# 14  2017-03-17T01:08:00Z  30.04601
# 15  2017-03-17T01:09:00Z  30.09564
# 16  2017-03-17T01:10:00Z  30.06812
# 17  2017-03-17T01:11:01Z  30.03995
# 18  2017-03-17T01:12:00Z  30.01307
# 19  2017-03-17T01:13:00Z  30.01005
# 20  2017-03-17T01:14:00Z  30.03569
# 21  2017-03-17T01:15:00Z  30.06132
# 22  2017-03-17T01:16:01Z  30.08748
# 23  2017-03-17T01:17:00Z  30.03358
# 24  2017-03-17T01:18:00Z  30.14889
# 25  2017-03-17T01:19:00Z  30.20000
# 26  2017-03-17T01:20:00Z  30.20000
# 27  2017-03-17T01:21:01Z  30.31062
# 28  2017-03-17T01:22:00Z  30.37359
# 29  2017-03-17T01:23:02Z  30.36814
# 30  2017-03-17T01:27:53Z  30.30647
# 31  2017-03-17T01:28:28Z  30.37440
# 32  2017-03-17T01:34:13Z  30.40107
# 33  2017-03-17T01:34:59Z  30.48236
# 34  2017-03-17T01:41:04Z  30.45669
# 35  2017-03-17T01:46:16Z  30.39139
# 36  2017-03-17T01:51:06Z  30.27349
# 37  2017-03-17T01:54:48Z  30.19674
# 38  2017-03-17T01:55:12Z  30.19313
# 39  2017-03-17T01:56:38Z  30.18885
# 40  2017-03-17T01:57:04Z  30.18661
# 41  2017-03-17T01:58:00Z  30.18306

# %% [markdown]
# #### 9) Plot the time-series data

# %%
layout = dict(title='Bottom Temperature')
data = [go.Scattergl(x = df['Timestamp'], y = df['Value'], mode='lines+markers')]
fig = go.FigureWidget(data=data, layout=layout)
fig
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'type': 'scattergl',
#               'uid': …

# %% [raw]
# fig = px.line(df, x='Timestamp', y='Value', labels=dict(Timestamp='Time', Value='Bottom Temperature (F)'))
# fig.data[0].update(mode='lines+markers')
# fig

# %% [markdown]
# ## Often analysis requires a single table with data from:
#
# ### 1- Values for multiple sensors, settings, and calculations organized as rows of observations
#
# ### 2- Multiple similar assets: consistent data shape
#
# ### 3- Data at regular intervals
#
# ## OSIsoft answer for the above is the Dataview
#
# ## Academic Hub provides a set of ready-to-use dataviews for students with each dataset hosted on the Academic Hub

# %% [markdown]
# ---
# ---
# # Comparison between PI Web API and OCS interpolations
# ---
# ---

# %% [markdown]
# ## Creation of the Dataviews, for fermenters 31 up to 36
#
# * Status 201 from POST request indicates success
# * Status 401 indicates unauthorized (try refreshing authorization header)
# * Status 409 when a Dataview with same Id already exists (go to last cell of this notebook to perform a clean up)
# * One Dataview per fermenter vessel

# %%
# Valid Fermenter Vessel IDs are 31 up to 36
for fv_id in range(31, 32):
    dataviews_id = ocs_client.create_fermenter_dataview(fv_id)
# Out:
# Status: 409 Dataview Id: DV_FV31 Error: {"OperationId":"c3d7da66-d61c-4518-bec2-22c5cb3081c1","Error":"Data view with specified id already exists.","DataViewId":"DV_FV31"}

# %% [markdown]
# ### Prepare OCS dataview request for Fermenter Vessel 31. We're interested in the Volume column

# %%
# Start of data in OCS
start_index = '2017-03-17T07:00'
# Convert to a datetime
start_time = parser.parse(start_index)
# Build a time delta 
delta_time = dt.timedelta(days=1)
# Get back a ISO8601 timestamp string which is delta_time later than start_index 
end_index = (start_time + delta_time).isoformat()
interval = '00:01:00'
dataview_id = 'DV_FV31'
dataview_url = namespace_url + f'/Dataviews/{dataview_id}/preview/interpolated' + \
            f'?startIndex={start_index}&endIndex={end_index}' + \
            f'&interval={interval}&form=csvh&maxcount=20000' 
dataview_url
# Out:
# 'https://dat-b.osisoft.com/api/v1-preview/Tenants/65292b6c-ec16-414a-b583-ce7ae04046d4/Namespaces/fermenter__vessels/Dataviews/DV_FV31/preview/interpolated?startIndex=2017-03-17T07:00&endIndex=2017-03-18T07:00:00&interval=00:01:00&form=csvh&maxcount=20000'

# %%
# Perform dataview request
fv31_dataview_result = requests.get(dataview_url, headers=headers)
print(fv31_dataview_result.status_code)
df_ocs = pd.read_csv(io.StringIO(fv31_dataview_result.text), parse_dates=['Timestamp'])
df_ocs
# Out:
# 200
#                      Timestamp   Volume  Top TIC PV  Top TIC OUT  Plato  \
# 0    2017-03-17 07:00:00+00:00  716.566   29.613152          0.0    NaN
# 1    2017-03-17 07:01:00+00:00  716.566   29.552847          0.0    NaN
# 2    2017-03-17 07:02:00+00:00  716.566   29.497858          0.0    NaN
# 3    2017-03-17 07:03:00+00:00  716.566   29.456203          0.0    NaN
# 4    2017-03-17 07:04:00+00:00  716.566   29.438652          0.0    NaN
# 5    2017-03-17 07:05:00+00:00  716.566   29.421194          0.0    NaN
# 6    2017-03-17 07:06:00+00:00  716.566   29.430151          0.0    NaN
# 7    2017-03-17 07:07:00+00:00  716.566   29.476150          0.0    NaN
# 8    2017-03-17 07:08:00+00:00  716.566   29.468636          0.0    NaN
# 9    2017-03-17 07:09:00+00:00  716.566   29.464607          0.0    NaN
# 10   2017-03-17 07:10:00+00:00  716.566   29.428816          0.0    NaN
# 11   2017-03-17 07:11:00+00:00  716.566   29.423681          0.0    NaN
# 12   2017-03-17 07:12:00+00:00  716.566   29.438360          0.0    NaN
# 13   2017-03-17 07:13:00+00:00  716.566   29.492730          0.0    NaN
# 14   2017-03-17 07:14:00+00:00  716.566   29.484865          0.0    NaN
# 15   2017-03-17 07:15:00+00:00  716.566   29.451567          0.0    NaN
# 16   2017-03-17 07:16:00+00:00  716.566   29.422504          0.0    NaN
# 17   2017-03-17 07:17:00+00:00  716.566   29.468386          0.0    NaN
# 18   2017-03-17 07:18:00+00:00  716.566   29.462850          0.0    NaN
# 19   2017-03-17 07:19:00+00:00  716.566   29.456930          0.0    NaN
# 20   2017-03-17 07:20:00+00:00  716.566   29.497790          0.0    NaN
# 21   2017-03-17 07:21:00+00:00  716.566   29.489620          0.0    NaN
# 22   2017-03-17 07:22:00+00:00  716.566   29.431010          0.0    NaN
# 23   2017-03-17 07:23:00+00:00  716.566   29.412770          0.0    NaN
# 24   2017-03-17 07:24:00+00:00  716.566   29.434036          0.0    NaN
# 25   2017-03-17 07:25:00+00:00  716.566   29.462510          0.0    NaN
# 26   2017-03-17 07:26:00+00:00  716.566   29.476015          0.0    NaN
# 27   2017-03-17 07:27:00+00:00      NaN   29.411950          NaN    NaN
# 28   2017-03-17 07:28:00+00:00      NaN   29.416990          NaN    NaN
# 29   2017-03-17 07:29:00+00:00      NaN   29.407148          NaN    NaN
# ...                        ...      ...         ...          ...    ...
# 1411 2017-03-18 06:31:00+00:00  716.566   29.900000          0.0    5.0
# 1412 2017-03-18 06:32:00+00:00  716.566   29.900000          0.0    5.0
# 1413 2017-03-18 06:33:00+00:00  716.566   29.900000          0.0    5.0
# 1414 2017-03-18 06:34:00+00:00  716.566   29.900000          0.0    5.0
# 1415 2017-03-18 06:35:00+00:00  716.566   29.900000          0.0    5.0
# 1416 2017-03-18 06:36:00+00:00  716.566   29.900000          0.0    5.0
# 1417 2017-03-18 06:37:00+00:00  716.566   29.900000          0.0    5.0
# 1418 2017-03-18 06:38:00+00:00  716.566   29.900000          0.0    5.0
# 1419 2017-03-18 06:39:00+00:00  716.566   29.900000          0.0    5.0
# 1420 2017-03-18 06:40:00+00:00  716.566   29.900000          0.0    5.0
# 1421 2017-03-18 06:41:00+00:00  716.566   29.900000          0.0    5.0
# 1422 2017-03-18 06:42:00+00:00  716.566   29.900000          0.0    5.0
# 1423 2017-03-18 06:43:00+00:00  716.566   29.900000          0.0    5.0
# 1424 2017-03-18 06:44:00+00:00  716.566   29.900000          0.0    5.0
# 1425 2017-03-18 06:45:00+00:00  716.566   29.900000          0.0    5.0
# 1426 2017-03-18 06:46:00+00:00  716.566   29.900000          0.0    5.0
# 1427 2017-03-18 06:47:00+00:00  716.566   29.900000          0.0    5.0
# 1428 2017-03-18 06:48:00+00:00  716.566   29.900000          0.0    5.0
# 1429 2017-03-18 06:49:00+00:00  716.566   29.900000          0.0    5.0
# 1430 2017-03-18 06:50:00+00:00  716.566   29.900000          0.0    5.0
# 1431 2017-03-18 06:51:00+00:00  716.566   29.900000          0.0    5.0
# 1432 2017-03-18 06:52:00+00:00  716.566   29.900000          0.0    5.0
# 1433 2017-03-18 06:53:00+00:00  716.566   29.900000          0.0    5.0
# 1434 2017-03-18 06:54:00+00:00  716.566   29.900000          0.0    5.0
# 1435 2017-03-18 06:55:00+00:00  716.566   29.900000          0.0    5.0
# 1436 2017-03-18 06:56:00+00:00  716.566   29.900000          0.0    5.0
# 1437 2017-03-18 06:57:00+00:00  716.566   29.900000          0.0    5.0
# 1438 2017-03-18 06:58:00+00:00  716.566   29.900000          0.0    5.0
# 1439 2017-03-18 06:59:00+00:00  716.566   29.900000          0.0    5.0
# 1440 2017-03-18 07:00:00+00:00  716.566   29.900000          0.0    5.0
#
#       Middle TIC PV  Middle TIC OUT  FV Full Plato           Fermentation ID  \
# 0         29.356380        0.000000            NaN  Fermentor 31201731179653
# 1         29.378868        0.000000            NaN  Fermentor 31201731179653
# 2         29.400892        0.000000            NaN  Fermentor 31201731179653
# 3         29.423298        0.000000            NaN  Fermentor 31201731179653
# 4         29.440790        0.000000            NaN  Fermentor 31201731179653
# 5         29.458190        0.000000            NaN  Fermentor 31201731179653
# 6         29.489014        0.000000            NaN  Fermentor 31201731179653
# 7         29.432340        0.000000            NaN  Fermentor 31201731179653
# 8         29.416090        0.000000            NaN  Fermentor 31201731179653
# 9         29.429405        0.000000            NaN  Fermentor 31201731179653
# 10        29.433302        0.000000            NaN  Fermentor 31201731179653
# 11        29.437784        0.000000            NaN  Fermentor 31201731179653
# 12        29.459850        0.000000            NaN  Fermentor 31201731179653
# 13        29.496010        0.000000            NaN  Fermentor 31201731179653
# 14        29.494457        0.000000            NaN  Fermentor 31201731179653
# 15        29.487812        0.000000            NaN  Fermentor 31201731179653
# 16        29.474813        0.000000            NaN  Fermentor 31201731179653
# 17        29.462631        0.000000            NaN  Fermentor 31201731179653
# 18        29.449730        0.000000            NaN  Fermentor 31201731179653
# 19        29.439764        0.000000            NaN  Fermentor 31201731179653
# 20        29.424730        0.000000            NaN  Fermentor 31201731179653
# 21        29.416422        0.000000            NaN  Fermentor 31201731179653
# 22        29.400710        0.000000            NaN  Fermentor 31201731179653
# 23        29.434050        0.000000            NaN  Fermentor 31201731179653
# 24        29.467443        0.000000            NaN  Fermentor 31201731179653
# 25        29.500720        0.000000            NaN  Fermentor 31201731179653
# 26        29.523935        0.000000            NaN  Fermentor 31201731179653
# 27        29.567390        0.000000            NaN  Fermentor 31201731179653
# 28        29.533970        0.000000            NaN  Fermentor 31201731179653
# 29        29.560633        0.000000            NaN  Fermentor 31201731179653
# ...             ...             ...            ...                       ...
# 1411      29.925835        0.000000       14.69401  Fermentor 31201731179653
# 1412      29.909073        0.000000       14.69401  Fermentor 31201731179653
# 1413      29.905619        0.000000       14.69401  Fermentor 31201731179653
# 1414      29.914247        0.000000       14.69401  Fermentor 31201731179653
# 1415      29.926382        0.000000       14.69401  Fermentor 31201731179653
# 1416      29.937992        0.000000       14.69401  Fermentor 31201731179653
# 1417      29.949880        0.000000       14.69401  Fermentor 31201731179653
# 1418      29.959858        0.000000       14.69401  Fermentor 31201731179653
# 1419      29.972992        0.000000       14.69401  Fermentor 31201731179653
# 1420      29.981985        0.000000       14.69401  Fermentor 31201731179653
# 1421      29.994856        0.000000       14.69401  Fermentor 31201731179653
# 1422      30.008036        0.641224       14.69401  Fermentor 31201731179653
# 1423      30.019087        1.807086       14.69401  Fermentor 31201731179653
# 1424      30.028880        2.972947       14.69401  Fermentor 31201731179653
# 1425      30.040619        4.138809       14.69401  Fermentor 31201731179653
# 1426      30.053942        5.304671       14.69401  Fermentor 31201731179653
# 1427      30.065622        7.094911       14.69401  Fermentor 31201731179653
# 1428      30.075064        9.010027       14.69401  Fermentor 31201731179653
# 1429      30.088009       10.925142       14.69401  Fermentor 31201731179653
# 1430      30.062792       12.840259       14.69401  Fermentor 31201731179653
# 1431      30.085730       14.755374       14.69401  Fermentor 31201731179653
# 1432      30.071127       12.502110       14.69401  Fermentor 31201731179653
# 1433      30.010070        9.415169       14.69401  Fermentor 31201731179653
# 1434      30.068003        6.328228       14.69401  Fermentor 31201731179653
# 1435      30.036314        3.241288       14.69401  Fermentor 31201731179653
# 1436      30.003580        0.154347       14.69401  Fermentor 31201731179653
# 1437      30.021994        2.258153       14.69401  Fermentor 31201731179653
# 1438      30.078285        4.635156       14.69401  Fermentor 31201731179653
# 1439      30.085482        7.012158       14.69401  Fermentor 31201731179653
# 1440      30.018522        9.389161       14.69401  Fermentor 31201731179653
#
#       Brand  Bottom TIC PV  Bottom TIC OUT       ADF  Status
# 0       4.0      29.884571       10.935327       NaN    12.0
# 1       4.0      29.931492       12.445787       NaN    12.0
# 2       4.0      29.978569       13.956246       NaN    12.0
# 3       4.0      30.033358       18.254084       NaN    12.0
# 4       4.0      30.083404       25.958717       NaN    12.0
# 5       4.0      30.133188       33.663350       NaN    12.0
# 6       4.0      30.193794       41.367980       NaN    12.0
# 7       4.0      30.191100       45.145805       NaN    12.0
# 8       4.0      30.184795       48.042100       NaN    12.0
# 9       4.0      30.179586       50.938390       NaN    12.0
# 10      4.0      30.172728       53.834682       NaN    12.0
# 11      4.0      30.165604       56.730976       NaN    12.0
# 12      4.0      30.159050       55.699925       NaN    12.0
# 13      4.0      30.152640       50.994907       NaN    12.0
# 14      4.0      30.147348       46.289887       NaN    12.0
# 15      4.0      30.140123       41.584870       NaN    12.0
# 16      4.0      30.133460       36.879850       NaN    12.0
# 17      4.0      30.127207       34.620860       NaN    12.0
# 18      4.0      30.120590       33.328910       NaN    12.0
# 19      4.0      30.115482       32.036960       NaN    12.0
# 20      4.0      30.107770       30.745012       NaN    12.0
# 21      4.0      30.092520       29.453062       NaN    12.0
# 22      4.0      29.900700       26.857450       NaN    12.0
# 23      4.0      29.933490       23.746439       NaN    12.0
# 24      4.0      29.966340       20.635426       NaN    12.0
# 25      4.0      29.999070       17.524414       NaN    12.0
# 26      4.0      30.021904       14.413403       NaN    12.0
# 27      4.0      30.064660       15.011147       NaN    12.0
# 28      4.0      30.097450       16.536083       NaN    12.0
# 29      4.0      30.084545       18.061018       NaN    12.0
# ...     ...            ...             ...       ...     ...
# 1411    4.0      30.031033       10.429822  0.659725    12.0
# 1412    4.0      30.057007        9.732054  0.659725    12.0
# 1413    4.0      30.056053        9.117924  0.659725    12.0
# 1414    4.0      30.030037        8.503794  0.659725    12.0
# 1415    4.0      30.067833        7.889663  0.659725    12.0
# 1416    4.0      30.054367        7.275533  0.659725    12.0
# 1417    4.0      30.081222        8.727330  0.659725    12.0
# 1418    4.0      30.070135       10.642908  0.659725    12.0
# 1419    4.0      30.072443       12.558485  0.659725    12.0
# 1420    4.0      30.042864       14.474063  0.659725    12.0
# 1421    4.0      30.022707       16.389640  0.659725    12.0
# 1422    4.0      30.027874       16.735737  0.659725    12.0
# 1423    4.0      30.018633       15.797715  0.659725    12.0
# 1424    4.0      30.052801       14.859692  0.659725    12.0
# 1425    4.0      30.028696       13.921669  0.659725    12.0
# 1426    4.0      30.069847       12.983646  0.659725    12.0
# 1427    4.0      30.004540       13.164211  0.659725    12.0
# 1428    4.0      30.069174       13.568493  0.659725    12.0
# 1429    4.0      30.079031       13.972776  0.659725    12.0
# 1430    4.0      30.018692       14.377057  0.659725    12.0
# 1431    4.0      30.067864       14.781340  0.659725    12.0
# 1432    4.0      30.028740       15.542957  0.659725    12.0
# 1433    4.0      30.085390       16.376041  0.659725    12.0
# 1434    4.0      30.027657       17.209125  0.659725    12.0
# 1435    4.0      30.053333       18.042212  0.659725    12.0
# 1436    4.0      30.088318       18.875296  0.659725    12.0
# 1437    4.0      30.050882       18.119314  0.659725    12.0
# 1438    4.0      30.014872       17.279697  0.659725    12.0
# 1439    4.0      30.084675       16.440080  0.659725    12.0
# 1440    4.0      30.012844       15.600465  0.659725    12.0
#
# [1441 rows x 14 columns]

# %%
df_ocs[['Timestamp', 'Volume']].to_csv('ocs_beer_fv31_03_17_1day.csv')
df_ocs[['Timestamp', 'Volume']]
# Out:
#                      Timestamp   Volume
# 0    2017-03-17 07:00:00+00:00  716.566
# 1    2017-03-17 07:01:00+00:00  716.566
# 2    2017-03-17 07:02:00+00:00  716.566
# 3    2017-03-17 07:03:00+00:00  716.566
# 4    2017-03-17 07:04:00+00:00  716.566
# 5    2017-03-17 07:05:00+00:00  716.566
# 6    2017-03-17 07:06:00+00:00  716.566
# 7    2017-03-17 07:07:00+00:00  716.566
# 8    2017-03-17 07:08:00+00:00  716.566
# 9    2017-03-17 07:09:00+00:00  716.566
# 10   2017-03-17 07:10:00+00:00  716.566
# 11   2017-03-17 07:11:00+00:00  716.566
# 12   2017-03-17 07:12:00+00:00  716.566
# 13   2017-03-17 07:13:00+00:00  716.566
# 14   2017-03-17 07:14:00+00:00  716.566
# 15   2017-03-17 07:15:00+00:00  716.566
# 16   2017-03-17 07:16:00+00:00  716.566
# 17   2017-03-17 07:17:00+00:00  716.566
# 18   2017-03-17 07:18:00+00:00  716.566
# 19   2017-03-17 07:19:00+00:00  716.566
# 20   2017-03-17 07:20:00+00:00  716.566
# 21   2017-03-17 07:21:00+00:00  716.566
# 22   2017-03-17 07:22:00+00:00  716.566
# 23   2017-03-17 07:23:00+00:00  716.566
# 24   2017-03-17 07:24:00+00:00  716.566
# 25   2017-03-17 07:25:00+00:00  716.566
# 26   2017-03-17 07:26:00+00:00  716.566
# 27   2017-03-17 07:27:00+00:00      NaN
# 28   2017-03-17 07:28:00+00:00      NaN
# 29   2017-03-17 07:29:00+00:00      NaN
# ...                        ...      ...
# 1411 2017-03-18 06:31:00+00:00  716.566
# 1412 2017-03-18 06:32:00+00:00  716.566
# 1413 2017-03-18 06:33:00+00:00  716.566
# 1414 2017-03-18 06:34:00+00:00  716.566
# 1415 2017-03-18 06:35:00+00:00  716.566
# 1416 2017-03-18 06:36:00+00:00  716.566
# 1417 2017-03-18 06:37:00+00:00  716.566
# 1418 2017-03-18 06:38:00+00:00  716.566
# 1419 2017-03-18 06:39:00+00:00  716.566
# 1420 2017-03-18 06:40:00+00:00  716.566
# 1421 2017-03-18 06:41:00+00:00  716.566
# 1422 2017-03-18 06:42:00+00:00  716.566
# 1423 2017-03-18 06:43:00+00:00  716.566
# 1424 2017-03-18 06:44:00+00:00  716.566
# 1425 2017-03-18 06:45:00+00:00  716.566
# 1426 2017-03-18 06:46:00+00:00  716.566
# 1427 2017-03-18 06:47:00+00:00  716.566
# 1428 2017-03-18 06:48:00+00:00  716.566
# 1429 2017-03-18 06:49:00+00:00  716.566
# 1430 2017-03-18 06:50:00+00:00  716.566
# 1431 2017-03-18 06:51:00+00:00  716.566
# 1432 2017-03-18 06:52:00+00:00  716.566
# 1433 2017-03-18 06:53:00+00:00  716.566
# 1434 2017-03-18 06:54:00+00:00  716.566
# 1435 2017-03-18 06:55:00+00:00  716.566
# 1436 2017-03-18 06:56:00+00:00  716.566
# 1437 2017-03-18 06:57:00+00:00  716.566
# 1438 2017-03-18 06:58:00+00:00  716.566
# 1439 2017-03-18 06:59:00+00:00  716.566
# 1440 2017-03-18 07:00:00+00:00  716.566
#
# [1441 rows x 2 columns]

# %%
# Perform similar request but towards Hub Plugin
# ----------- User parameters ------------
# Absolute time 
start_time = '2017-03-17T07:00:00Z'  # UTC
end_time = '2017-03-18T07:00:00Z'
# Relative time 
# start_time = '*-1d'
# end_time = '*'
interpolation_interval = '1m'
equipment_path = '?path=\\\\PIAF-ACAD\\Food and Beverage\\Brewery\\Double Hop Brewery\\Assets\\Fermentors\\Fermentor 31'
max_count = '10000' 
# Credential
username = 'reader0'
password = 'OSIsoft2017'

base_url = 'https://academicpi.azure-api.net/hub/api/' 
time_params = '&startTime={0}&endTime={1}&interval={2}&maxCount={3}'

interpolated_url_template = base_url + 'Csv/ElementInterpolated' + equipment_path + time_params  
interpolated_url = interpolated_url_template.format(start_time, end_time, interpolation_interval, max_count)

response = requests.get(interpolated_url, auth=(username, password))
if response.status_code != 200:
    print('# Request failed with code:', response.status_code, response.text)
else:
    df_plugin = pd.read_csv(io.StringIO(response.text), parse_dates=['Timestamp'])
df_plugin[['Timestamp', 'Volume']].to_csv('hub_beer_fv31_03_17_1day_0700.csv')
df_plugin
# Out:
#            Element                 Timestamp  Quality Performance  \
# 0     Fermentor 31 2017-03-17 07:00:00+00:00  No Data     No Data
# 1     Fermentor 31 2017-03-17 07:01:00+00:00  No Data     No Data
# 2     Fermentor 31 2017-03-17 07:02:00+00:00  No Data     No Data
# 3     Fermentor 31 2017-03-17 07:03:00+00:00  No Data     No Data
# 4     Fermentor 31 2017-03-17 07:04:00+00:00  No Data     No Data
# 5     Fermentor 31 2017-03-17 07:05:00+00:00  No Data     No Data
# 6     Fermentor 31 2017-03-17 07:06:00+00:00  No Data     No Data
# 7     Fermentor 31 2017-03-17 07:07:00+00:00  No Data     No Data
# 8     Fermentor 31 2017-03-17 07:08:00+00:00  No Data     No Data
# 9     Fermentor 31 2017-03-17 07:09:00+00:00  No Data     No Data
# 10    Fermentor 31 2017-03-17 07:10:00+00:00  No Data     No Data
# 11    Fermentor 31 2017-03-17 07:11:00+00:00  No Data     No Data
# 12    Fermentor 31 2017-03-17 07:12:00+00:00  No Data     No Data
# 13    Fermentor 31 2017-03-17 07:13:00+00:00  No Data     No Data
# 14    Fermentor 31 2017-03-17 07:14:00+00:00  No Data     No Data
# 15    Fermentor 31 2017-03-17 07:15:00+00:00  No Data     No Data
# 16    Fermentor 31 2017-03-17 07:16:00+00:00  No Data     No Data
# 17    Fermentor 31 2017-03-17 07:17:00+00:00  No Data     No Data
# 18    Fermentor 31 2017-03-17 07:18:00+00:00  No Data     No Data
# 19    Fermentor 31 2017-03-17 07:19:00+00:00  No Data     No Data
# 20    Fermentor 31 2017-03-17 07:20:00+00:00  No Data     No Data
# 21    Fermentor 31 2017-03-17 07:21:00+00:00  No Data     No Data
# 22    Fermentor 31 2017-03-17 07:22:00+00:00  No Data     No Data
# 23    Fermentor 31 2017-03-17 07:23:00+00:00  No Data     No Data
# 24    Fermentor 31 2017-03-17 07:24:00+00:00  No Data     No Data
# 25    Fermentor 31 2017-03-17 07:25:00+00:00  No Data     No Data
# 26    Fermentor 31 2017-03-17 07:26:00+00:00  No Data     No Data
# 27    Fermentor 31 2017-03-17 07:27:00+00:00  No Data     No Data
# 28    Fermentor 31 2017-03-17 07:28:00+00:00  No Data     No Data
# 29    Fermentor 31 2017-03-17 07:29:00+00:00  No Data     No Data
# ...            ...                       ...      ...         ...
# 1411  Fermentor 31 2017-03-18 06:31:00+00:00  No Data     No Data
# 1412  Fermentor 31 2017-03-18 06:32:00+00:00  No Data     No Data
# 1413  Fermentor 31 2017-03-18 06:33:00+00:00  No Data     No Data
# 1414  Fermentor 31 2017-03-18 06:34:00+00:00  No Data     No Data
# 1415  Fermentor 31 2017-03-18 06:35:00+00:00  No Data     No Data
# 1416  Fermentor 31 2017-03-18 06:36:00+00:00  No Data     No Data
# 1417  Fermentor 31 2017-03-18 06:37:00+00:00  No Data     No Data
# 1418  Fermentor 31 2017-03-18 06:38:00+00:00  No Data     No Data
# 1419  Fermentor 31 2017-03-18 06:39:00+00:00  No Data     No Data
# 1420  Fermentor 31 2017-03-18 06:40:00+00:00  No Data     No Data
# 1421  Fermentor 31 2017-03-18 06:41:00+00:00  No Data     No Data
# 1422  Fermentor 31 2017-03-18 06:42:00+00:00  No Data     No Data
# 1423  Fermentor 31 2017-03-18 06:43:00+00:00  No Data     No Data
# 1424  Fermentor 31 2017-03-18 06:44:00+00:00  No Data     No Data
# 1425  Fermentor 31 2017-03-18 06:45:00+00:00  No Data     No Data
# 1426  Fermentor 31 2017-03-18 06:46:00+00:00  No Data     No Data
# 1427  Fermentor 31 2017-03-18 06:47:00+00:00  No Data     No Data
# 1428  Fermentor 31 2017-03-18 06:48:00+00:00  No Data     No Data
# 1429  Fermentor 31 2017-03-18 06:49:00+00:00  No Data     No Data
# 1430  Fermentor 31 2017-03-18 06:50:00+00:00  No Data     No Data
# 1431  Fermentor 31 2017-03-18 06:51:00+00:00  No Data     No Data
# 1432  Fermentor 31 2017-03-18 06:52:00+00:00  No Data     No Data
# 1433  Fermentor 31 2017-03-18 06:53:00+00:00  No Data     No Data
# 1434  Fermentor 31 2017-03-18 06:54:00+00:00  No Data     No Data
# 1435  Fermentor 31 2017-03-18 06:55:00+00:00  No Data     No Data
# 1436  Fermentor 31 2017-03-18 06:56:00+00:00  No Data     No Data
# 1437  Fermentor 31 2017-03-18 06:57:00+00:00  No Data     No Data
# 1438  Fermentor 31 2017-03-18 06:58:00+00:00  No Data     No Data
# 1439  Fermentor 31 2017-03-18 06:59:00+00:00  No Data     No Data
# 1440  Fermentor 31 2017-03-18 07:00:00+00:00  No Data     No Data
#
#      Availability  Batch Active Tag Active Production (last 24h) Yeast Strain  \
# 0         No Data                 1                           24     NCYC1187
# 1         No Data                 1                           24     NCYC1187
# 2         No Data                 1                           24     NCYC1187
# 3         No Data                 1                           24     NCYC1187
# 4         No Data                 1                           24     NCYC1187
# 5         No Data                 1                           24     NCYC1187
# 6         No Data                 1                           24     NCYC1187
# 7         No Data                 1                           24     NCYC1187
# 8         No Data                 1                           24     NCYC1187
# 9         No Data                 1                           24     NCYC1187
# 10        No Data                 1                           24     NCYC1187
# 11        No Data                 1                           24     NCYC1187
# 12        No Data                 1                           24     NCYC1187
# 13        No Data                 1                           24     NCYC1187
# 14        No Data                 1                           24     NCYC1187
# 15        No Data                 1                           24     NCYC1187
# 16        No Data                 1                           24     NCYC1187
# 17        No Data                 1                           24     NCYC1187
# 18        No Data                 1                           24     NCYC1187
# 19        No Data                 1                           24     NCYC1187
# 20        No Data                 1                           24     NCYC1187
# 21        No Data                 1                           24     NCYC1187
# 22        No Data                 1                           24     NCYC1187
# 23        No Data                 1                           24     NCYC1187
# 24        No Data                 1                           24     NCYC1187
# 25        No Data                 1                           24     NCYC1187
# 26        No Data                 1                           24     NCYC1187
# 27        No Data                 1                           24     NCYC1187
# 28        No Data                 1                           24     NCYC1187
# 29        No Data                 1                           24     NCYC1187
# ...           ...               ...                          ...          ...
# 1411      No Data                 0             23.5658302307129     NCYC1187
# 1412      No Data                 0             23.5658302307129     NCYC1187
# 1413      No Data                 0             23.5658302307129     NCYC1187
# 1414      No Data                 0             23.5658302307129     NCYC1187
# 1415      No Data                 0             23.5658302307129     NCYC1187
# 1416      No Data                 0             23.5658302307129     NCYC1187
# 1417      No Data                 0             23.5658302307129     NCYC1187
# 1418      No Data                 0             23.5658302307129     NCYC1187
# 1419      No Data                 0             23.5658302307129     NCYC1187
# 1420      No Data                 0             23.5658302307129     NCYC1187
# 1421      No Data                 0             23.5658302307129     NCYC1187
# 1422      No Data                 0             23.5658302307129     NCYC1187
# 1423      No Data                 0             23.5658302307129     NCYC1187
# 1424      No Data                 0             23.5658302307129     NCYC1187
# 1425      No Data                 0             23.5658302307129     NCYC1187
# 1426      No Data                 0             23.5658302307129     NCYC1187
# 1427      No Data                 0             23.5658302307129     NCYC1187
# 1428      No Data                 0             23.5658302307129     NCYC1187
# 1429      No Data                 0             23.5658302307129     NCYC1187
# 1430      No Data                 0             23.5658302307129     NCYC1187
# 1431      No Data                 0             23.5658302307129     NCYC1187
# 1432      No Data                 0             23.5658302307129     NCYC1187
# 1433      No Data                 0             23.5658302307129     NCYC1187
# 1434      No Data                 0             23.5658302307129     NCYC1187
# 1435      No Data                 0             23.5658302307129     NCYC1187
# 1436      No Data                 0             23.5658302307129     NCYC1187
# 1437      No Data                 0             23.5658302307129     NCYC1187
# 1438      No Data                 0             23.5658302307129     NCYC1187
# 1439      No Data                 0             23.5658302307129     NCYC1187
# 1440      No Data                 0             23.5658302307129     NCYC1187
#
#      Yeast Generation Volume Out  ... Process Cell Cone Temperature  \
# 0             No Data          0  ...           C2                0
# 1             No Data          0  ...           C2                0
# 2             No Data          0  ...           C2                0
# 3             No Data          0  ...           C2                0
# 4             No Data          0  ...           C2                0
# 5             No Data          0  ...           C2                0
# 6             No Data          0  ...           C2                0
# 7             No Data          0  ...           C2                0
# 8             No Data          0  ...           C2                0
# 9             No Data          0  ...           C2                0
# 10            No Data          0  ...           C2                0
# 11            No Data          0  ...           C2                0
# 12            No Data          0  ...           C2                0
# 13            No Data          0  ...           C2                0
# 14            No Data          0  ...           C2                0
# 15            No Data          0  ...           C2                0
# 16            No Data          0  ...           C2                0
# 17            No Data          0  ...           C2                0
# 18            No Data          0  ...           C2                0
# 19            No Data          0  ...           C2                0
# 20            No Data          0  ...           C2                0
# 21            No Data          0  ...           C2                0
# 22            No Data          0  ...           C2                0
# 23            No Data          0  ...           C2                0
# 24            No Data          0  ...           C2                0
# 25            No Data          0  ...           C2                0
# 26            No Data          0  ...           C2                0
# 27            No Data          0  ...           C2                0
# 28            No Data          0  ...           C2                0
# 29            No Data          0  ...           C2                0
# ...               ...        ...  ...          ...              ...
# 1411          No Data          0  ...           C2                0
# 1412          No Data          0  ...           C2                0
# 1413          No Data          0  ...           C2                0
# 1414          No Data          0  ...           C2                0
# 1415          No Data          0  ...           C2                0
# 1416          No Data          0  ...           C2                0
# 1417          No Data          0  ...           C2                0
# 1418          No Data          0  ...           C2                0
# 1419          No Data          0  ...           C2                0
# 1420          No Data          0  ...           C2                0
# 1421          No Data          0  ...           C2                0
# 1422          No Data          0  ...           C2                0
# 1423          No Data          0  ...           C2                0
# 1424          No Data          0  ...           C2                0
# 1425          No Data          0  ...           C2                0
# 1426          No Data          0  ...           C2                0
# 1427          No Data          0  ...           C2                0
# 1428          No Data          0  ...           C2                0
# 1429          No Data          0  ...           C2                0
# 1430          No Data          0  ...           C2                0
# 1431          No Data          0  ...           C2                0
# 1432          No Data          0  ...           C2                0
# 1433          No Data          0  ...           C2                0
# 1434          No Data          0  ...           C2                0
# 1435          No Data          0  ...           C2                0
# 1436          No Data          0  ...           C2                0
# 1437          No Data          0  ...           C2                0
# 1438          No Data          0  ...           C2                0
# 1439          No Data          0  ...           C2                0
# 1440          No Data          0  ...           C2                0
#
#      Bottom Temperature Active Status OEE  Brewery Name Production Status  \
# 0                     0           1.0 NaN        Assets               1.0
# 1                     0           1.0 NaN        Assets               1.0
# 2                     0           1.0 NaN        Assets               1.0
# 3                     0           1.0 NaN        Assets               1.0
# 4                     0           1.0 NaN        Assets               1.0
# 5                     0           1.0 NaN        Assets               1.0
# 6                     0           1.0 NaN        Assets               1.0
# 7                     0           1.0 NaN        Assets               1.0
# 8                     0           1.0 NaN        Assets               1.0
# 9                     0           1.0 NaN        Assets               1.0
# 10                    0           1.0 NaN        Assets               1.0
# 11                    0           1.0 NaN        Assets               1.0
# 12                    0           1.0 NaN        Assets               1.0
# 13                    0           1.0 NaN        Assets               1.0
# 14                    0           1.0 NaN        Assets               1.0
# 15                    0           1.0 NaN        Assets               1.0
# 16                    0           1.0 NaN        Assets               1.0
# 17                    0           1.0 NaN        Assets               1.0
# 18                    0           1.0 NaN        Assets               1.0
# 19                    0           1.0 NaN        Assets               1.0
# 20                    0           1.0 NaN        Assets               1.0
# 21                    0           1.0 NaN        Assets               1.0
# 22                    0           1.0 NaN        Assets               1.0
# 23                    0           1.0 NaN        Assets               1.0
# 24                    0           1.0 NaN        Assets               1.0
# 25                    0           1.0 NaN        Assets               1.0
# 26                    0           1.0 NaN        Assets               1.0
# 27                    0           1.0 NaN        Assets               1.0
# 28                    0           1.0 NaN        Assets               1.0
# 29                    0           1.0 NaN        Assets               1.0
# ...                 ...           ...  ..           ...               ...
# 1411                  0           1.0 NaN        Assets               1.0
# 1412                  0           1.0 NaN        Assets               1.0
# 1413                  0           1.0 NaN        Assets               1.0
# 1414                  0           1.0 NaN        Assets               1.0
# 1415                  0           1.0 NaN        Assets               1.0
# 1416                  0           1.0 NaN        Assets               1.0
# 1417                  0           1.0 NaN        Assets               1.0
# 1418                  0           1.0 NaN        Assets               1.0
# 1419                  0           1.0 NaN        Assets               1.0
# 1420                  0           1.0 NaN        Assets               1.0
# 1421                  0           1.0 NaN        Assets               1.0
# 1422                  0           1.0 NaN        Assets               1.0
# 1423                  0           1.0 NaN        Assets               1.0
# 1424                  0           1.0 NaN        Assets               1.0
# 1425                  0           1.0 NaN        Assets               1.0
# 1426                  0           1.0 NaN        Assets               1.0
# 1427                  0           1.0 NaN        Assets               1.0
# 1428                  0           1.0 NaN        Assets               1.0
# 1429                  0           1.0 NaN        Assets               1.0
# 1430                  0           1.0 NaN        Assets               1.0
# 1431                  0           1.0 NaN        Assets               1.0
# 1432                  0           1.0 NaN        Assets               1.0
# 1433                  0           1.0 NaN        Assets               1.0
# 1434                  0           1.0 NaN        Assets               1.0
# 1435                  0           1.0 NaN        Assets               1.0
# 1436                  0           1.0 NaN        Assets               1.0
# 1437                  0           1.0 NaN        Assets               1.0
# 1438                  0           1.0 NaN        Assets               1.0
# 1439                  0           1.0 NaN        Assets               1.0
# 1440                  0           1.0 NaN        Assets               1.0
#
#       Yeast Status   Vessel Name       ADF
# 0              NaN  Fermentor 31  0.659725
# 1              NaN  Fermentor 31  0.659725
# 2              NaN  Fermentor 31  0.659725
# 3              NaN  Fermentor 31  0.659725
# 4              NaN  Fermentor 31  0.659725
# 5              NaN  Fermentor 31  0.659725
# 6              NaN  Fermentor 31  0.659725
# 7              NaN  Fermentor 31  0.659725
# 8              NaN  Fermentor 31  0.659725
# 9              NaN  Fermentor 31  0.659725
# 10             NaN  Fermentor 31  0.659725
# 11             NaN  Fermentor 31  0.659725
# 12             NaN  Fermentor 31  0.659725
# 13             NaN  Fermentor 31  0.659725
# 14             NaN  Fermentor 31  0.659725
# 15             NaN  Fermentor 31  0.659725
# 16             NaN  Fermentor 31  0.659725
# 17             NaN  Fermentor 31  0.659725
# 18             NaN  Fermentor 31  0.659725
# 19             NaN  Fermentor 31  0.659725
# 20             NaN  Fermentor 31  0.659725
# 21             NaN  Fermentor 31  0.659725
# 22             NaN  Fermentor 31  0.659725
# 23             NaN  Fermentor 31  0.659725
# 24             NaN  Fermentor 31  0.659725
# 25             NaN  Fermentor 31  0.659725
# 26             NaN  Fermentor 31  0.659725
# 27             NaN  Fermentor 31  0.659725
# 28             NaN  Fermentor 31  0.659725
# 29             NaN  Fermentor 31  0.659725
# ...            ...           ...       ...
# 1411           NaN  Fermentor 31  0.659725
# 1412           NaN  Fermentor 31  0.659725
# 1413           NaN  Fermentor 31  0.659725
# 1414           NaN  Fermentor 31  0.659725
# 1415           NaN  Fermentor 31  0.659725
# 1416           NaN  Fermentor 31  0.659725
# 1417           NaN  Fermentor 31  0.659725
# 1418           NaN  Fermentor 31  0.659725
# 1419           NaN  Fermentor 31  0.659725
# 1420           NaN  Fermentor 31  0.659725
# 1421           NaN  Fermentor 31  0.659725
# 1422           NaN  Fermentor 31  0.659725
# 1423           NaN  Fermentor 31  0.659725
# 1424           NaN  Fermentor 31  0.659725
# 1425           NaN  Fermentor 31  0.659725
# 1426           NaN  Fermentor 31  0.659725
# 1427           NaN  Fermentor 31  0.659725
# 1428           NaN  Fermentor 31  0.659725
# 1429           NaN  Fermentor 31  0.659725
# 1430           NaN  Fermentor 31  0.659725
# 1431           NaN  Fermentor 31  0.659725
# 1432           NaN  Fermentor 31  0.659725
# 1433           NaN  Fermentor 31  0.659725
# 1434           NaN  Fermentor 31  0.659725
# 1435           NaN  Fermentor 31  0.659725
# 1436           NaN  Fermentor 31  0.659725
# 1437           NaN  Fermentor 31  0.659725
# 1438           NaN  Fermentor 31  0.659725
# 1439           NaN  Fermentor 31  0.659725
# 1440           NaN  Fermentor 31  0.659725
#
# [1441 rows x 49 columns]

# %%
recorded_url_template = base_url + 'Csv/ElementRecorded' + equipment_path + '&startTime={0}&endTime={1}'
recorded_url = recorded_url_template.format(start_time, end_time)
response = requests.get(recorded_url, auth=(username, password))
response
# Out:
# <Response [200]>

# %%
if response.status_code != 200:
    print('# Request failed with code:', response.status_code, response.text)
else:
    df_plugin_rec = pd.read_csv(io.StringIO(response.text), parse_dates=['Timestamp'])
#df_plugin_rec[['Timestamp', 'Volume']].to_csv('hub_beer_fv31_03_17_1day_rec.csv')
#df_plugin_rec[['Timestamp', 'Volume']]
df_plugin_rec[df_plugin_rec.Attribute == 'Volume']
# Out:
#          Element Attribute                 Timestamp             Value
# 32  Fermentor 31    Volume 2017-03-17 07:26:12+00:00  716.565979003906
# 33  Fermentor 31    Volume 2017-03-17 15:01:06+00:00         Bad Input
# 34  Fermentor 31    Volume 2017-03-17 15:16:54+00:00  716.565979003906
# 35  Fermentor 31    Volume 2017-03-17 15:26:00+00:00         Bad Input
# 36  Fermentor 31    Volume 2017-03-17 15:36:15+00:00  716.565979003906
# 37  Fermentor 31    Volume 2017-03-17 23:36:01+00:00  716.565979003906

# %%
data = []
trace_ocs = go.Scattergl(x = df_ocs['Timestamp'], 
                             y = df_ocs['Volume'], 
                             mode = 'markers', 
                             name = 'OCS',
                             hoverlabel = {'namelength': -1})
data.append(trace_ocs)

# %%
trace_hub = go.Scattergl(x = df_plugin['Timestamp'], 
                             y = df_plugin['Volume'], 
                             mode = 'markers', 
                             name = 'PIWeb',
                             hoverlabel = {'namelength': -1})
data.append(trace_hub)

# %%
layout = dict(title='OCS Versus PI Web API Interpolation around Bad Input values')
fig = go.FigureWidget(data=data, layout=layout)
fig
# Out:
# FigureWidget({
#     'data': [{'hoverlabel': {'namelength': -1},
#               'mode': 'markers',
#               …

# %% [markdown]
# ### Multiple sensors - Similar assets have consistent data shape - Regular time intervals

# %% [markdown]
# ### Note the that resulting dataframe has about 28801 rows
#
# **This is for 1 fermenter X 20 days X 1440 rows per day (24 hours at 1 minute interval)**
#
# ## Save data into CSV file locally

# %% [raw]
# df.to_csv('beer_ocs_all_20days.csv', index=False)

# %% [markdown]
# ## The file `beer_ocs_all_20days.csv` can be opened with Excel for inspection

# %% [markdown]
# # ADF Prediction
#
# ## First start by reading all fermenter vessels data, 300 days
#
# ### (Previously saved on file, takes a little while to read back)

# %%
# Warnings while running this cell are normal
# df = pd.read_csv('beer_ocs_all_300days.csv.zip', parse_dates = ['Timestamp'], compression='infer')
# df

# %% [markdown]
# ### Note: the result CSV above has 2.6 million rows
#
# ### List all unique Fermentation Batch IDs, filter out bad ones

# %%
all_ferm_ids = sorted(df['Fermentation ID'].unique()) 
# Check for invalid Fermentation ID
for ferm_id in all_ferm_ids:
    if not ('FV' in ferm_id or 'Fermentor' in ferm_id):
        print('Bad Ferm ID:', ferm_id)
# Keep only valid ones, should contain 'FV' or 'Fermenter'
all_valid_ferm_ids = [ferm_id for ferm_id in all_ferm_ids if 'FV' in ferm_id or 'Fermentor' in ferm_id]
print(all_valid_ferm_ids)
df = df[df['Fermentation ID'].isin(all_valid_ferm_ids)]
df

# %% [markdown]
# ### Apparent Degree of Fermentation for a set of fermentations

# %%
data = []
end_time = parser.parse('2017-04-04').isoformat()
dft = df[df.Timestamp <= end_time]
for ferm_id in all_valid_ferm_ids:
    df_ferm_id = dft[(dft['Fermentation ID'] == ferm_id) & (dft['Status'] == 'Fermentation')][['Timestamp', 'ADF']]
    if len(df_ferm_id) > 0:
        trace = go.Scattergl(x = df_ferm_id['Timestamp'], 
                             y = df_ferm_id['ADF'], 
                             mode = 'lines+markers', 
                             name = str(ferm_id),
                             hoverlabel = {'namelength': -1})
        data.append(trace)

# %% [markdown]
# ### Add a range slider
#
# With a few time range selectors: 1 day, 3 days and everything

# %%
layout = dict(
    title='ADF during fermentation stage, 20 days',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1d',
                     step='day',
                     stepmode='backward'),
                dict(count=3,
                    label='3d',
                    step='day',
                    stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)
 
fig = go.FigureWidget(data=data, layout=layout)

# %%
fig

# %% [markdown]
# # Learning Outcome: Data cleansing and preparation
# ## Example: student selects relevant data for analysis

# %% [markdown]
# ###  (We only want to look at data while the fermentor is in the fermentation stage)

# %%
# Keep only the relevant columns
ndf = df[(df['Status'] == 'Fermentation')][['Timestamp', 'ADF', 'Brand', 'FV Full Plato', 'Plato', 'Fermentation ID']]
ndf

# %%
# Filter out rows without valid ADF value
ndf = ndf[~(ndf['ADF'].isin(['Calc Failed']))]
ndf

# %% [markdown]
# ## Step 2: ADF is an offline measurement, keep only data that corresponds to a new measurement

# %%
dff = ndf[ndf.ADF.shift() != ndf.ADF].reset_index()
dff.to_csv('df_step2.csv')
dff[['Timestamp', 'ADF', 'Brand', 'Fermentation ID']]

# %% [markdown]
# ## Step 3: We want to analyze all fermentations together, so we need to look at elapsed time. Here we find the index that corresponds to the beginning of each fermentation

# %%
# Make sure that the ADF column is of type float, necessary for arithmetic operations on it
dff = dff.astype({'ADF': 'float'})
dfferm = dff[abs(dff.ADF) <= 0.000001]
ferm_start_indexes = []
for i, _ in dfferm.iterrows():
    # print(i, row['index'])
    ferm_start_indexes.append(i)
print(ferm_start_indexes)

# %% [markdown]
# ## Step 4: Create new columns (computed in step 5)
#
# * **Elapsed**: elapsed time since fermentation starts
#
# * **tdif**: time difference with row just before
#
# * **adfdif**: ADF difference with row just before

# %%
dff['Elapsed'] = dff['Timestamp'] - dff['Timestamp']
dff['tdif'] = dff['Timestamp'] - dff['Timestamp']
dff['adfdif'] = dff['ADF'] 
dff.to_csv('dff_step4.csv', index=False)
dff

# %% [markdown]
# ## Step 5: Compute values for 3 new columns

# %%
ferm_start_indexes.append(-1)
adf_start_time = dfferm.iloc[0]['Timestamp']
count = 1
for i, row in dff.iterrows():
    try: 
        dff.at[i,'Elapsed'] = row.Timestamp - dfferm.iloc[count-1].Timestamp
        if i != ferm_start_indexes[count-1]:
            dff.at[i,'tdif'] = row.Timestamp - last_timestamp
            dff.at[i,'adfdif'] = row.ADF - last_adf
        last_timestamp = row.Timestamp 
        last_adf = row.ADF 
        if i+1 == ferm_start_indexes[count]:
            count += 1 
    except IndexError:
        pass
dff.to_csv('dff_step5.csv', index=False)
dff[['Timestamp', 'Elapsed', 'tdif', 'ADF', 'adfdif', 'Brand']]

# %% [markdown]
# ### Number of fermentations for brand Realtime Hops
# This brand has the most data to work with for the analysis part

# %%
len(dff[(dff.Brand == 'Realtime Hops') & (abs(dff.ADF) <= 0.000001)])

# %% [markdown]
# ## All the way up to Step 6:
#
# ### Only keep data for Realtime Hops and remove inconsistent data
#
# * All elapsed time must be positive
# * A fermentation cannot last more than 4 days, remove is elapsed is over

# %%
delta0 = dt.timedelta(days=0)
delta4 = dt.timedelta(days=4)
rh_df = dff[(dff.Brand == 'Realtime Hops') & (dff.Elapsed >= delta0) & (dff.Elapsed < delta4)]
rh_df

# %% [markdown]
# ### Compute new columns with Elasped and tdif in seconds
# Note: warnings are OK

# %%
rh_df.loc[:, 'Elapsed_seconds'] = rh_df['Elapsed'].dt.days * (60*60*24) + rh_df['Elapsed'].dt.seconds
rh_df.loc[:, 'tdif_seconds'] = rh_df.Elapsed_seconds - rh_df.Elapsed_seconds.shift()
l = [i for i, _ in rh_df[(rh_df.tdif_seconds < 0)].iterrows()]
for i in l:
    # rh_df.at[i, 'tdif_seconds'] = 0
    rh_df.loc[i, 'tdif_seconds'] = 0
rh_df

# %% [markdown]
# ### Plot all relative fermentention curves for Realtime Hops brand

# %%
bad_ferm_ids = ['Fermentor 362017423070', 'Fermentor 36201742557961']  # known bad fermentation batch
rh_df = rh_df[~rh_df['Fermentation ID'].isin(bad_ferm_ids)]
for i in ferm_start_indexes:
    rh_df = rh_df.drop(i, errors='ignore')
data = []
for ferm_id in sorted(rh_df['Fermentation ID'].unique()):
    df_ferm_id = rh_df[rh_df['Fermentation ID'] == ferm_id][['Elapsed_seconds', 'ADF']]
    trace = go.Scattergl(x = df_ferm_id['Elapsed_seconds'], 
                         y = df_ferm_id['ADF'], 
                         mode = 'markers', 
                         name = str(ferm_id),
                         hoverlabel = {'namelength': -1})
    data.append(trace)
    
fig = go.FigureWidget(data=data, layout = dict(title='ADF - Realtime Hops'))

# %% [markdown]
# # Learning Outcome: data exploration and visual analysis

# %%
fig

# %% [markdown]
# ### The last cell of the data preprocessing part
# The output file `regression_ocs.csv` is the input of the analysis part which follows

# %%
# This cell produces a CSV in exactly the same format as the one for original R code 

df_csv = rh_df[['Elapsed_seconds', 'ADF', 'tdif_seconds', 'adfdif', 'FV Full Plato', 'Plato']]
df_csvR = df_csv.rename(columns = {'Elapsed_seconds': 'time', 'ADF': 'adf', 'tdif_seconds': 'tdif', 'FV Full Plato': 'A', 'Plato': 'B'})
df_csvR.to_csv('regression_ocs.csv', index=False)
df_csvR

# %% [markdown]
# ## Learning Outcome: application of analytical techniques
# ![Linear](./lehigh-linear-model.png)

# %% [markdown]
# ### Setting up analysis environment (using R)

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# #-------------------------------------------
# # LOAD LIBRARIES -
# # NOTE: run at least once with install.packages uncommented
# #-------------------------------------------
# # install.packages('RCurl', repos='http://cran.us.r-project.org')
# library(RCurl);
# # install.packages('tibble', repos='http://cran.us.r-project.org')
# library(tibble)
# # install.packages('ggplot2', repos='http://cran.us.r-project.org')
# library(ggplot2)
#
# # install.packages('data.table', repos='http://cran.us.r-project.org')
# library(data.table)
# # install.packages('segmented', repos='http://cran.us.r-project.org')
# library(segmented)

# %% [markdown]
# ### Plot data to analyse: Realtime Hops brand fermentations

# %%
# %%R
# # Header: time,adf,tdif,adfdif,A,B
# MyData <- read.csv(file="regression_ocs.csv", header=TRUE, sep=",")
# MyData$time <- MyData$time/60/60
# plot(MyData$time, MyData$adf,xlab = "Time Since Fermentation [hours]", ylab='ADF', main = "All data")

# %% [markdown]
# ### Create filter for outliers

# %%
# %%R
# outliers <- (MyData$time< 50000/60/60 & MyData$adf > 0.2) + (MyData$time< 70000/60/60 & MyData$adf > 0.3) + (MyData$time< 120000/60/60 & MyData$adf > 0.6)
#
# goodData <- !outliers
#
# goodData

# %% [markdown]
# ## First try with a simple linear model

# %% [raw]
# %%R -o s
# FilteredADF <- MyData$adf[goodData]
# FilteredTimes <- MyData$time[goodData]
# plot(FilteredTimes, FilteredADF,xlab = "Time Since Fermentation [hours]", ylab='ADF', main = "ADF ~ Time")
# linMod <- lm(FilteredADF ~ FilteredTimes)
# abline(linMod$coefficients)
# s <- summary(linMod)

# %%
# %%R
# ADF <- MyData$adf[goodData]
# Times <- MyData$time[goodData]

# %%
# %%R -o s
# plot(Times, ADF,xlab = "Time Since Fermentation [hours]", ylab='ADF', main = "ADF ~ Time")
# linMod <- lm(ADF ~ Times)
# abline(linMod$coefficients)
# s <- summary(linMod)

# %% [markdown]
# ### Information summary from linear regression library

# %%
print(s)

# %% [markdown]
# ![Error](./images/lehigh-linear-check.png)

# %% [markdown]
# ## Actual residuals

# %%
# %%R
# predicted <- fitted(linMod)
# errors <- resid(linMod)
# plot( predicted ,errors, main = "Residuals vs. predicted ADF" )

# %% [markdown]
# ## Normality test - should be randomly distributed if model is OK

# %%
# %%R
# stdres = rstandard(linMod)
# qqnorm(stdres, ylab="Standardized Residuals", xlab="Normal Scores", main="Normality test")
# qqline(stdres)

# %% [markdown]
# ![Change model](./images/lehigh-change-model.png)

# %% [markdown]
# ![Justification](./images/lehigh-justification-new-model.png)

# %% [markdown]
# ![Segmented](./images/lehigh-segmented-model.png)

# %% [markdown]
# ## Improved model: segmented linear
#
# Using R package called `segmented`

# %%
# %%R -o o
# plot(Times, ADF,xlab = "Time Since Fermentation [hours]", ylab='ADF', main = "ADF ~ Time")
# linMod <- lm(ADF ~ Times)
# set.seed(12)
# xx <- Times
# yy <- ADF
# dati <- data.frame(x = xx, y = yy )
# out.lm <- lm(y ~ x, data = dati)
# o <- segmented(out.lm, seg.Z = ~x, psi = list(x = c(10,40)), control = seg.control(display = FALSE) )
# dat2 = data.frame(x = xx, y = broken.line(o)$fit)
# o

# %% [markdown]
# ### Information summary from segmented linear regression library

# %%
print(o)

# %% [markdown]
# ### Graphical verification of the segmented linear model prediction

# %%
# %%R
# ggplot(dati, aes(x = x, y = y)) + xlab("Time Since Fermentation [hours]") + ylab('ADF') + geom_point() +
#   geom_line(data = dat2, color = 'blue')

# %% [markdown]
# ### Error analysis (again, should be randomly distributed)

# %%
# %%R
# errors <- resid(o)
#
# plot( predicted ,errors, main = "Residuals vs. predicted ADF" )

# %%
# %%R
# stdres = rstandard(o)
# qqnorm(stdres, ylab="Standardized Residuals", xlab="Normal Scores", main="Normality test")
# qqline(stdres)

# %% [markdown]
# ![noimg](./images/osi_thank_you_slide.png)
