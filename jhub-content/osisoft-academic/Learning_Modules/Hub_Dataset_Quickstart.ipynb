# %% [markdown]
# # OSIsoft Academic Hub Datasets Quick Start (Python Library)
#
# Version 0.95
#
# Academic Hub datasets are hosted by the OSIsoft Cloud Service (OCS, https://www.osisoft.com/solutions/cloud/vision/), a cloud-native realtime data infrastructure to perform enterprise-wide analytics using tools and languages of their choice.
#
# **Raw operational data has specific characteristics making it difficult to deal with directly**, among them:
#
# * variable data collection frequencies
# * bad values (system error codes)
# * data gaps
#
#
# **But data science projects against operational data needs to be:**
#
# * **Time-aligned** to deal with the characteritics above in consistent way according to the data type (e.g. interpolation for float values, repeat last good value for categorical data, etc)
# * **Context aware** so that the data can be understandable, across as many real-world assets that you need it for
# * **Shaped and filtered** to ensure you have the data you need, in the form you need it
#
# **OCS solution for application-ready data are Data Views:**
#
# ![](https://academichub.blob.core.windows.net/images/piworld-dse-dataview-p2.png)
#
# **Each Academic Hub datasets comes endowed with a set of asset-centric data views.** The goal of Academic Hub Python library is to allow in a very generic and consistent way to access:
#
# * the list of existing datasets
# * for a given dataset:
#   * get the list of its assets
#   * get the OCS namespace where the dataset is hosted
# * for a given asset, get the list data views it belongs to
#
# The rest of this notebook is a working example of the functionality listed above.

# %% [markdown]
# ## Install Academic Hub Python library

# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple ocs-academic-hub==0.79.0

# %% [markdown]
# ## Use the `pip uninstall` only in case of library issues

# %%
# It's sometimes necessary to uninstall previous versions, uncomment and run the following line. Then restart kernel and reinstall with previous cell
# !pip uninstall -y ocs-academic-hub ocs-sample-library-preview

# WARNING: uncomment only for testing
#%env OCS_HUB_CONFIG=config.ini
# Out:
# env: OCS_HUB_CONFIG=config.ini

# %% [markdown]
# ## Import HubClient, necessary to connect and interact with OCS

# %%
from ocs_academic_hub import HubClient

# %% [markdown]
# ## Running the following cell initiate the login sequence
#
# Return to this web page when done

# %%
hub = HubClient()
# Out:
# > configuration file: config.ini

# %% [markdown]
# ## Get list of published hub datasets
#
# NOTE: currently only `Deschutes Brewery` supports the new interface. This notebook is specifically about this dataset.

# %%
hub.datasets()
# Out:
# ['Deschutes-v1', 'UCDavis.Facilities', 'Brewery']

# %% [markdown]
# ## Display current active dataset
#
# NOTE: it will be possible to switch it once other datasets support the new asset interface.

# %%
hub.current_dataset()
# Out:
# 'Brewery'

# %% [markdown]
# ## Get list of assets with Data Views
#
# Returned into the form of a pandas dataframe, with column `Asset_Id` and `Description`. The cell above with `print` and `.to_string()` allows to see the whole dataframe content.

# %%
print(hub.assets().to_string())
# Out:
#           Asset_Id                Description
# 0        Acid Tank                        AT1
# 1              BA1
# 2              BA2
# 3             BB02                Bright Tank
# 4        BB02 Line                Bright Tank
# 5             BB03                Bright Tank
# 6             BB04                Bright Tank
# 7             BB05                Bright Tank
# 8             BB06                Bright Tank
# 9             BB07                Bright Tank
# 10            BB08                Bright Tank
# 11            BB09                Bright Tank
# 12            BB11                Bright Tank
# 13            BB12                Bright Tank
# 14            BB13                Bright Tank
# 15            BB14                Bright Tank
# 16            BB15                Bright Tank
# 17   Beer Transfer      Beer TransferTemplate
# 18         C1_BBL1   Cellar1 Bright Beer Line
# 19          C1_BL1         Cellar 1 Beer Line
# 20          C1_PS1                        PS1
# 21          C1_PS2                        PS2
# 22          C1_YL1        Cellar 1 Yeast Line
# 23         C2_BBL1  Cellar 2 Bright Beer Line
# 24          C2_FT1         Cellar 2 Foam Tank
# 25          C2_PS1                     C2_PS1
# 26          C2_PS2                     C2_PS2
# 27          C3_BL1         Cellar 3 Beer Line
# 28          C3_FT1         Cellar 3 Foam Trap
# 29          C3_YL1        Cellar 3 Yeast Line
# 30            CNT1                 Centrifuge
# 31            CNT2                 Centrifuge
# 32            CST1
# 33    Caustic Tank                        CT1
# 34  Clean In Place                       CIP1
# 35            FV01        Fermentation Vessel
# 36            FV02        Fermentation Vessel
# 37            FV08        Fermentation Vessel
# 38            FV09        Fermentation Vessel
# 39    FV1/FV2 Line        Fermentation Vessel
# 40            FV10        Fermentation Vessel
# 41            FV11        Fermentation Vessel
# 42            FV12        Fermentation Vessel
# 43            FV13        Fermentation Vessel
# 44            FV14        Fermentation Vessel
# 45            FV15        Fermentation Vessel
# 46            FV16        Fermentation Vessel
# 47            FV17        Fermentation Vessel
# 48            FV18        Fermentation Vessel
# 49            FV19        Fermentation Vessel
# 50            FV20        Fermentation Vessel
# 51            FV21        Fermentation Vessel
# 52            FV22        Fermentation Vessel
# 53            FV23        Fermentation Vessel
# 54            FV24        Fermentation Vessel
# 55            FV25        Fermentation Vessel
# 56            FV26        Fermentation Vessel
# 57            FV27        Fermentation Vessel
# 58            FV28        Fermentation Vessel
# 59            FV31        Fermentation Vessel
# 60            FV32        Fermentation Vessel
# 61            FV33        Fermentation Vessel
# 62            FV34        Fermentation Vessel
# 63            FV35        Fermentation Vessel
# 64            FV36        Fermentation Vessel
# 65            FV37        Fermentation Vessel
# 66            FV38        Fermentation Vessel
# 67            FV39        Fermentation Vessel
# 68            FV40        Fermentation Vessel
# 69            FV41        Fermentation Vessel
# 70            FV42        Fermentation Vessel
# 71            FV43        Fermentation Vessel
# 72            FV44        Fermentation Vessel
# 73            FV45        Fermentation Vessel
# 74            FV46        Fermentation Vessel
# 75          Loop 1
# 76          Loop 2
# 77             PZ1

# %% [markdown]
# ## List of all Data Views
#
# Those are all single-asset default (with all data available for the asset) Data Views

# %%
hub.asset_dataviews()
# Out:
# ['brewery-acid.tank',
#  'brewery-ba1',
#  'brewery-ba2',
#  'brewery-bb02',
#  'brewery-bb02.line',
#  'brewery-bb03',
#  'brewery-bb04',
#  'brewery-bb05',
#  'brewery-bb06',
#  'brewery-bb07',
#  'brewery-bb08',
#  'brewery-bb09',
#  'brewery-bb11',
#  'brewery-bb12',
#  'brewery-bb13',
#  'brewery-bb14',
#  'brewery-bb15',
#  'brewery-beer.transfer',
#  'brewery-c1_bbl1',
#  'brewery-c1_bl1',
#  'brewery-c1_ps1',
#  'brewery-c1_ps2',
#  'brewery-c1_yl1',
#  'brewery-c2_bbl1',
#  'brewery-c2_ft1',
#  'brewery-c2_ps1',
#  'brewery-c2_ps2',
#  'brewery-c3_bl1',
#  'brewery-c3_ft1',
#  'brewery-c3_yl1',
#  'brewery-caustic.tank',
#  'brewery-clean.in.place',
#  'brewery-cnt1',
#  'brewery-cnt2',
#  'brewery-cst1',
#  'brewery-fv01',
#  'brewery-fv02',
#  'brewery-fv08',
#  'brewery-fv09',
#  'brewery-fv10',
#  'brewery-fv11',
#  'brewery-fv12',
#  'brewery-fv13',
#  'brewery-fv14',
#  'brewery-fv15',
#  'brewery-fv16',
#  'brewery-fv17',
#  'brewery-fv18',
#  'brewery-fv19',
#  'brewery-fv1__fv2.line',
#  'brewery-fv20',
#  'brewery-fv21',
#  'brewery-fv22',
#  'brewery-fv23',
#  'brewery-fv24',
#  'brewery-fv25',
#  'brewery-fv26',
#  'brewery-fv27',
#  'brewery-fv28',
#  'brewery-fv31',
#  'brewery-fv32',
#  'brewery-fv33',
#  'brewery-fv34',
#  'brewery-fv35',
#  'brewery-fv36',
#  'brewery-fv37',
#  'brewery-fv38',
#  'brewery-fv39',
#  'brewery-fv40',
#  'brewery-fv41',
#  'brewery-fv42',
#  'brewery-fv43',
#  'brewery-fv44',
#  'brewery-fv45',
#  'brewery-fv46',
#  'brewery-loop.1',
#  'brewery-loop.2',
#  'brewery-pz1']

# %% [markdown]
# ## List of Data Views exclusive to Fermenter Vessel #32 (FV32)
#
# Empty filter (`filter=""`) allows to see all dataviews for the asset instead of simply the default one

# %%
dvs_fv32 = hub.asset_dataviews(asset="FV32", filter="")
dvs_fv32
# Out:
# ['brewery-fv32',
#  'brewery-fv32-adf_prediction',
#  'brewery-fv32-cooling_prediction',
#  'brewery-fv32-pca']

# %% [markdown]
# ## List Multi-Asset Data Views Containing FV32
#
# The column `Asset_Id` in data view results indicates which asset the row of data belongs to

# %%
hub.asset_dataviews(asset="FV32", multiple_asset=True, filter="")
# Out:
# ['brewery-fv31--36',
#  'brewery-fv31--36-adf_prediction',
#  'brewery-fv31--36-cooling_prediction',
#  'brewery-fv31--36-pca']

# %% [markdown]
# ## Get the OCS namespace associated to the dataset
#
# Each data set belongs to a namespace within the Academic Hub OCS account. Since dataset may move over time, the function below always return the active namespace for the given dataset.

# %%
dataset = hub.current_dataset()
namespace_id = hub.namespace_of(dataset)
namespace_id
# Out:
# 'academic_hub_01'

# %% [markdown]
# ## Get Data View structure
#
# With Stream Name, the column name under which stream data appears, its value type and engineering units if available. We display below the structure of the default data view.

# %%
dataview_id = hub.asset_dataviews(asset="FV32", filter="default")[0]
print(dataview_id)
hub.dataview_definition(namespace_id, dataview_id)
# Out:
# brewery-fv32
#    Asset_Id                         OCS_StreamName                DV_Column  \
# 0      FV32                      B2_CL_C2_FV32/ADF                      ADF
# 1      FV32                 B2_CL_C2_FV32/BRAND.CV                    Brand
# 2      FV32          B2_CL_C2_FV32/DcrsFvFullPlato            FV Full Plato
# 3      FV32                 B2_CL_C2_FV32/Diacetyl                 Diacetyl
# 4      FV32          B2_CL_C2_FV32/EndPhaseTime.CV           End Phase Time
# 5      FV32  B2_CL_C2_FV32/Fermentation_Start_Time  Fermentation Start Time
# 6      FV32           B2_CL_C2_FV32/Integrator Key           Integrator Key
# 7      FV32           B2_CL_C2_FV32/Phase Duration           Phase Duration
# 8      FV32                    B2_CL_C2_FV32/Plato                    Plato
# 9      FV32     B2_CL_C2_FV32/Predicted Transition     Predicted Transition
# 10     FV32     B2_CL_C2_FV32/Prediction.Deviation                Deviation
# 11     FV32                B2_CL_C2_FV32/STATUS.CV                   Status
# 12     FV32                 B2_CL_C2_FV32/VesselID                 VesselID
# 13     FV32          B2_CL_C2_FV32/VesselProcedure         Vessel Procedure
# 14     FV32                 B2_CL_C2_FV32/YEAST.CV             Yeast Strain
# 15     FV32              B2_CL_C2_FV32/YEASTGEN.CV         Yeast Generation
# 16     FV32        B2_CL_C2_FV32/YeastOutTotalizer      Yeast Out Totalizer
# 17     FV32        B2_CL_C2_FV32_FQ1380_A/TOTAL.CV                Volume In
# 18     FV32        B2_CL_C2_FV32_FQ1380_B/TOTAL.CV               Volume Out
# 19     FV32             B2_CL_C2_FV32_LT1380/PV.CV                   Volume
# 20     FV32           B2_CL_C2_FV32_PIC1382/OUT.CV                  PIC OUT
# 21     FV32            B2_CL_C2_FV32_PIC1382/PV.CV                   PIC PV
# 22     FV32            B2_CL_C2_FV32_PIC1382/SP.CV                   PIC SP
# 23     FV32          B2_CL_C2_FV32_TIC1380A/OUT.CV           Bottom TIC OUT
# 24     FV32           B2_CL_C2_FV32_TIC1380A/PV.CV            Bottom TIC PV
# 25     FV32           B2_CL_C2_FV32_TIC1380A/SP.CV            Bottom TIC SP
# 26     FV32          B2_CL_C2_FV32_TIC1380B/OUT.CV           Middle TIC OUT
# 27     FV32           B2_CL_C2_FV32_TIC1380B/PV.CV            Middle TIC PV
# 28     FV32           B2_CL_C2_FV32_TIC1380B/SP.CV            Middle TIC SP
# 29     FV32          B2_CL_C2_FV32_TIC1380C/OUT.CV              Top TIC OUT
# 30     FV32           B2_CL_C2_FV32_TIC1380C/PV.CV               Top TIC PV
# 31     FV32           B2_CL_C2_FV32_TIC1380C/SP.CV               Top TIC SP
#
#    Value_Type EngUnits
# 0       Float
# 1    Category
# 2       Float    Plato
# 3     Integer      ppb
# 4       Float        m
# 5   Timestamp
# 6       Float
# 7     Integer
# 8       Float    Plato
# 9      String
# 10      Float
# 11   Category
# 12    Integer
# 13     String
# 14   Category
# 15    Integer
# 16      Float
# 17      Float      bbl
# 18      Float      bbl
# 19      Float      bbl
# 20      Float        %
# 21      Float      psi
# 22      Float      psi
# 23      Float        %
# 24      Float      Â°F
# 25      Float      Â°F
# 26      Float        %
# 27      Float      Â°F
# 28      Float      Â°F
# 29      Float        %
# 30      Float      Â°F
# 31      Float      Â°F

# %% [markdown]
# ## Getting data from a Data View
#
# Return interpolated data between a start and end date, with the requested interpolation interval (format is HH:MM:SS)

# %%
df_fv32= hub.dataview_interpolated_pd(namespace_id, dataview_id, "2017-01-19", "2020-01-19", "00:30:00")
df_fv32
# Out:
# +++++++++++++++++++
#   ==> Finished 'dataview_interpolated_pd' in       64.9983 secs [ 809 rows/sec ]
#                 Timestamp Asset_Id       ADF  FV Full Plato  Diacetyl  \
# 0     2017-01-19 00:00:00     FV32  0.104108      13.506092       NaN
# 1     2017-01-19 00:30:00     FV32  0.104108      13.506092       NaN
# 2     2017-01-19 01:00:00     FV32  0.104108      13.506092       NaN
# 3     2017-01-19 01:30:00     FV32  0.104108      13.506092       NaN
# 4     2017-01-19 02:00:00     FV32  0.104108      13.506092       NaN
# ...                   ...      ...       ...            ...       ...
# 52556 2020-01-18 22:00:00     FV32  0.756629      16.295610      25.0
# 52557 2020-01-18 22:30:00     FV32  0.756629      16.295610      25.0
# 52558 2020-01-18 23:00:00     FV32  0.756629      16.295610      25.0
# 52559 2020-01-18 23:30:00     FV32  0.756629      16.295610      25.0
# 52560 2020-01-19 00:00:00     FV32  0.756629      16.295610      25.0
#
#        End Phase Time       Fermentation Start Time  Integrator Key  \
# 0                 NaN  2017-01-18T05:59:56.6180112Z        12.10000
# 1                 NaN  2017-01-18T05:59:56.6180112Z        12.10000
# 2                 NaN  2017-01-18T05:59:56.6180112Z        12.10000
# 3                 NaN  2017-01-18T05:59:56.6180112Z        12.10000
# 4                 NaN  2017-01-18T05:59:56.6180112Z        12.10000
# ...               ...                           ...             ...
# 52556          2880.0  2019-12-16T09:28:19.6750028Z         3.96588
# 52557          2880.0  2019-12-16T09:28:19.6750028Z         3.96588
# 52558          2880.0  2019-12-16T09:28:19.6750028Z         3.96588
# 52559          2880.0  2019-12-16T09:28:19.6750028Z         3.96588
# 52560          2880.0  2019-12-16T09:28:19.6750028Z         3.96588
#
#        Phase Duration     Plato  ... Bottom TIC SP  Middle TIC OUT  \
# 0                 NaN  12.10000  ...          63.0       17.355146
# 1                 NaN  12.10000  ...          63.0        7.568751
# 2                 NaN  12.10000  ...          63.0        4.256329
# 3                 NaN  12.10000  ...          63.0       17.092400
# 4                 NaN  12.10000  ...          63.0       46.463210
# ...               ...       ...  ...           ...             ...
# 52556          6803.0   3.96588  ...          30.0        6.131247
# 52557          6833.0   3.96588  ...          30.0        0.000000
# 52558          6863.0   3.96588  ...          30.0        0.000000
# 52559          6893.0   3.96588  ...          30.0        0.000000
# 52560          6923.0   3.96588  ...          30.0        0.000000
#
#        Middle TIC PV Middle TIC SP  Top TIC OUT  Top TIC PV  Top TIC SP  \
# 0          63.032608          63.0     8.699567   63.067005        63.0
# 1          63.035385          63.0    20.299335   63.055607        63.0
# 2          63.019897          63.0    46.984615   63.241917        63.0
# 3          63.079906          63.0    74.284065   63.305080        63.0
# 4          63.176716          63.0    42.702755   63.150780        63.0
# ...              ...           ...          ...         ...         ...
# 52556      30.028662          30.0     0.000000   29.951517        30.0
# 52557      29.966312          30.0    38.112650   30.199999        30.0
# 52558      30.089066          30.0    42.780502   30.199999        30.0
# 52559      30.011000          30.0    42.780502   30.199999        30.0
# 52560      29.922298          30.0    42.780502   30.199999        30.0
#
#                Brand             Status  Yeast Strain
# 0      Realtime Hops       Fermentation      NCYC1187
# 1      Realtime Hops       Fermentation      NCYC1187
# 2      Realtime Hops       Fermentation      NCYC1187
# 3      Realtime Hops       Fermentation      NCYC1187
# 4      Realtime Hops       Fermentation      NCYC1187
# ...              ...                ...           ...
# 52556     Trois Lacs  Ready to Transfer           a38
# 52557     Trois Lacs  Ready to Transfer           a38
# 52558     Trois Lacs  Ready to Transfer           a38
# 52559     Trois Lacs  Ready to Transfer           a38
# 52560     Trois Lacs  Ready to Transfer           a38
#
# [52561 rows x 34 columns]

# %%
# Information about the dataframe
df_fv32.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52561 entries, 0 to 52560
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                52561 non-null  datetime64[ns]
#  1   Asset_Id                 52561 non-null  object
#  2   ADF                      30540 non-null  float64
#  3   FV Full Plato            36987 non-null  float64
#  4   Diacetyl                 32934 non-null  float64
#  5   End Phase Time           37646 non-null  float64
#  6   Fermentation Start Time  44539 non-null  object
#  7   Integrator Key           51627 non-null  float64
#  8   Phase Duration           5244 non-null   float64
#  9   Plato                    34735 non-null  float64
#  10  Predicted Transition     16973 non-null  object
#  11  Deviation                21289 non-null  float64
#  12  VesselID                 52561 non-null  int64
#  13  Vessel Procedure         33063 non-null  object
#  14  Yeast Generation         52554 non-null  float64
#  15  Yeast Out Totalizer      22735 non-null  float64
#  16  Volume In                52551 non-null  float64
#  17  Volume Out               52551 non-null  float64
#  18  Volume                   52547 non-null  float64
#  19  PIC OUT                  52547 non-null  float64
#  20  PIC PV                   52550 non-null  float64
#  21  PIC SP                   52554 non-null  float64
#  22  Bottom TIC OUT           52547 non-null  float64
#  23  Bottom TIC PV            52547 non-null  float64
#  24  Bottom TIC SP            52551 non-null  float64
#  25  Middle TIC OUT           52547 non-null  float64
#  26  Middle TIC PV            52547 non-null  float64
#  27  Middle TIC SP            52551 non-null  float64
#  28  Top TIC OUT              52547 non-null  float64
#  29  Top TIC PV               52547 non-null  float64
#  30  Top TIC SP               52551 non-null  float64
#  31  Brand                    52561 non-null  object
#  32  Status                   52561 non-null  object
#  33  Yeast Strain             52561 non-null  object
# dtypes: datetime64[ns](1), float64(25), int64(1), object(7)
# memory usage: 13.6+ MB

# %% [markdown]
# ## Data Views with multiple assets
#
# Some Data Views return data for fermenter vessels 31 up to 36. Cell below is how to get their names.

# %%
multi_asset_dvs = hub.asset_dataviews(multiple_asset=True)
multi_asset_dvs
# Out:
# ['brewery-fv31--36']

# %% [markdown]
# ## Get result
#
# The column "Asset_Id" indicates which asset the data row belongs to. The data order is all data for FV31 in increasing time, followed by FV32 and so on up to FV36.

# %%
df_fv31_36 = hub.dataview_interpolated_pd(namespace_id, multi_asset_dvs[0], "2017-02-01", "2017-08-01", "00:10:00")
df_fv31_36
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#   ==> Finished 'dataview_interpolated_pd' in       67.9013 secs [ 2.30K rows/sec ]
#                  Timestamp Asset_Id       ADF  FV Full Plato  Diacetyl  \
# 0      2017-02-01 00:00:00     FV31  0.719046      17.084625      70.0
# 1      2017-02-01 00:10:00     FV31  0.719046      17.084625      70.0
# 2      2017-02-01 00:20:00     FV31  0.719046      17.084625      70.0
# 3      2017-02-01 00:30:00     FV31  0.719046      17.084625      70.0
# 4      2017-02-01 00:40:00     FV31  0.719046      17.084625      70.0
# ...                    ...      ...       ...            ...       ...
# 156385 2017-07-31 23:20:00     FV36  0.787345      17.026010      60.0
# 156386 2017-07-31 23:30:00     FV36  0.787345      17.026010      60.0
# 156387 2017-07-31 23:40:00     FV36  0.787345      17.026010      60.0
# 156388 2017-07-31 23:50:00     FV36  0.787345      17.026010      60.0
# 156389 2017-08-01 00:00:00     FV36  0.787345      17.026010      60.0
#
#         End Phase Time       Fermentation Start Time  Integrator Key  \
# 0                  NaN  2017-01-26T07:30:03.2369995Z            -1.0
# 1                  NaN  2017-01-26T07:30:03.2369995Z            -1.0
# 2                  NaN  2017-01-26T07:30:03.2369995Z            -1.0
# 3                  NaN  2017-01-26T07:30:03.2369995Z            -1.0
# 4                  NaN  2017-01-26T07:30:03.2369995Z            -1.0
# ...                ...                           ...             ...
# 156385             NaN  2017-07-25T00:43:17.1560056Z            60.0
# 156386             NaN  2017-07-25T00:43:17.1560056Z            60.0
# 156387             NaN  2017-07-25T00:43:17.1560056Z            60.0
# 156388             NaN  2017-07-25T00:43:17.1560056Z            60.0
# 156389             NaN  2017-07-25T00:43:17.1560056Z            60.0
#
#         Phase Duration    Plato  ...  Bottom TIC SP  Middle TIC OUT  \
# 0                  NaN  4.80000  ...           30.0           100.0
# 1                  NaN  4.80000  ...           30.0           100.0
# 2                  NaN  4.80000  ...           30.0           100.0
# 3                  NaN  4.80000  ...           30.0           100.0
# 4                  NaN  4.80000  ...           30.0           100.0
# ...                ...      ...  ...            ...             ...
# 156385             NaN  3.62067  ...           30.0           100.0
# 156386             NaN  3.62067  ...           30.0           100.0
# 156387             NaN  3.62067  ...           30.0           100.0
# 156388             NaN  3.62067  ...           30.0           100.0
# 156389             NaN  3.62067  ...           30.0           100.0
#
#         Middle TIC PV  Middle TIC SP  Top TIC OUT  Top TIC PV  Top TIC SP  \
# 0           53.798340           30.0        100.0   53.674717        30.0
# 1           53.607800           30.0        100.0   53.494137        30.0
# 2           53.483322           30.0        100.0   53.200000        30.0
# 3           53.009580           30.0        100.0   52.928270        30.0
# 4           52.899998           30.0        100.0   52.800003        30.0
# ...               ...            ...          ...         ...         ...
# 156385      40.500000           30.0        100.0   39.928513        30.0
# 156386      40.653477           30.0        100.0   39.853134        30.0
# 156387      40.390297           30.0        100.0   39.852184        30.0
# 156388      40.443350           30.0        100.0   39.700000        30.0
# 156389      40.323550           30.0        100.0   39.637337        30.0
#
#              Brand   Status  Yeast Strain
# 0       Grey Horse  Cooling      NCYC1187
# 1       Grey Horse  Cooling      NCYC1187
# 2       Grey Horse  Cooling      NCYC1187
# 3       Grey Horse  Cooling      NCYC1187
# 4       Grey Horse  Cooling      NCYC1187
# ...            ...      ...           ...
# 156385  Grey Horse  Cooling      NCYC1187
# 156386  Grey Horse  Cooling      NCYC1187
# 156387  Grey Horse  Cooling      NCYC1187
# 156388  Grey Horse  Cooling      NCYC1187
# 156389  Grey Horse  Cooling      NCYC1187
#
# [156390 rows x 34 columns]

# %%
df_fv31_36.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156390 entries, 0 to 156389
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                156390 non-null  datetime64[ns]
#  1   Asset_Id                 156390 non-null  object
#  2   ADF                      91764 non-null   float64
#  3   FV Full Plato            125435 non-null  float64
#  4   Diacetyl                 99260 non-null   float64
#  5   End Phase Time           0 non-null       float64
#  6   Fermentation Start Time  129216 non-null  object
#  7   Integrator Key           153709 non-null  float64
#  8   Phase Duration           0 non-null       float64
#  9   Plato                    96089 non-null   float64
#  10  Predicted Transition     0 non-null       float64
#  11  Deviation                0 non-null       float64
#  12  VesselID                 156390 non-null  int64
#  13  Vessel Procedure         0 non-null       float64
#  14  Yeast Generation         156360 non-null  float64
#  15  Yeast Out Totalizer      0 non-null       float64
#  16  Volume In                156336 non-null  float64
#  17  Volume Out               156336 non-null  float64
#  18  Volume                   156336 non-null  float64
#  19  PIC OUT                  156336 non-null  float64
#  20  PIC PV                   156322 non-null  float64
#  21  PIC SP                   156336 non-null  float64
#  22  Bottom TIC OUT           156336 non-null  float64
#  23  Bottom TIC PV            156336 non-null  float64
#  24  Bottom TIC SP            156336 non-null  float64
#  25  Middle TIC OUT           156336 non-null  float64
#  26  Middle TIC PV            156336 non-null  float64
#  27  Middle TIC SP            156336 non-null  float64
#  28  Top TIC OUT              156336 non-null  float64
#  29  Top TIC PV               156336 non-null  float64
#  30  Top TIC SP               156336 non-null  float64
#  31  Brand                    156390 non-null  object
#  32  Status                   156390 non-null  object
#  33  Yeast Strain             156390 non-null  object
# dtypes: datetime64[ns](1), float64(27), int64(1), object(5)
# memory usage: 40.6+ MB

# %% [markdown]
# ## Refresh datasets information
#
# When new datasets are published and/or existing ones are extended, you can access the updated information using `refresh_datasets`

# %%
hub.refresh_datasets()
# Out:
# @ Hub data file: hub_datasets.json
# @ Current dataset: Brewery
