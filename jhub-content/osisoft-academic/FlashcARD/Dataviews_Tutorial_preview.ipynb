# %% [markdown]
# # Dataviews with SDS: Introduction
#
# Dataviews allows data scientist to create and use table views which can be vary from simple like the ones in this notebook, to very elaborate.
#
# The dataset is from the Deschutes Brewery, with many fermentors which are the assets with the data of interest.
#
# This notebook shows the steps involved in creating and using Dataviews.
#
# ## Imports

# %%
# To run this notebook outside Academic JupyterHub: pip install requests-futures
# 
# For parallel HTTP requests
from concurrent.futures import ThreadPoolExecutor
from requests_futures.sessions import FuturesSession
import requests
# Pandas dataframe
import pandas as pd
import io, datetime, json
from random import randint
from enum import Enum

# %% [markdown]
# ## Tenant and client credentials
#
# ### NOTE: this info should be abstracted when we deploy for a course (TBD)

# %%
# Tenant is osisoft on production cluster, use your own credentials
tenant_id = 'd7847614-2e4a-4c1e-812b-e8de5fd06a0f'
client_id = 'ad48b3b2-cdf0-499e-9458-eb42a77edb85'  # input('client_id:')  # 
client_secret = '42cArto7tigc5ea5iJeNd9mjfQKQaXpph0EtiOlgyS0='  # input('client_secret:')  # 
resource_url = 'https://dat-b.osisoft.com'
namespace = 'beer_fermenters'
api_version = 'v1-preview'

# %% [markdown]
# ## Get an the autorization token and define the http for upcoming requests

# %%
# Request a fresh authorization bearer token 
discovery = requests.get(resource_url + '/identity/.well-known/openid-configuration', headers={'Accept': 'application/json'})
if discovery.status_code < 200 or discovery.status_code >= 300:
    raise Exception(f'Failed to get access token endpoint from discovery URL: {discovery.status_code}: {discovery.text}')
token_endpoint = discovery.json()['token_endpoint']
authorization = requests.post(token_endpoint, 
                              data={'client_id': client_id,
                                    'client_secret': client_secret,
                                    'grant_type': 'client_credentials',
                                   })

# %%
# Required headers for SDS endpoint
headers = {'Authorization': 'bearer %s' % authorization.json()['access_token'],
           'Content-type': 'application/json',
           'Accept': 'text/plain', 
           'Request-Timeout': '60000' }
headers
# Out:
# {'Authorization': 'bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjJDQjI4MzFEREJFRDc1NzAyM0NCMTM5OUVBRjRDMjkxQzE3MkQ5RjQiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJMTEtESGR2dGRYQWp5eE9aNnZUQ2tjRnkyZlEifQ..ULd2ctz1zXBn-EC8gy2naBCsTQS3ZSYkstQ5IKKtlw-BCiFJLTTPqmFd2N8AxdyxcdLXFrm1KqTJpHkmTNVABh3CwRGfHPW-g7t6hC9ew9mbEwIqGGCMlwPJIXfZKRPE1rTR9NVp1Lpiibn_xHrAOsJydiVTSHaekuCN0AwdmLZyDCJIubIjkm83u4htaWKNXpBgFVduSqrFYsWt1wRSVG7K3_8nrKMrbKniAdpifNBQxczBGo6MTz0sDFyfPEjBussnA_LNC6tioh5NWMAPTy_LR5FkSA9x4ETIAlwqooTKs9C3sLRpme5Ik0_8Iftk4NwBPP2-u9FRJ3BYx2avUw',
#  'Content-type': 'application/json',
#  'Accept': 'text/plain',
#  'Request-Timeout': '60000'}

# %% [markdown]
# ### Endpoint for namespace 'beer_fermenters' on production cluster

# %%
# Endpoint for dataview access
namespace_url = resource_url + f'/api/{api_version}/Tenants/{tenant_id}/Namespaces/{namespace}' 
endpoint = namespace_url + '/dataviews/'

# %% [markdown]
# ## All data streams of a fermentor, here Fermentor 31
# ### (16 in total, listed in alphabetical order)

# %%
streams_url = namespace_url + '/Streams?query=name:*FV31*'
print('Stream URL:', streams_url)
fv31_streams = requests.get(streams_url, headers=headers)
print(json.dumps(fv31_streams.json(), indent=4))
# Out:
# Stream URL: https://dat-b.osisoft.com/api/v1-preview/Tenants/d7847614-2e4a-4c1e-812b-e8de5fd06a0f/Namespaces/beer_fermenters/Streams?query=name:*FV31*
# [
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2592",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV",
#         "Description": "FV31 Bottom Temperature Control Output"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2598",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV",
#         "Description": "FV31 Brand",
#         "InterpolationMode": 1
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2639",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/SP.CV",
#         "Description": "FV31 Pressure Control Setpoint"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2968",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/YEAST.CV",
#         "Description": "FV31 Yeast"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2594",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/SP.CV",
#         "Description": "FV31 Bottom Temperature Control Setpoint"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2624",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV",
#         "Description": "FV31 Middle Temperature Control Value"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2638",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/PV.CV",
#         "Description": "FV31 Pressure Control Value"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2934",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/HARVEST.CV",
#         "Description": "FV31 Yeast Harvest Complete Indicator"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2619",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV",
#         "Description": "FV31 Middle Temperature Control Output"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2792",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV",
#         "Description": "FV31  Level Accumulator",
#         "InterpolationMode": 1
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2635",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/SP.CV",
#         "Description": "FV31 Middle Temperature Control Setpoint"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2661",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV",
#         "Description": "FV31 Status",
#         "InterpolationMode": 1
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2951",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/PCD.CV",
#         "Description": "FV31 Yeast Pre-Centrifuge Disposal Complete Indicator"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2614",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato",
#         "Description": "The DCRS Calculated FV Full Plato of FV31"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2926",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/PULLSP.CV",
#         "Description": "FV31 Yeast Cooling Disposal Ready Indicator"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2907",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/PULL.CV",
#         "Description": "FV31 Yeast Cooling Disposal Complete Indicator"
#     },
#     {
#         "TypeId": "PIInt16",
#         "Id": "PI_acad-pida-vm0_2797",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/YEASTGEN.CV",
#         "Description": "FV31 Yeast Generation"
#     },
#     {
#         "TypeId": "PIString",
#         "Id": "PI_acad-pida-vm0_2606",
#         "Name": "acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1",
#         "Description": "",
#         "InterpolationMode": 1
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2781",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV",
#         "Description": "FV31 Top Temperature Control Value"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2805",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/T90PULL.CV",
#         "Description": "FV31 T90 Disposal Complete Indicator"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2593",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV",
#         "Description": "FV31 Bottom Temperature Control Value"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2636",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/OUT.CV",
#         "Description": "FV31 Pressure Control Output"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2640",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/Plato",
#         "Description": "The specific gravity in plato of FV31"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2959",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/PCDSP.CV",
#         "Description": "FV31 Yeast Pre-Centrifuge Disposal Ready Indicator"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2791",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/SP.CV",
#         "Description": "FV31 Top Temperature Control Setpoint"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2772",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV",
#         "Description": "FV31 Top Temperature Control Output"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2795",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_FQ1360_B/TOTAL.CV",
#         "Description": "FV31 Flow Totalizer Out"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_2794",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31_FQ1360_A/TOTAL.CV",
#         "Description": "FV31 Flow Totalizer In"
#     },
#     {
#         "TypeId": "PIFloat32",
#         "Id": "PI_acad-pida-vm0_3002",
#         "Name": "acsbrew.BREWERY.B3.FV31.24h Availability",
#         "Description": "FV31 24h availability"
#     },
#     {
#         "TypeId": "PIInt16",
#         "Id": "PI_acad-pida-vm0_3011",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag",
#         "Description": "FV31 Batch Active Tag"
#     },
#     {
#         "TypeId": "PIDigital",
#         "Id": "PI_acad-pida-vm0_2863",
#         "Name": "acsbrew.BREWERY.B2_CL_C2_FV31/T90PULLSP.CV",
#         "Description": "FV31 T90 Disposal Ready Indicator"
#     }
# ]

# %%
streams = [stream['Name'] for stream in fv31_streams.json()]
streams
# Out:
# ['acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/SP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/YEAST.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/SP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/HARVEST.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/SP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/PCD.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/PULLSP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/PULL.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/YEASTGEN.CV',
#  'acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/T90PULL.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/OUT.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/Plato',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/PCDSP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/SP.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_FQ1360_B/TOTAL.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_FQ1360_A/TOTAL.CV',
#  'acsbrew.BREWERY.B3.FV31.24h Availability',
#  'acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag',
#  'acsbrew.BREWERY.B2_CL_C2_FV31/T90PULLSP.CV']

# %% [markdown]
# | Stream Name | DV Column Name | Description |
# |-------------|----------------|-------------|
# | acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV | `Brand` | Vessel Brand
# | acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1 | `Fermentation ID` | Unique ID for fermentation batch
# | acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV | `Status` | * Vessel Status
# | acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato | `FV Full Plato` | The specific gravity of the vessel in plato at the end of filling
# | acsbrew.BREWERY.B2_CL_C2_FV31/Plato | `Plato` | The specific gravity of the vessel in plato
# | acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV | `Volume` | * Vessel Volume
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV |`Bottom TIC OUT` | * Vessel Bottom Temperature Indicator Controller Output
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV | `Bottom TIC PV` | * Vessel Bottom Temperture Indicator Controller Process Value
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV | `Middle TIC OUT` | * Vessel Middle Temperature Indicator Controller Output
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV | `Middle TIC PV` | * Vessel Middle Temperture Indicator Controller Process Value
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV | `Top TIC OUT` | * Vessel Top Temperature Indicator Controller Output
# | acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV | `Top TIC PV` | * Vessel Bottom Temperture Indicator Controller Process Value

# %%
bottom_out = [s for s in outcv_streams if 'A/' in s][0]
bottom_out
# Out:
# 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV'

# %%
class Pos(Enum):
    bottom = 1
    middle = 2
    top = 3

stream_key = {Pos.bottom: 'A/', Pos.middle: 'B/', Pos.top: 'C/'}
tic_out_streams = [s for s in streams if 'OUT.CV' in s]
tic_out_tags = { p: next(s for s in tic_out_streams if stream_key[p] in s) for p in Pos }
tic_out_tags
# Out:
# {<Pos.bottom: 1>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV',
#  <Pos.middle: 2>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV',
#  <Pos.top: 3>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV'}

# %%
tic_pv_streams = [s for s in streams if 'PV.CV' in s]
tic_pv_tags = { p: next(s for s in tic_pv_streams if stream_key[p] in s) for p in Pos }
tic_pv_tags
# Out:
# {<Pos.bottom: 1>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV',
#  <Pos.middle: 2>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV',
#  <Pos.top: 3>: 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV'}

# %%
ticpv_streams = [s for s in streams if 'PV.CV' in s]
ticpv_streams
# Out:
# ['acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_PIC1362/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV',
#  'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV']

# %%
[p.name for p in Pos]
# Out:
# ['bottom', 'middle', 'top']

# %%
tic_out_map = [ (stream_key[p] + 'OUT.CV', p.name.capitalize() + ' TIC OUT') for p in Pos]
tic_out_map
# Out:
# [('A/OUT.CV', 'Bottom TIC OUT'),
#  ('B/OUT.CV', 'Middle TIC OUT'),
#  ('C/OUT.CV', 'Top TIC OUT')]

# %%
pm.bound.reset()
[ (s, m[1]) for s in streams for m in tic_out_map if pm.match(s, pm.anything + m[0])]
# Out:
# [('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV', 'Bottom TIC OUT'),
#  ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV', 'Middle TIC OUT'),
#  ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV', 'Top TIC OUT')]

# %%
tic_pv_map = [ (stream_key[p] + 'PV.CV', p.name.capitalize() + ' TIC PV') for p in Pos]
tic_pv_map
# Out:
# [('A/PV.CV', 'Bottom TIC PV'),
#  ('B/PV.CV', 'Middle TIC PV'),
#  ('C/PV.CV', 'Top TIC PV')]

# %%
[ (s, m[1]) for s in streams for m in tic_pv_map if pm.match(s, pm.anything + m[0])]
# Out:
# [('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV', 'Middle TIC PV'),
#  ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV', 'Top TIC PV'),
#  ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV', 'Bottom TIC PV')]

# %%
rest_map = [
    ('_LT', 'Volume'),
    ('BRAND', 'Brand'),
    ('STATUS', 'Status'),
    ('FullPlato', 'FV Full Plato'),
    ('/Plato', 'Plato'),
    ('Fermentation ID', 'Fermentation ID')
]
rest_map
# Out:
# [('_LT', 'Volume'),
#  ('BRAND', 'Brand'),
#  ('STATUS', 'Status'),
#  ('FullPlato', 'FV Full Plato'),
#  ('/Plato', 'Plato'),
#  ('Fermentation ID', 'Fermentation ID')]

# %%
full_map = [
    ('_LT', 'Volume'),
    ('C/PV.CV', 'Top TIC PV'),
    ('C/OUT.CV', 'Top TIC OUT'),
    ('STATUS', 'Status'),
    ('/Plato', 'Plato'),
    ('B/PV.CV', 'Middle TIC PV'),
    ('B/OUT.CV', 'Middle TIC OUT'),
    ('FullPlato', 'FV Full Plato'),
    ('Fermentation ID', 'Fermentation ID'),
    ('BRAND', 'Brand'),
    ('A/PV.CV', 'Bottom TIC PV'),
    ('A/OUT.CV', 'Bottom TIC OUT'),
]

# %%
# full_map = tic_out_map + tic_pv_map + rest_map
[i for i in enumerate(full_map)]
# Out:
# [(0, ('_LT', 'Volume')),
#  (1, ('C/PV.CV', 'Top TIC PV')),
#  (2, ('C/OUT.CV', 'Top TIC OUT')),
#  (3, ('STATUS', 'Status')),
#  (4, ('/Plato', 'Plato')),
#  (5, ('B/PV.CV', 'Middle TIC PV')),
#  (6, ('B/OUT.CV', 'Middle TIC OUT')),
#  (7, ('FullPlato', 'FV Full Plato')),
#  (8, ('Fermentation ID', 'Fermentation ID')),
#  (9, ('BRAND', 'Brand')),
#  (10, ('A/PV.CV', 'Bottom TIC PV')),
#  (11, ('A/OUT.CV', 'Bottom TIC OUT'))]

# %%
dv_names = [ (s, m[1]) for m in full_map for s in streams if m[0] in s ]
[i for i in enumerate(dv_names)]
# Out:
# [(0, ('acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV', 'Volume')),
#  (1, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV', 'Top TIC PV')),
#  (2, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV', 'Top TIC OUT')),
#  (3, ('acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV', 'Status')),
#  (4, ('acsbrew.BREWERY.B2_CL_C2_FV31/Plato', 'Plato')),
#  (5, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV', 'Middle TIC PV')),
#  (6, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV', 'Middle TIC OUT')),
#  (7, ('acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato', 'FV Full Plato')),
#  (8,
#   ('acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1',
#    'Fermentation ID')),
#  (9, ('acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV', 'Brand')),
#  (10, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV', 'Bottom TIC PV')),
#  (11, ('acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV', 'Bottom TIC OUT'))]

# %%
'''
{
	"Id": "CDV7_FV31",
	"Name": "CDV7_FV31",
	"Description": "Fermenter dataview",
	"Queries": [
		{
			"Id": "Fermentor",
			"Query": {
				"Resource": "Streams",
				"Field": "Description",
				"Value": "FV31",
				"Operator": "Contains"
			}
		}
	],
	"GroupRules": [],
	"Mappings": {
		"Columns": [
			{
				"Name": "Timestamp",
				"MappingRule": {
					"PropertyPaths": [
						"Timestamp"
					]
				},
				"IsKey": true,
				"DataType": "DateTime"
			},
            
            ############## Columns ################## e.g.
            
            {
				"Name": "Bottom TIC OUT",
				"MappingRule": {
					"PropertyPaths": [
						"Value"
					],
					"ItemIdentifier": {
						"Resource": "Streams",
						"Field": "Name",
						"Value": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV",
						"Operator": "Equals"
					}
				},
				"IsKey": false
			}
	]
	},
	"IndexDataType": "DateTime",
	"IndexConfig": {
		"StartIndex": "2017-03-17T07:00:00Z",
		"EndIndex": "2017-03-18T07:00:00Z",
		"Mode": "Interpolated",
		"Interval": "00:01:00"
	}
}
'''
# Out:
# '\n{\n\t"Id": "CDV7_FV31",\n\t"Name": "CDV7_FV31",\n\t"Description": "Fermenter dataview",\n\t"Queries": [\n\t\t{\n\t\t\t"Id": "Fermentor",\n\t\t\t"Query": {\n\t\t\t\t"Resource": "Streams",\n\t\t\t\t"Field": "Description",\n\t\t\t\t"Value": "FV31",\n\t\t\t\t"Operator": "Contains"\n\t\t\t}\n\t\t}\n\t],\n\t"GroupRules": [],\n\t"Mappings": {\n\t\t"Columns": [\n\t\t\t{\n\t\t\t\t"Name": "Timestamp",\n\t\t\t\t"MappingRule": {\n\t\t\t\t\t"PropertyPaths": [\n\t\t\t\t\t\t"Timestamp"\n\t\t\t\t\t]\n\t\t\t\t},\n\t\t\t\t"IsKey": true,\n\t\t\t\t"DataType": "DateTime"\n\t\t\t},\n            \n            ############## Columns ################## e.g.\n            \n            {\n\t\t\t\t"Name": "Bottom TIC OUT",\n\t\t\t\t"MappingRule": {\n\t\t\t\t\t"PropertyPaths": [\n\t\t\t\t\t\t"Value"\n\t\t\t\t\t],\n\t\t\t\t\t"ItemIdentifier": {\n\t\t\t\t\t\t"Resource": "Streams",\n\t\t\t\t\t\t"Field": "Name",\n\t\t\t\t\t\t"Value": "acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV",\n\t\t\t\t\t\t"Operator": "Equals"\n\t\t\t\t\t}\n\t\t\t\t},\n\t\t\t\t"IsKey": false\n\t\t\t}\n\t]\n\t},\n\t"IndexDataType": "DateTime",\n\t"IndexConfig": {\n\t\t"StartIndex": "2017-03-17T07:00:00Z",\n\t\t"EndIndex": "2017-03-18T07:00:00Z",\n\t\t"Mode": "Interpolated",\n\t\t"Interval": "00:01:00"\n\t}\n}\n'

# %%
true = True
false = False
def generate_time_column():
    return [ {
                "Name": "Timestamp",
                "MappingRule": {
                    "PropertyPaths": [
                        "Timestamp"
                    ]
                },
                "IsKey": true,
                "DataType": "DateTime"
            } ]

# %%
def generate_column_def(column_def):
    name = column_def[1]
    tag = column_def[0]
    return {
        "Name": name,
        "MappingRule": {
            "PropertyPaths": [
                "Value"
            ],
            "ItemIdentifier": {
                "Resource": "Streams",
                "Field": "Name",
                "Value": tag,
                "Operator": "Equals"
            }
        }
    }
generate_column_def(('TAGNAME', 'COLUMN_NAME'))
# Out:
# {'Name': 'COLUMN_NAME',
#  'MappingRule': {'PropertyPaths': ['Value'],
#   'ItemIdentifier': {'Resource': 'Streams',
#    'Field': 'Name',
#    'Value': 'TAGNAME',
#    'Operator': 'Equals'}}}

# %%
def generate_column_mappings(): 
    return { "Columns": 
                generate_time_column() + 
                [generate_column_def(c) for c in dv_names]
           }
generate_column_mappings()
# Out:
# {'Columns': [{'Name': 'Timestamp',
#    'MappingRule': {'PropertyPaths': ['Timestamp']},
#    'IsKey': True,
#    'DataType': 'DateTime'},
#   {'Name': 'Volume',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Top TIC PV',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Top TIC OUT',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Status',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Plato',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/Plato',
#      'Operator': 'Equals'}}},
#   {'Name': 'Middle TIC PV',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Middle TIC OUT',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'FV Full Plato',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato',
#      'Operator': 'Equals'}}},
#   {'Name': 'Fermentation ID',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1',
#      'Operator': 'Equals'}}},
#   {'Name': 'Brand',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Bottom TIC PV',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV',
#      'Operator': 'Equals'}}},
#   {'Name': 'Bottom TIC OUT',
#    'MappingRule': {'PropertyPaths': ['Value'],
#     'ItemIdentifier': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV',
#      'Operator': 'Equals'}}}]}

# %%
version = 10
def generate_dataview_def(ferm_id):
    dataview_id = f'TestDV{version}_FV{ferm_id}'
    return dataview_id, {
    "Id": dataview_id, 
    "Name": dataview_id, 
    "Description": f'Fermentor {ferm_id} DV',
    "Queries": [
        {
            "Id": "Fermentor",
            "Query": {
                "Resource": "Streams",
                "Field": "Name",
                "Value": "FV31",
                "Operator": "Contains"
            }
        }
    ],
    "GroupRules": [],
    "Mappings": generate_column_mappings(),
    "IndexDataType": "DateTime",
    "IndexConfig": {
        "StartIndex": "2017-03-17T07:00:00Z",
        "EndIndex": "2017-03-18T07:00:00Z",
        "Mode": "Interpolated",
        "Interval": "00:01:00"
    }
    }

# %%
generate_dataview_def(31)
# Out:
# ('TestDV10_FV31',
#  {'Id': 'TestDV10_FV31',
#   'Name': 'TestDV10_FV31',
#   'Description': 'Fermentor 31 DV',
#   'Queries': [{'Id': 'Fermentor',
#     'Query': {'Resource': 'Streams',
#      'Field': 'Name',
#      'Value': 'FV31',
#      'Operator': 'Contains'}}],
#   'GroupRules': [],
#   'Mappings': {'Columns': [{'Name': 'Timestamp',
#      'MappingRule': {'PropertyPaths': ['Timestamp']},
#      'IsKey': True,
#      'DataType': 'DateTime'},
#     {'Name': 'Volume',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Top TIC PV',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Top TIC OUT',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Status',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Plato',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/Plato',
#        'Operator': 'Equals'}}},
#     {'Name': 'Middle TIC PV',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Middle TIC OUT',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'FV Full Plato',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato',
#        'Operator': 'Equals'}}},
#     {'Name': 'Fermentation ID',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1',
#        'Operator': 'Equals'}}},
#     {'Name': 'Brand',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Bottom TIC PV',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV',
#        'Operator': 'Equals'}}},
#     {'Name': 'Bottom TIC OUT',
#      'MappingRule': {'PropertyPaths': ['Value'],
#       'ItemIdentifier': {'Resource': 'Streams',
#        'Field': 'Name',
#        'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV',
#        'Operator': 'Equals'}}}]},
#   'IndexDataType': 'DateTime',
#   'IndexConfig': {'StartIndex': '2017-03-17T07:00:00Z',
#    'EndIndex': '2017-03-18T07:00:00Z',
#    'Mode': 'Interpolated',
#    'Interval': '00:01:00'}})

# %% [markdown]
# ## NOTE: There are more values for Fermentor 31 (29 instead of 17) because the filter for Bifrost was on tag instead of AF structure which obviously didn't map all available on the Data Archive. But we don't want to filter out the extra data at this point, we can do it later on the dataframe itself.

# %% [markdown]
# ## Generate JSON for a Dataview
#
# **TODO**: Documentation for dataview available at: TBD
#
# #### Function `generate_dataview_def` returns a pair: Dataview Id and Dataview JSON body definition.
#
# #### The Dataview is built to return:
# * all data of Fermentor #`ferm_id` as rows
# * each stream of the fermentor becomes a column _without the_ `Fermentor 3x` _prefix_ (important for dataframe concatenation)
# * with data starting on UTC time `2017-03-18T00:00:00Z` up to 2017-03-19T00:00:00Z (1 day)
# * with data interpolated at 1 minute (00:01:00) interval
#
# ## BELOW IS THE NEW DATAFRAME

# %%
dv_id, dv_def = generate_dataview_def(31)   
dv_url = namespace_url + f'/Dataviews/{dv_id}'
print('DV URL:', dv_url)
r = requests.post(dv_url, json=dv_def, headers=headers)
print(r.status_code, r.text)
# df = pd.read_csv(io.StringIO(r.text), parse_dates=['Timestamp'])
# Out:
# DV URL: https://dat-b.osisoft.com/api/v1-preview/Tenants/d7847614-2e4a-4c1e-812b-e8de5fd06a0f/Namespaces/beer_fermenters/Dataviews/TestDV10_FV31
# 201 {"Id":"TestDV10_FV31","Name":"TestDV10_FV31","Description":"Fermentor 31 DV","Queries":[{"Id":"Fermentor","Query":{"Resource":"Streams","Field":"Name","Value":"FV31","Operator":"Contains"}}],"GroupRules":[],"Mappings":{"Columns":[{"Name":"Timestamp","MappingRule":{"PropertyPaths":["Timestamp"]},"IsKey":true,"DataType":"DateTime"},{"Name":"Volume","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV","Operator":"Equals"}}},{"Name":"Top TIC PV","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV","Operator":"Equals"}}},{"Name":"Top TIC OUT","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV","Operator":"Equals"}}},{"Name":"Status","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV","Operator":"Equals"}}},{"Name":"Plato","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31/Plato","Operator":"Equals"}}},{"Name":"Middle TIC PV","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV","Operator":"Equals"}}},{"Name":"Middle TIC OUT","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV","Operator":"Equals"}}},{"Name":"FV Full Plato","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato","Operator":"Equals"}}},{"Name":"Fermentation ID","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1","Operator":"Equals"}}},{"Name":"Brand","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV","Operator":"Equals"}}},{"Name":"Bottom TIC PV","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV","Operator":"Equals"}}},{"Name":"Bottom TIC OUT","MappingRule":{"PropertyPaths":["Value"],"ItemIdentifier":{"Resource":"Streams","Field":"Name","Value":"acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV","Operator":"Equals"}}}]},"IndexDataType":"DateTime","IndexConfig":{"StartIndex":"2017-03-17T07:00:00Z","EndIndex":"2017-03-18T07:00:00Z","Mode":"Interpolated","Interval":"00:01:00"}}

# %% [markdown]
# ## Creation of the Dataviews, for fermenters 31 up to 36
#
# * Status 201 from POST request indicates success
# * Status 401 indicates unauthorized (try refreshing authorization header)
# * Status 409 when a Dataview with same Id already exists (go to last cell of this notebook to perform a clean up)

# %%
dataviews = []
for ferm_id in range(31, 32):  # ONLY FERMENTER 31 FOR TESTING
    dataview_name, dataview_def = generate_dataview_def(ferm_id)
    print(dataview_def)
    dataviews.append(dataview_name)
    response = requests.post(endpoint + dataview_name, headers=headers, json=dataview_def)
    print('Status:', response.status_code, dataview_name, response.text)
# Out:
# {'Id': 'TestDV10_FV31', 'Name': 'TestDV10_FV31', 'Description': 'Fermentor 31 DV', 'Queries': [{'Id': 'Fermentor', 'Query': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'FV31', 'Operator': 'Contains'}}], 'GroupRules': [], 'Mappings': {'Columns': [{'Name': 'Timestamp', 'MappingRule': {'PropertyPaths': ['Timestamp']}, 'IsKey': True, 'DataType': 'DateTime'}, {'Name': 'Volume', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_LT1360/PV.CV', 'Operator': 'Equals'}}}, {'Name': 'Top TIC PV', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/PV.CV', 'Operator': 'Equals'}}}, {'Name': 'Top TIC OUT', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360C/OUT.CV', 'Operator': 'Equals'}}}, {'Name': 'Status', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/STATUS.CV', 'Operator': 'Equals'}}}, {'Name': 'Plato', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/Plato', 'Operator': 'Equals'}}}, {'Name': 'Middle TIC PV', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/PV.CV', 'Operator': 'Equals'}}}, {'Name': 'Middle TIC OUT', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360B/OUT.CV', 'Operator': 'Equals'}}}, {'Name': 'FV Full Plato', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/DcrsFvFullPlato', 'Operator': 'Equals'}}}, {'Name': 'Fermentation ID', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.FV31.Fermentation ID.194fa814-869f-5f35-3501-0b9198ac52e1', 'Operator': 'Equals'}}}, {'Name': 'Brand', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31/BRAND.CV', 'Operator': 'Equals'}}}, {'Name': 'Bottom TIC PV', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/PV.CV', 'Operator': 'Equals'}}}, {'Name': 'Bottom TIC OUT', 'MappingRule': {'PropertyPaths': ['Value'], 'ItemIdentifier': {'Resource': 'Streams', 'Field': 'Name', 'Value': 'acsbrew.BREWERY.B2_CL_C2_FV31_TIC1360A/OUT.CV', 'Operator': 'Equals'}}}]}, 'IndexDataType': 'DateTime', 'IndexConfig': {'StartIndex': '2017-03-17T07:00:00Z', 'EndIndex': '2017-03-18T07:00:00Z', 'Mode': 'Interpolated', 'Interval': '00:01:00'}}
# Status: 409 TestDV10_FV31 {"OperationId":"1a88a6cb-a6a2-4405-923a-c452c4ccaaa9","Error":"Data view with specified id already exists.","DataViewId":"TestDV10_FV31"}

# %% [markdown]
# ## List of Dataviews URLs

# %%
# We want 20 days of data worth at 1 minute interval, for fermenter 31 up to 36
dataviews_url = [endpoint + '%s/preview/interpolated?form=csvh&maxcount=2000' % d for d in dataviews]
dataviews_url
# Out:
# ['https://dat-b.osisoft.com/api/v1-preview/Tenants/d7847614-2e4a-4c1e-812b-e8de5fd06a0f/Namespaces/beer_fermenters/dataviews/TestDV10_FV31/preview/interpolated?form=csvh&maxcount=2000']

# %% [markdown]
# ## From a list of dataviews, gather them in parallel and return a single dataframe

# %%
def postproc(reply):
    s = io.StringIO(reply)
    # 255 Bad Input, 307 Bad, 313 Comm Fail, 246 I/O Timeout, 
    # print('Line 1:', s.readline())
    # print('Line 2:', s.readline())
    s.close()
    return reply 

# Request in parallel all the dataviews, return the concatenated dataframe
def get_ocs_dataframe(dataviews, headers, workers=8):
    ti = datetime.datetime.now()
    session = FuturesSession(executor=ThreadPoolExecutor(max_workers=workers))
    rs = [session.get(u, headers=headers, params={'count': '10000'}) for u in dataviews]
    resps = [r.result() for r in rs]
    print('Requests completed in', datetime.datetime.now() - ti) 
    print(resps)
    dfs = [pd.read_csv(io.StringIO(postproc(r.text)), parse_dates=['Timestamp']) for r in resps]
    return(pd.concat(dfs, sort=True))

# %% [markdown]
# ## Get dataframe and time it (about 20 seconds, be patient)
#
# All responses should HTTP code [200] if everything is ok

# %%
t0 = datetime.datetime.now()
df = get_ocs_dataframe(dataviews_url, headers)
print('Dataframe obtained in', datetime.datetime.now() - t0) 
df.info
# Out:
# Requests completed in 0:00:00.903322
# [<Response [200]>]
# Line 1: Timestamp,Volume,Top TIC PV,Top TIC OUT,Status,Plato,Middle TIC PV,Middle TIC OUT,FV Full Plato,Fermentation ID,Brand,Bottom TIC PV,Bottom TIC OUT
#
# Line 2: 2017-03-17T07:00:00Z,716.566,29.6131516,0,Maturation,168.919174,29.35638,0,171.893845,Fermentor 31201731179653,Kerberos,29.8845711,10.9353266
#
# Dataframe obtained in 0:00:00.922018
# <bound method DataFrame.info of       Bottom TIC OUT  Bottom TIC PV     Brand  FV Full Plato  \
# 0          10.935327      29.884571  Kerberos     171.893845
# 1          12.445787      29.931492  Kerberos     172.065735
# 2          13.956246      29.978569  Kerberos     172.237610
# 3          18.254084      30.033358  Kerberos     172.409500
# 4          25.958717      30.083404  Kerberos     172.581375
# 5          33.663350      30.133188  Kerberos     172.753265
# 6          41.367980      30.193794  Kerberos     172.925156
# 7          45.145805      30.191100  Kerberos     173.097031
# 8          48.042100      30.184795  Kerberos     173.268921
# 9          50.938390      30.179586  Kerberos     173.440811
# 10         53.834682      30.172728  Kerberos     173.612686
# 11         56.730976      30.165604  Kerberos     173.784576
# 12         55.699925      30.159050  Kerberos     173.956451
# 13         50.994907      30.152640  Kerberos     174.128342
# 14         46.289887      30.147348  Kerberos     174.300232
# 15         41.584870      30.140123  Kerberos     174.472100
# 16         36.879850      30.133460  Kerberos     174.644000
# 17         34.620860      30.127207  Kerberos     174.815887
# 18         33.328910      30.120590  Kerberos     174.987762
# 19         32.036960      30.115482  Kerberos     175.159653
# 20         30.745012      30.107770  Kerberos     175.331528
# 21         29.453062      30.092520  Kerberos     175.503418
# 22         26.857450      29.900700  Kerberos     175.675308
# 23         23.746439      29.933490  Kerberos     175.847183
# 24         20.635426      29.966340  Kerberos     176.019073
# 25         17.524414      29.999070  Kerberos     176.190964
# 26         14.413403      30.021904  Kerberos     176.362839
# 27         15.011147      30.064660  Kerberos     176.534729
# 28         16.536083      30.097450  Kerberos     176.706600
# 29         18.061018      30.084545  Kerberos     176.878500
# ...              ...            ...       ...            ...
# 1411       10.429822      30.031033  Kerberos      14.694010
# 1412        9.732054      30.057007  Kerberos      14.694010
# 1413        9.117924      30.056053  Kerberos      14.694010
# 1414        8.503794      30.030037  Kerberos      14.694010
# 1415        7.889663      30.067833  Kerberos      14.694010
# 1416        7.275533      30.054367  Kerberos      14.694010
# 1417        8.727330      30.081222  Kerberos      14.694010
# 1418       10.642908      30.070135  Kerberos      14.694010
# 1419       12.558485      30.072443  Kerberos      14.694010
# 1420       14.474063      30.042864  Kerberos      14.694010
# 1421       16.389640      30.022707  Kerberos      14.694010
# 1422       16.735737      30.027874  Kerberos      14.694010
# 1423       15.797715      30.018633  Kerberos      14.694010
# 1424       14.859692      30.052801  Kerberos      14.694010
# 1425       13.921669      30.028696  Kerberos      14.694010
# 1426       12.983646      30.069847  Kerberos      14.694010
# 1427       13.164211      30.004540  Kerberos      14.694010
# 1428       13.568493      30.069174  Kerberos      14.694010
# 1429       13.972776      30.079031  Kerberos      14.694010
# 1430       14.377057      30.018692  Kerberos      14.694010
# 1431       14.781340      30.067864  Kerberos      14.694010
# 1432       15.542957      30.028740  Kerberos      14.694010
# 1433       16.376041      30.085390  Kerberos      14.694010
# 1434       17.209125      30.027657  Kerberos      14.694010
# 1435       18.042212      30.053333  Kerberos      14.694010
# 1436       18.875296      30.088318  Kerberos      14.694010
# 1437       18.119314      30.050882  Kerberos      14.694010
# 1438       17.279697      30.014872  Kerberos      14.694010
# 1439       16.440080      30.084675  Kerberos      14.694010
# 1440       15.600465      30.012844  Kerberos      14.694010
#
#                Fermentation ID  Middle TIC OUT  Middle TIC PV       Plato  \
# 0     Fermentor 31201731179653        0.000000      29.356380  168.919174
# 1     Fermentor 31201731179653        0.000000      29.378868  169.098100
# 2     Fermentor 31201731179653        0.000000      29.400892  169.277023
# 3     Fermentor 31201731179653        0.000000      29.423298  169.455948
# 4     Fermentor 31201731179653        0.000000      29.440790  169.634872
# 5     Fermentor 31201731179653        0.000000      29.458190  169.813800
# 6     Fermentor 31201731179653        0.000000      29.489014  169.992722
# 7     Fermentor 31201731179653        0.000000      29.432340  170.171646
# 8     Fermentor 31201731179653        0.000000      29.416090  170.350571
# 9     Fermentor 31201731179653        0.000000      29.429405  170.529500
# 10    Fermentor 31201731179653        0.000000      29.433302  170.708420
# 11    Fermentor 31201731179653        0.000000      29.437784  170.887344
# 12    Fermentor 31201731179653        0.000000      29.459850  171.066269
# 13    Fermentor 31201731179653        0.000000      29.496010  171.245200
# 14    Fermentor 31201731179653        0.000000      29.494457  171.424118
# 15    Fermentor 31201731179653        0.000000      29.487812  171.603043
# 16    Fermentor 31201731179653        0.000000      29.474813  171.781967
# 17    Fermentor 31201731179653        0.000000      29.462631  171.960892
# 18    Fermentor 31201731179653        0.000000      29.449730  172.139832
# 19    Fermentor 31201731179653        0.000000      29.439764  172.318756
# 20    Fermentor 31201731179653        0.000000      29.424730  172.497681
# 21    Fermentor 31201731179653        0.000000      29.416422  172.676600
# 22    Fermentor 31201731179653        0.000000      29.400710  172.855530
# 23    Fermentor 31201731179653        0.000000      29.434050  173.034454
# 24    Fermentor 31201731179653        0.000000      29.467443  173.213379
# 25    Fermentor 31201731179653        0.000000      29.500720  173.392300
# 26    Fermentor 31201731179653        0.000000      29.523935  173.571228
# 27    Fermentor 31201731179653        0.000000      29.567390  173.750153
# 28    Fermentor 31201731179653        0.000000      29.533970  173.929077
# 29    Fermentor 31201731179653        0.000000      29.560633  174.108000
# ...                        ...             ...            ...         ...
# 1411  Fermentor 31201731179653        0.000000      29.925835    5.000000
# 1412  Fermentor 31201731179653        0.000000      29.909073    5.000000
# 1413  Fermentor 31201731179653        0.000000      29.905619    5.000000
# 1414  Fermentor 31201731179653        0.000000      29.914247    5.000000
# 1415  Fermentor 31201731179653        0.000000      29.926382    5.000000
# 1416  Fermentor 31201731179653        0.000000      29.937992    5.000000
# 1417  Fermentor 31201731179653        0.000000      29.949880    5.000000
# 1418  Fermentor 31201731179653        0.000000      29.959858    5.000000
# 1419  Fermentor 31201731179653        0.000000      29.972992    5.000000
# 1420  Fermentor 31201731179653        0.000000      29.981985    5.000000
# 1421  Fermentor 31201731179653        0.000000      29.994856    5.000000
# 1422  Fermentor 31201731179653        0.641224      30.008036    5.000000
# 1423  Fermentor 31201731179653        1.807086      30.019087    5.000000
# 1424  Fermentor 31201731179653        2.972947      30.028880    5.000000
# 1425  Fermentor 31201731179653        4.138809      30.040619    5.000000
# 1426  Fermentor 31201731179653        5.304671      30.053942    5.000000
# 1427  Fermentor 31201731179653        7.094911      30.065622    5.000000
# 1428  Fermentor 31201731179653        9.010027      30.075064    5.000000
# 1429  Fermentor 31201731179653       10.925142      30.088009    5.000000
# 1430  Fermentor 31201731179653       12.840259      30.062792    5.000000
# 1431  Fermentor 31201731179653       14.755374      30.085730    5.000000
# 1432  Fermentor 31201731179653       12.502110      30.071127    5.000000
# 1433  Fermentor 31201731179653        9.415169      30.010070    5.000000
# 1434  Fermentor 31201731179653        6.328228      30.068003    5.000000
# 1435  Fermentor 31201731179653        3.241288      30.036314    5.000000
# 1436  Fermentor 31201731179653        0.154347      30.003580    5.000000
# 1437  Fermentor 31201731179653        2.258153      30.021994    5.000000
# 1438  Fermentor 31201731179653        4.635156      30.078285    5.000000
# 1439  Fermentor 31201731179653        7.012158      30.085482    5.000000
# 1440  Fermentor 31201731179653        9.389161      30.018522    5.000000
#
#           Status           Timestamp  Top TIC OUT  Top TIC PV   Volume
# 0     Maturation 2017-03-17 07:00:00     0.000000   29.613152  716.566
# 1     Maturation 2017-03-17 07:01:00     0.000000   29.552847  716.566
# 2     Maturation 2017-03-17 07:02:00     0.000000   29.497858  716.566
# 3     Maturation 2017-03-17 07:03:00     0.000000   29.456203  716.566
# 4     Maturation 2017-03-17 07:04:00     0.000000   29.438652  716.566
# 5     Maturation 2017-03-17 07:05:00     0.000000   29.421194  716.566
# 6     Maturation 2017-03-17 07:06:00     0.000000   29.430151  716.566
# 7     Maturation 2017-03-17 07:07:00     0.000000   29.476150  716.566
# 8     Maturation 2017-03-17 07:08:00     0.000000   29.468636  716.566
# 9     Maturation 2017-03-17 07:09:00     0.000000   29.464607  716.566
# 10    Maturation 2017-03-17 07:10:00     0.000000   29.428816  716.566
# 11    Maturation 2017-03-17 07:11:00     0.000000   29.423681  716.566
# 12    Maturation 2017-03-17 07:12:00     0.000000   29.438360  716.566
# 13    Maturation 2017-03-17 07:13:00     0.000000   29.492730  716.566
# 14    Maturation 2017-03-17 07:14:00     0.000000   29.484865  716.566
# 15    Maturation 2017-03-17 07:15:00     0.000000   29.451567  716.566
# 16    Maturation 2017-03-17 07:16:00     0.000000   29.422504  716.566
# 17    Maturation 2017-03-17 07:17:00     0.000000   29.468386  716.566
# 18    Maturation 2017-03-17 07:18:00     0.000000   29.462850  716.566
# 19    Maturation 2017-03-17 07:19:00     0.000000   29.456930  716.566
# 20    Maturation 2017-03-17 07:20:00     0.000000   29.497790  716.566
# 21    Maturation 2017-03-17 07:21:00     0.000000   29.489620  716.566
# 22    Maturation 2017-03-17 07:22:00     0.000000   29.431010  716.566
# 23    Maturation 2017-03-17 07:23:00     0.000000   29.412770  716.566
# 24    Maturation 2017-03-17 07:24:00     0.000000   29.434036  716.566
# 25    Maturation 2017-03-17 07:25:00     0.000000   29.462510  716.566
# 26    Maturation 2017-03-17 07:26:00     0.000000   29.476015  716.566
# 27    Maturation 2017-03-17 07:27:00     0.448450   29.411950  716.566
# 28    Maturation 2017-03-17 07:28:00     1.009013   29.416990  716.566
# 29    Maturation 2017-03-17 07:29:00     1.569576   29.407148  716.566
# ...          ...                 ...          ...         ...      ...
# 1411  Maturation 2017-03-18 06:31:00     0.000000   29.900000  716.566
# 1412  Maturation 2017-03-18 06:32:00     0.000000   29.900000  716.566
# 1413  Maturation 2017-03-18 06:33:00     0.000000   29.900000  716.566
# 1414  Maturation 2017-03-18 06:34:00     0.000000   29.900000  716.566
# 1415  Maturation 2017-03-18 06:35:00     0.000000   29.900000  716.566
# 1416  Maturation 2017-03-18 06:36:00     0.000000   29.900000  716.566
# 1417  Maturation 2017-03-18 06:37:00     0.000000   29.900000  716.566
# 1418  Maturation 2017-03-18 06:38:00     0.000000   29.900000  716.566
# 1419  Maturation 2017-03-18 06:39:00     0.000000   29.900000  716.566
# 1420  Maturation 2017-03-18 06:40:00     0.000000   29.900000  716.566
# 1421  Maturation 2017-03-18 06:41:00     0.000000   29.900000  716.566
# 1422  Maturation 2017-03-18 06:42:00     0.000000   29.900000  716.566
# 1423  Maturation 2017-03-18 06:43:00     0.000000   29.900000  716.566
# 1424  Maturation 2017-03-18 06:44:00     0.000000   29.900000  716.566
# 1425  Maturation 2017-03-18 06:45:00     0.000000   29.900000  716.566
# 1426  Maturation 2017-03-18 06:46:00     0.000000   29.900000  716.566
# 1427  Maturation 2017-03-18 06:47:00     0.000000   29.900000  716.566
# 1428  Maturation 2017-03-18 06:48:00     0.000000   29.900000  716.566
# 1429  Maturation 2017-03-18 06:49:00     0.000000   29.900000  716.566
# 1430  Maturation 2017-03-18 06:50:00     0.000000   29.900000  716.566
# 1431  Maturation 2017-03-18 06:51:00     0.000000   29.900000  716.566
# 1432  Maturation 2017-03-18 06:52:00     0.000000   29.900000  716.566
# 1433  Maturation 2017-03-18 06:53:00     0.000000   29.900000  716.566
# 1434  Maturation 2017-03-18 06:54:00     0.000000   29.900000  716.566
# 1435  Maturation 2017-03-18 06:55:00     0.000000   29.900000  716.566
# 1436  Maturation 2017-03-18 06:56:00     0.000000   29.900000  716.566
# 1437  Maturation 2017-03-18 06:57:00     0.000000   29.900000  716.566
# 1438  Maturation 2017-03-18 06:58:00     0.000000   29.900000  716.566
# 1439  Maturation 2017-03-18 06:59:00     0.000000   29.900000  716.566
# 1440  Maturation 2017-03-18 07:00:00     0.000000   29.900000  716.566
#
# [1441 rows x 13 columns]>

# %% [markdown]
# ### Note the that resulting dataframe has almost 182K rows
#
# ## Save data into CSV file locally in directory FlashcARD

# %%
df.to_csv('beer_ocs_v1.csv')

# %% [markdown]
# ---
# ## Clicking this [link](./beer_20_days.csv) opens up a CSV browser with the CSV above
# ---

# %% [markdown]
# ### List of column names with their type
#
# Note that the `_time` column (a new column on top of the 16 ones of a Fermentor) has the correct datetime panda data type for timestamps

# %%
for i, c in enumerate(df.columns, 1):
    print('%2d' % i, c, '((( type:', df[c].dtype, ')))')
# Out:
#  1 DefaultGroupRule ((( type: object )))
#  2 DigitalStateName ((( type: float64 )))
#  3 Quality ((( type: int64 )))
#  4 StateCode ((( type: float64 )))
#  5 Timestamp ((( type: datetime64[ns] )))
#  6 Value ((( type: int64 )))

# %%
for row in df.iterrows():
    print(row)
# Out:
# (0, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:00:00
# Value                                                            0
# Name: 0, dtype: object)
# (1, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:01:00
# Value                                                            0
# Name: 1, dtype: object)
# (2, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:02:00
# Value                                                            0
# Name: 2, dtype: object)
# (3, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:03:00
# Value                                                            0
# Name: 3, dtype: object)
# (4, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:04:00
# Value                                                            0
# Name: 4, dtype: object)
# (5, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:05:00
# Value                                                            0
# Name: 5, dtype: object)
# (6, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:06:00
# Value                                                            0
# Name: 6, dtype: object)
# (7, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:07:00
# Value                                                            0
# Name: 7, dtype: object)
# (8, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:08:00
# Value                                                            0
# Name: 8, dtype: object)
# (9, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:09:00
# Value                                                            0
# Name: 9, dtype: object)
# (10, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:10:00
# Value                                                            0
# Name: 10, dtype: object)
# (11, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:11:00
# Value                                                            0
# Name: 11, dtype: object)
# (12, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:12:00
# Value                                                            0
# Name: 12, dtype: object)
# (13, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:13:00
# Value                                                            0
# Name: 13, dtype: object)
# (14, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:14:00
# Value                                                            0
# Name: 14, dtype: object)
# (15, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:15:00
# Value                                                            0
# Name: 15, dtype: object)
# (16, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:16:00
# Value                                                            0
# Name: 16, dtype: object)
# (17, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:17:00
# Value                                                            0
# Name: 17, dtype: object)
# (18, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:18:00
# Value                                                            0
# Name: 18, dtype: object)
# (19, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:19:00
# Value                                                            0
# Name: 19, dtype: object)
# (20, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:20:00
# Value                                                            0
# Name: 20, dtype: object)
# (21, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:21:00
# Value                                                            0
# Name: 21, dtype: object)
# (22, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:22:00
# Value                                                            0
# Name: 22, dtype: object)
# (23, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:23:00
# Value                                                            0
# Name: 23, dtype: object)
# (24, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:24:00
# Value                                                            0
# Name: 24, dtype: object)
# (25, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:25:00
# Value                                                            0
# Name: 25, dtype: object)
# (26, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:26:00
# Value                                                            0
# Name: 26, dtype: object)
# (27, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:27:00
# Value                                                            0
# Name: 27, dtype: object)
# (28, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:28:00
# Value                                                            0
# Name: 28, dtype: object)
# (29, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:29:00
# Value                                                            0
# Name: 29, dtype: object)
# (30, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:30:00
# Value                                                            0
# Name: 30, dtype: object)
# (31, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:31:00
# Value                                                            0
# Name: 31, dtype: object)
# (32, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:32:00
# Value                                                            0
# Name: 32, dtype: object)
# (33, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:33:00
# Value                                                            0
# Name: 33, dtype: object)
# (34, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:34:00
# Value                                                            0
# Name: 34, dtype: object)
# (35, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:35:00
# Value                                                            0
# Name: 35, dtype: object)
# (36, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:36:00
# Value                                                            0
# Name: 36, dtype: object)
# (37, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:37:00
# Value                                                            0
# Name: 37, dtype: object)
# (38, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:38:00
# Value                                                            0
# Name: 38, dtype: object)
# (39, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:39:00
# Value                                                            0
# Name: 39, dtype: object)
# (40, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:40:00
# Value                                                            0
# Name: 40, dtype: object)
# (41, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:41:00
# Value                                                            0
# Name: 41, dtype: object)
# (42, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:42:00
# Value                                                            0
# Name: 42, dtype: object)
# (43, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:43:00
# Value                                                            0
# Name: 43, dtype: object)
# (44, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:44:00
# Value                                                            0
# Name: 44, dtype: object)
# (45, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:45:00
# Value                                                            0
# Name: 45, dtype: object)
# (46, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:46:00
# Value                                                            0
# Name: 46, dtype: object)
# (47, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:47:00
# Value                                                            0
# Name: 47, dtype: object)
# (48, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:48:00
# Value                                                            0
# Name: 48, dtype: object)
# (49, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:49:00
# Value                                                            0
# Name: 49, dtype: object)
# (50, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:50:00
# Value                                                            0
# Name: 50, dtype: object)
# (51, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:51:00
# Value                                                            0
# Name: 51, dtype: object)
# (52, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:52:00
# Value                                                            0
# Name: 52, dtype: object)
# (53, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:53:00
# Value                                                            0
# Name: 53, dtype: object)
# (54, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:54:00
# Value                                                            0
# Name: 54, dtype: object)
# (55, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:55:00
# Value                                                            0
# Name: 55, dtype: object)
# (56, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:56:00
# Value                                                            0
# Name: 56, dtype: object)
# (57, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:57:00
# Value                                                            0
# Name: 57, dtype: object)
# (58, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:58:00
# Value                                                            0
# Name: 58, dtype: object)
# (59, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 00:59:00
# Value                                                            0
# Name: 59, dtype: object)
# (60, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:00:00
# Value                                                            0
# Name: 60, dtype: object)
# (61, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:01:00
# Value                                                            0
# Name: 61, dtype: object)
# (62, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:02:00
# Value                                                            0
# Name: 62, dtype: object)
# (63, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:03:00
# Value                                                            0
# Name: 63, dtype: object)
# (64, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:04:00
# Value                                                            0
# Name: 64, dtype: object)
# (65, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:05:00
# Value                                                            0
# Name: 65, dtype: object)
# (66, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:06:00
# Value                                                            0
# Name: 66, dtype: object)
# (67, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:07:00
# Value                                                            0
# Name: 67, dtype: object)
# (68, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:08:00
# Value                                                            0
# Name: 68, dtype: object)
# (69, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:09:00
# Value                                                            0
# Name: 69, dtype: object)
# (70, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:10:00
# Value                                                            0
# Name: 70, dtype: object)
# (71, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:11:00
# Value                                                            0
# Name: 71, dtype: object)
# (72, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:12:00
# Value                                                            0
# Name: 72, dtype: object)
# (73, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:13:00
# Value                                                            0
# Name: 73, dtype: object)
# (74, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:14:00
# Value                                                            0
# Name: 74, dtype: object)
# (75, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:15:00
# Value                                                            0
# Name: 75, dtype: object)
# (76, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:16:00
# Value                                                            0
# Name: 76, dtype: object)
# (77, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:17:00
# Value                                                            0
# Name: 77, dtype: object)
# (78, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:18:00
# Value                                                            0
# Name: 78, dtype: object)
# (79, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:19:00
# Value                                                            0
# Name: 79, dtype: object)
# (80, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:20:00
# Value                                                            0
# Name: 80, dtype: object)
# (81, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:21:00
# Value                                                            0
# Name: 81, dtype: object)
# (82, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:22:00
# Value                                                            0
# Name: 82, dtype: object)
# (83, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:23:00
# Value                                                            0
# Name: 83, dtype: object)
# (84, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:24:00
# Value                                                            0
# Name: 84, dtype: object)
# (85, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:25:00
# Value                                                            0
# Name: 85, dtype: object)
# (86, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:26:00
# Value                                                            0
# Name: 86, dtype: object)
# (87, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:27:00
# Value                                                            0
# Name: 87, dtype: object)
# (88, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:28:00
# Value                                                            0
# Name: 88, dtype: object)
# (89, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:29:00
# Value                                                            0
# Name: 89, dtype: object)
# (90, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:30:00
# Value                                                            0
# Name: 90, dtype: object)
# (91, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:31:00
# Value                                                            0
# Name: 91, dtype: object)
# (92, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:32:00
# Value                                                            0
# Name: 92, dtype: object)
# (93, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:33:00
# Value                                                            0
# Name: 93, dtype: object)
# (94, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:34:00
# Value                                                            0
# Name: 94, dtype: object)
# (95, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:35:00
# Value                                                            0
# Name: 95, dtype: object)
# (96, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:36:00
# Value                                                            0
# Name: 96, dtype: object)
# (97, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:37:00
# Value                                                            0
# Name: 97, dtype: object)
# (98, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:38:00
# Value                                                            0
# Name: 98, dtype: object)
# (99, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:39:00
# Value                                                            0
# Name: 99, dtype: object)
# (100, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:40:00
# Value                                                            0
# Name: 100, dtype: object)
# (101, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:41:00
# Value                                                            0
# Name: 101, dtype: object)
# (102, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:42:00
# Value                                                            0
# Name: 102, dtype: object)
# (103, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:43:00
# Value                                                            0
# Name: 103, dtype: object)
# (104, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:44:00
# Value                                                            0
# Name: 104, dtype: object)
# (105, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:45:00
# Value                                                            0
# Name: 105, dtype: object)
# (106, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:46:00
# Value                                                            0
# Name: 106, dtype: object)
# (107, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:47:00
# Value                                                            0
# Name: 107, dtype: object)
# (108, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:48:00
# Value                                                            0
# Name: 108, dtype: object)
# (109, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:49:00
# Value                                                            0
# Name: 109, dtype: object)
# (110, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 01:50:00
# Value                                                            0
# Name: 110, dtype: object)
# ...
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:03:00
# Value                                                            0
# Name: 963, dtype: object)
# (964, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:04:00
# Value                                                            0
# Name: 964, dtype: object)
# (965, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:05:00
# Value                                                            0
# Name: 965, dtype: object)
# (966, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:06:00
# Value                                                            0
# Name: 966, dtype: object)
# (967, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:07:00
# Value                                                            0
# Name: 967, dtype: object)
# (968, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:08:00
# Value                                                            0
# Name: 968, dtype: object)
# (969, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:09:00
# Value                                                            0
# Name: 969, dtype: object)
# (970, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:10:00
# Value                                                            0
# Name: 970, dtype: object)
# (971, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:11:00
# Value                                                            0
# Name: 971, dtype: object)
# (972, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:12:00
# Value                                                            0
# Name: 972, dtype: object)
# (973, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:13:00
# Value                                                            0
# Name: 973, dtype: object)
# (974, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:14:00
# Value                                                            0
# Name: 974, dtype: object)
# (975, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:15:00
# Value                                                            0
# Name: 975, dtype: object)
# (976, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:16:00
# Value                                                            0
# Name: 976, dtype: object)
# (977, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:17:00
# Value                                                            0
# Name: 977, dtype: object)
# (978, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:18:00
# Value                                                            0
# Name: 978, dtype: object)
# (979, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:19:00
# Value                                                            0
# Name: 979, dtype: object)
# (980, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:20:00
# Value                                                            0
# Name: 980, dtype: object)
# (981, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:21:00
# Value                                                            0
# Name: 981, dtype: object)
# (982, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:22:00
# Value                                                            0
# Name: 982, dtype: object)
# (983, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:23:00
# Value                                                            0
# Name: 983, dtype: object)
# (984, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:24:00
# Value                                                            0
# Name: 984, dtype: object)
# (985, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:25:00
# Value                                                            0
# Name: 985, dtype: object)
# (986, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:26:00
# Value                                                            0
# Name: 986, dtype: object)
# (987, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:27:00
# Value                                                            0
# Name: 987, dtype: object)
# (988, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:28:00
# Value                                                            0
# Name: 988, dtype: object)
# (989, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:29:00
# Value                                                            0
# Name: 989, dtype: object)
# (990, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:30:00
# Value                                                            0
# Name: 990, dtype: object)
# (991, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:31:00
# Value                                                            0
# Name: 991, dtype: object)
# (992, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:32:00
# Value                                                            0
# Name: 992, dtype: object)
# (993, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:33:00
# Value                                                            0
# Name: 993, dtype: object)
# (994, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:34:00
# Value                                                            0
# Name: 994, dtype: object)
# (995, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:35:00
# Value                                                            0
# Name: 995, dtype: object)
# (996, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:36:00
# Value                                                            0
# Name: 996, dtype: object)
# (997, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:37:00
# Value                                                            0
# Name: 997, dtype: object)
# (998, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:38:00
# Value                                                            0
# Name: 998, dtype: object)
# (999, DefaultGroupRule    acsbrew.BREWERY.B2_CL_C2_FV31.Batch Active Tag
# DigitalStateName                                               NaN
# Quality                                                          0
# StateCode                                                      NaN
# Timestamp                                      2017-03-18 16:39:00
# Value                                                            0
# Name: 999, dtype: object)

# %%
for f in df.Fermentation_ID.unique():
    print(f, isinstance(f, str))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-83aa316c76c4> in <module>
# ----> 1 for f in df.Fermentation_ID.unique():
#       2     print(f, isinstance(f, str))
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fermentation_ID'

# %% [markdown]
# ### Prepare ADF curve plots over time

# %%
import plotly.graph_objs as go

figs = []
data = []
for f in df.Fermentation_ID.unique():
    trace = go.Scattergl(x = df[df.Fermentation_ID == f]['_time'], y = df[df.Fermentation_ID == f]['ADF'], mode='lines+markers', name=str(f))
    figs.append(go.FigureWidget(data=[trace]))
    data.append(trace)

# %% [markdown]
# ### Add a range slider
#
# With a few time range selectors: 8 hours, 1 day and everything
#
# Note: range slider is grey now because of an incompatibility with ScatterGL: https://github.com/plotly/plotly.js/issues/2627

# %%
layout = dict(
    title='Brewing ADF with time range slider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=8,
                     label='8h',
                     step='hour',
                     stepmode='backward'),
                dict(count=1,
                     label='1d',
                     step='day',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)
        
fig = go.FigureWidget(data=data, layout=layout)
fig

# %% [markdown]
# ## Clean up: delete Dataviews
#
# * Code 204 if deletion is successful
# * Code 404 if requested Dataview Id doesn't exist or already deleted

# %%
for dv in dataviews_url:
    dv_url = dv[:dv.find('/preview')]
    s = requests.delete(dv_url, headers=headers)
    print(s.status_code, dv_url)
