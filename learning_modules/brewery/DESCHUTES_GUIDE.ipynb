# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Academic-Hub---Deschutes-Brewery-Dataset-Learning-Modules" data-toc-modified-id="Academic-Hub---Deschutes-Brewery-Dataset-Learning-Modules-1">Academic Hub - Deschutes Brewery Dataset Learning Modules</a></span><ul class="toc-item"><li><span><a href="#IMPORTANT-NOTE" data-toc-modified-id="IMPORTANT-NOTE-1.1">IMPORTANT NOTE</a></span></li><li><span><a href="#Overview:" data-toc-modified-id="Overview:-1.2">Overview:</a></span><ul class="toc-item"><li><span><a href="#Learning-modules" data-toc-modified-id="Learning-modules-1.2.1">Learning modules</a></span></li><li><span><a href="#Tutorials-and-dataset-document" data-toc-modified-id="Tutorials-and-dataset-document-1.2.2">Tutorials and dataset document</a></span></li></ul></li><li><span><a href="#Learning-modules" data-toc-modified-id="Learning-modules-1.3">Learning modules</a></span><ul class="toc-item"><li><span><a href="#Exercise-1:-Apparent-Degree-of-Fermentation-notebooks" data-toc-modified-id="Exercise-1:-Apparent-Degree-of-Fermentation-notebooks-1.3.1">Exercise 1: Apparent Degree of Fermentation notebooks</a></span></li><li><span><a href="#Exercise-2:-Beer-Cooling-Prediction-notebooks" data-toc-modified-id="Exercise-2:-Beer-Cooling-Prediction-notebooks-1.3.2">Exercise 2: Beer Cooling Prediction notebooks</a></span></li><li><span><a href="#Exercise-3:-Principal-Component-Analysis-notebooks" data-toc-modified-id="Exercise-3:-Principal-Component-Analysis-notebooks-1.3.3">Exercise 3: Principal Component Analysis notebooks</a></span></li></ul></li><li><span><a href="#Brewery-Dataset-Documentation-and-Tutorials" data-toc-modified-id="Brewery-Dataset-Documentation-and-Tutorials-1.4">Brewery Dataset Documentation and Tutorials</a></span><ul class="toc-item"><li><span><a href="#Brewery-Dataset-Document-Notebook" data-toc-modified-id="Brewery-Dataset-Document-Notebook-1.4.1"><a href="./Brewery_Dataset_Doc.ipynb" rel="nofollow" target="_blank">Brewery Dataset Document Notebook</a></a></span></li><li><span><a href="#Brewery-Dataset-Quick-Start" data-toc-modified-id="Brewery-Dataset-Quick-Start-1.4.2"><a href="./Brewery_Dataset_Quickstart.ipynb" rel="nofollow" target="_blank">Brewery Dataset Quick Start</a></a></span></li><li><span><a href="#Pandas-Guide" data-toc-modified-id="Pandas-Guide-1.4.3"><a href="./PandasGuide.ipynb" rel="nofollow" target="_blank">Pandas Guide</a></a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Academic Hub - Deschutes Brewery Dataset Learning Modules
# ___
#
# ![Hub Overview](https://academichub.blob.core.windows.net/images/Nav_markdown_hub-overview.png)
#
# Academic Hub is a cloud-based platform that supports modern chemical engineering data analytics for classroom education in universities. The best way to learn data analytics is to be exposed to real industry issues using real process data. This is why OSIsoft asked one of its commercial customers, [Deschutes Brewery](https://www.deschutesbrewery.com/) if they would like to share their PI System data with our educational customers.
#
# The Deschutes Brewery dataset represents the process data collected during their beer-making process, compiled from January 2017 to May 2020. Deschutes brewers have identified the critical process parameters that can have significant impact on their organizational performance. In the three learning modules, students will visualize, analyze, and apply data analytics on the brewing process data that reflect the real-world problems.
#
#
# ---
#
# ## IMPORTANT NOTE
#
# **Each learning module is composed of a pair of Jupyter notebooks: one notebook for the students with exercises and an associated solution for professor/TA. The exercise notebooks have missing pieces of codes with the pattern `@@@ You code here @@@`. Once completed, the exercise notebook should run to completion (meaning all cells run successfully in sequence) and produce the same results/graphs as the solution notebook. It is then possible experiment by changing the input parameters and analyse another brand of beer, or check the impact (if any) of the interpolation interval on the results, etc.**
#
# **Each exercise notebook is generated from its associated solution notebook. The first two cells after the table of contents in each solution notebook can be used to regenerate the exercise notebook after edits to the solution notebook. We put below of copy of the exercise notebook generation process:**
#
# **Professor/TA Section Only**
#
# The present notebook is a SOLUTION notebook with identified code blocks students should fill in. All student code blocks have the following format:
#
#     # we are only interested in events in status="Fermentation"
#     # TODO: complete the filter expression to keep only data corresponding to the fermentation stages
#     # =========== STUDENT BEGIN ==========
#     # all_brands_df = all_brands_df[@@@ Your code here @@@]
#     # =========== STUDENT END ==========
#     all_brands_df = all_brands_df[all_brands_df["Status"] == "Fermentation"]
#     # =========== STUDENT SOLUTION ===========
#
# * A sequence of STUDENT BEGIN / STUDENT END / STUDENT SOLUTION keyword lines
# * All lines between BEGIN / END are commented out with missing pieces clearly identified
# * The SOLUTION part should not be commented out
#
# If you follow the rules above, executing the cell below produces a fresh exercise notebook using `generate_exercise_notebook` where the exercise notebook has the following changes:
#
# * This cell and the next one are removed
# * The notebook filename is the same as this one except "SOLUTION" => "EXERCISE"
# * Solution lines are stripped out and lines of code between BEGIN / END have the comment character # removed
#
# The EXERCISE notebook is executable up to the point of the first student code block where a syntax error will be reported.
#
# ---
#
# **Academic Hub data infrastructure is based on [OSIsoft Cloud Services (OCS)](https://www.osisoft.com/Solutions/OSIsoft-Cloud-Services/) which requires each student to have an active Academic Hub account. To register, go to https://academic.osisoft.com**
#
# **All learning modules can be executed with a standard Jupyter server. We test our learning modules with and recommend [Anaconda](https://www.anaconda.com/distribution/) for advanced classes. For all other classes, free cloud services like [Binder](https://mybinder.com) or [Google Colab](https://colab.research.google.com/) are better options for student zero-setup deployment.**
#
# The rest of this guide help navigating through different notebooks that suit your interest, while providing a hint of what each notebook contains. To navigate to the learning modules, tutorials, or dataset document, click the hyperlinks to navigate to the notebook instantly.
#
#
# ---
#
# ## Overview:
#
# ### Learning modules
#
# There are three different learning modules, encompassing the topic that the Deschutes brewers identified as critical to their process optimization. Deschutes brewers optimizing these parameters saved $750K in capital investment and reduced lost production time. By completing the exercises in the learning modules, students solve the process analysis problems that reflect real-world industry challenges.
#
# **Exercise 1:** [Apparent Degree of Fermentation notebook](#section_1a)
#
# **Exercise 2:** [Beer Cooling Prediction notebook](#section_1b)
#
# **Exercise 3:** [Principal Component Analysis notebook](#section_1c)
#
#
# ### Tutorials and dataset document
#
#
# The dataset document and tutorials are provided to cover the fundamental and the complementary concepts that students need to understand for the learning modules.
#
# * [Dataset Document Notebook](./Brewery_Dataset_Doc.ipynb)
#
# * [Brewery Dataset Quick Start](./Brewery_Dataset_Quickstart.ipynb)
#
# * [Pandas tutorial](./PandasGuide.ipynb)
#
# ---
# ---
#
# ## Learning modules
#
# <a id="section_1a"></a>
# <a id="exercise1"></a>
# <a id="Part-1a.-Apparent-Degree-of-Fermentation-notebooks"></a>
# ### Exercise 1: Apparent Degree of Fermentation notebooks
#
# **Links**
#
# * **[Learning Objectives](./NB1_LEARNOBJECTIVES_ADF_Prediction.ipynb)**
# * **[Exercise NB](./NB1_EXERCISE_ADF_Prediction.ipynb)**
# * **[Solution NB](./NB1_SOLUTION_ADF_Prediction.ipynb)** (TA only)
#
# In this learning module, students will analyze the Apparent Degree of Fermentation (ADF) during the beer-making process, which is a critical process parameter that inform brewers how much a batch has fermented over time. Brewers use this parameter to make a shift from fermentation phase to free rise phase. Through this exercise, students will learn how to build the predictive linear, and predictive piecewise linear model on ADF.
#
# ![ADF Prediction](https://academichub.blob.core.windows.net/images/nb1_linear_reg_v1.png)
#
# ---
# <a id="section_1b"></a>
# <a id="exercise2"></a>
# <a id="Part-1b.-Beer-Cooling-Prediction-notebook"></a>
# ### Exercise 2: Beer Cooling Prediction notebooks
#
# **Links**
#
# * **[Learning Objectives](./NB2_LEARNOBJECTIVES_Cooling_Prediction.ipynb)**
# * **[Exercise NB](./NB2_EXERCISE_Cooling_Prediction.ipynb)**
# * **[Solution NB](./NB2_SOLUTION_Cooling_Prediction.ipynb)** (TA)
#
# Consistent cooling temperature profile of every batch is directly related to the quality of beer production. During the cooling phase of the brewing process, the temperature of the solution in the fermenter drops from 70°F to 30°F. In the learning module of Beer Cooling Prediction, students will visualize and analyze the data, and will build the predictive model of the cooling temperature.
#
# ![Beer Cooling Prediction](https://academichub.blob.core.windows.net/images/nb2_solution_graph_v4.png)
#
#
# ---
# <a id="section_1c"></a>
# <a id="exercise3"></a>
# <a id="Part-1c.-Principal-Component-Analysis-notebooks"></a>
# ### Exercise 3: Principal Component Analysis notebooks
#
# **Links**
#
# * **[Learning Objectives](./NB3_LEARNOBJECTIVES_Beer_PCA.ipynb)**
# * **[Exercise NB](./NB3_EXERCISE_Beer_PCA.ipynb)**
# * **[Solution NB](./NB3_SOLUTION_Beer_PCA.ipynb)** (TA only)
#
# Principal Component Analysis is a statistical technique that compresses the dimensionality of large datasets to a few Principal Components to represent the data. In the learning module, students use PCA to determine the anomalous production batch, and the contributing factors for such deviation behavior.
#
# ![Principal Component Analysis](https://academichub.blob.core.windows.net/images/nb3_pca_scatterplot_new_v6.png)
#
# ---
#
# ## Brewery Dataset Documentation and Tutorials
#
# <a id="section_2a"></a>
# ### [Brewery Dataset Document Notebook](./Brewery_Dataset_Doc.ipynb)
#
#
# The primary purpose of the dataset document is to provide students the basic understanding of Deschutes brewery dataset, including both straight-forward description and less intuitive concepts to non-Computer Science students. The dataset document entails the summary of Deschutes dataset and the data quality. Less intuitive topics includes stream data and data view. It is recommended to look into the dataset document before exploring the learning modules.
#
# ![Dataset Document Notebook](https://academichub.blob.core.windows.net/images/brewery-dataset-doc-toc.png)
#
#
# ---
# <a id="section_2b"></a>
# ### [Brewery Dataset Quick Start](./Brewery_Dataset_Quickstart.ipynb)
#
#
# Each Academic Hub dataset is a collection of related assets, each asset data being accessible through a set (each asset as at least one) of data views. Data views are OSIsoft OCS solution to collect into an application-ready table format process/operation data about the assets. This notebook will get you up to speed accessing process data and associated information to make sense of it.
#
# ![](https://academichub.blob.core.windows.net/images/hub-new-login-cell.png)
#
# ---
# ---
# <a id="section_2c"></a>
# ### [Pandas Guide](./PandasGuide.ipynb)
#
#
# [Pandas](https://pandas.pydata.org/) has become the de-facto Python library for data analysis. Before Pandas, Python role has been confined to data munging and preparation. With Pandas, it is possible to perform data analysis and modeling fully and simply in Python. This is why this library has been selected for the learning modules. The Pandas guide look into the concept of Pandas, and simple Pandas operations used throughout the 3 modules.
#
# ![Pandas Guide](https://academichub.blob.core.windows.net/images/pandas-guide-landing.png)
#
# ---

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=27d58a9b-9aaa-47c5-b041-7e32d6d185a5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
