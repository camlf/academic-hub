# %% [markdown]
# ## Step 2: Augment database with asset data view and supporting metadata
#
# #### For all elements/assets with PIPoints, create a default Data View having as columns all those PIPoints
#
# Data View column names are the attribute names in AF, so elements sharing a template have identical Data Views modulo missing streams
#
# This notebook also creates specialized Data Views:
#
# * Some are subsets of the default Data View, per asset
# * Others are multi-assets version of the above
#
# #### After running this notebook, the graph has all the necessary information for Step 2: projection of tags/metadata on streams and Data View creation

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import json
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import yaml
import pprint
from collections import OrderedDict

# %% [markdown]
# ## Input Parameters

# %%
config_file = "config-delmar.yaml"
# config_file = "config-cmu2.yaml"
# config_file = "config-windfarm.yaml"  # 
# config_file = "config-acad-prod-desc-v2.yaml"

# %%
with open(config_file) as f:
    config = yaml.safe_load(f)
# config

# %%
# Input parameters

database_name = config["db"]["database_name"]
root_element = config["db"]["root_element"]
ocs_asset_db = dv_id_prefix = config["ocs"]["configuration"]["asset_db"]

# Each assets in a Hub dataset is endowed with default Data View (DV) "All_Columns" having all the asset streams
# The next line of code defines a dictionary to build all default (DV)
# If <column list> is empty list [], include all streams in Data View
dv_defs = {"Default": ("all_columns", [], lambda id: True)}
has_no_dv = lambda id: False


# YAML config file may embed additional code to define additional custom dataviews
try:
    exec(config["custom_dvs"])
except:
    pass

dv_defs
# Out:
# {'Default': ('all_columns', [], <function __main__.<lambda>(id)>)}

# %%
sample_transport = RequestsHTTPTransport(
    url=config["graphql"]["endpoint"], verify=False, retries=3
)
client = Client(transport=sample_transport, fetch_schema_from_transport=True)

# %%
db_query = gql(
    """
query DatabaseId($database: String) {
    Database(name: $database) {
        name
        id
        asset_db
    }
}
"""
)
print(f"database_name={database_name}")
db = client.execute(db_query, variable_values={"database": database_name})
print(json.dumps(db, indent=4))
# Out:
# database_name=Pilot_Plant
# {
#     "Database": [
#         {
#             "name": "Pilot_Plant",
#             "id": "pilot.plant:F1RDcFWpYyj-GkWKwoVLgdSfpwG1XyxiSvX0WMNyDlsRHq8AUElBRi1BQ0FEXFBJTE9UUExBTlQ",
#             "asset_db": "pilot.plant"
#         }
#     ]
# }

# %%
db_id = db["Database"][0]["id"]
asset_db = db["Database"][0]["asset_db"]
asset_db, db_id
# Out:
# ('pilot.plant',
#  'pilot.plant:F1RDcFWpYyj-GkWKwoVLgdSfpwG1XyxiSvX0WMNyDlsRHq8AUElBRi1BQ0FEXFBJTE9UUExBTlQ')

# %% [raw]
#     """
# query RootElementTree($root : String, $asset_db: String) {
#     Element(name: $root, asset_db: $asset_db) {
#         name
#         id
#         has_element(orderBy: name_asc) {
#             name
#             id
#             has_attribute(filter: {is_stream: true}) {
#                 name
#                 id
#                 has_dynamic(orderBy: stream_name_asc) {
#                       name
#                       stream_name
#                       id
#                       pointsource
#                 }
#             }
#         }
#     }
# }
# """

# %%
root_query = gql(
    """
query RootElementTree($root : String, $asset_db: String) {
    Element(name: $root, asset_db: $asset_db) {
        name
        id
        has_element(orderBy: name_asc) {
            name
            id
            all_streams(orderBy: name_asc) {
                name
                stream_name
                id
                pointsource
            }
        }
    }
}
"""
)
j = client.execute(
    root_query, variable_values={"root": root_element, "asset_db": ocs_asset_db}
)
print(json.dumps(j, indent=4))
# Out:
# {
#     "Element": [
#         {
#             "name": "Pilot Plant",
#             "id": "pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw7j7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlQ",
#             "has_element": [
#                 {
#                     "name": "HOT-1",
#                     "id": "pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE",
#                     "all_streams": [
#                         {
#                             "name": "E-102 Duty",
#                             "stream_name": "delmar.DELMAR_UNIT1_E-102_DUTY",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Heat Transfer Coefficient",
#                             "stream_name": "delmar.DELMAR_UNIT1_E-102_HTC",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 LMTD",
#                             "stream_name": "delmar.DELMAR_UNIT1_E-102_LMTD",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Heater Charge Flow",
#                             "stream_name": "delmar.DELMAR_UNIT1_FI-102.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Feed Flow Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT1_FIC-101.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Feed Flow Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT1_FIC-101.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Feed Flow Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT1_FIC-101.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Feed Flow Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT1_FIC-101.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "T-101 Level Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT1_LIC-101.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "T-101 Level Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT1_LIC-101.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "T-101 Level Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT1_LIC-101.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "T-101 Level Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT1_LIC-101.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Inlet Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-105.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-102 Discharge pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-108.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "H-101 Outlet Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-109.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Shell Side Outlet Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-110.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-101 A/B Discharge pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-111.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Outlet Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-112.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-101 Outlet Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT1_PI-113.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Inlet Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT1_TI-101.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Shell Side Inlet Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT1_TI-105.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Shell Side Outlet Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT1_TI-106.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-101 Air Cooler Outlet Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT1_TI-107.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Outlet Temperature Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-103.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Outlet Temperature Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-103.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Outlet Temperature Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-103.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-102 Tube Side Outlet Temperature Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-103.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "H-101 Outlet Temperature Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-104.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "H-101 Outlet Temperature Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-104.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "H-101 Outlet Temperature Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-104.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "H-101 Outlet Temperature Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT1_TIC-104.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Unit 1 Common Trouble Alarm",
#                             "stream_name": "delmar.DELMAR_UNIT1_XA-100",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "E-101 Run Status",
#                             "stream_name": "delmar.DELMAR_UNIT1_XB-101",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-101A Run Status",
#                             "stream_name": "delmar.DELMAR_UNIT1_XB-101A",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-101B Run Status",
#                             "stream_name": "delmar.DELMAR_UNIT1_XB-101B",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-102 Run Status",
#                             "stream_name": "delmar.DELMAR_UNIT1_XB-102",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "P-103 Run Status",
#                             "stream_name": "delmar.DELMAR_UNIT1_XB-103",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw",
#                             "pointsource": "PIC"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "HOT-3",
#                     "id": "pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM",
#                     "all_streams": [
#                         {
#                             "name": "Reboiler Duty",
#                             "stream_name": "delmar.DELMAR_UNIT3_E-201_REBOILERDUTY",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead to Feed Flow",
#                             "stream_name": "delmar.DELMAR_UNIT3_FI-210.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms to Feed Flow Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-200.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms to Feed Flow Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-200.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms to Feed Flow Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-200.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms to Feed Flow Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-200.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reflux to VacTower Flow Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-240.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reflux to Vac Tower Flow Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-240.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reflux to Vac Tower Flow Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-240.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reflux to Vac Tower Flow Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-240.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam to Reboiler Flow Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-275.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam to Reboiler Flow Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-275.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam to Reboiler Flow Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-275.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam to Reboiler Flow Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_FIC-275.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms Level",
#                             "stream_name": "delmar.DELMAR_UNIT3_LI-210.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead Receiver Level Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_LIC-240.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead Receiver Level Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_LIC-240.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead Receiver Level Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_LIC-240.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead Receiver Level Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_LIC-240.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Tower Top Bed Differential Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT3_PDI-220.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Overhead Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT3_PI-225.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam Header Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT3_PI-275.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Steam to Reboiler Pressure",
#                             "stream_name": "delmar.DELMAR_UNIT3_PI-280.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "V-240 Receiver Vacuum Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_PIC-250.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "V-240 Receiver Vacuum Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_PIC-250.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "V-240 Receiver Vacuum Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_PIC-250.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "V-240 Receiver Vacuum Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_PIC-250.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Bottoms Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-200.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Feed Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-210.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Tower Midsection temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-215.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Tower Top Section Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-225.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Ovhd Condenser Product Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-230.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Cooling Water Header Temperature",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-260.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Cooling Water Discharge E-230",
#                             "stream_name": "delmar.DELMAR_UNIT3_TI-265.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reboiler Outlet Temperature Controller Mode",
#                             "stream_name": "delmar.DELMAR_UNIT3_TIC-205.MODE",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reboiler Outlet Temperature Controller Output",
#                             "stream_name": "delmar.DELMAR_UNIT3_TIC-205.OUT",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reboiler Outlet Temperature Controller PV",
#                             "stream_name": "delmar.DELMAR_UNIT3_TIC-205.PV",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Reboiler Outlet Temperature Controller Setpoint",
#                             "stream_name": "delmar.DELMAR_UNIT3_TIC-205.SP",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A",
#                             "pointsource": "PIC"
#                         },
#                         {
#                             "name": "Unit 3 Common Trouble Alarm",
#                             "stream_name": "delmar.DELMAR_UNIT3_XA-200",
#                             "id": "F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA",
#                             "pointsource": "PIC"
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
elements = j["Element"][0]["has_element"] 
len(elements), elements
# Out:
# (2,
#  [{'name': 'HOT-1',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#    'all_streams': [{'name': 'E-102 Duty',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Heat Transfer Coefficient',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 LMTD',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#      'pointsource': 'PIC'},
#     {'name': 'Heater Charge Flow',
#      'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-101 A/B Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 1 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#      'pointsource': 'PIC'},
#     {'name': 'P-101A Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#      'pointsource': 'PIC'},
#     {'name': 'P-101B Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#      'pointsource': 'PIC'},
#     {'name': 'P-103 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#      'pointsource': 'PIC'}]},
#   {'name': 'HOT-3',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#    'all_streams': [{'name': 'Reboiler Duty',
#      'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam Header Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Header Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Discharge E-230',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 3 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#      'pointsource': 'PIC'}]}])

# %%
all_elements = elements
for element in elements:
    j = client.execute(root_query, variable_values={"root": element["name"]})
    all_elements += j["Element"][0]["has_element"] 
all_elements
# Out:
# [{'name': 'HOT-1',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#   'all_streams': [{'name': 'E-102 Duty',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Heat Transfer Coefficient',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 LMTD',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#     'pointsource': 'PIC'},
#    {'name': 'Heater Charge Flow',
#     'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'P-102 Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'P-101 A/B Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Air Cooler Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 1 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#     'pointsource': 'PIC'},
#    {'name': 'P-101A Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#     'pointsource': 'PIC'},
#    {'name': 'P-101B Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#     'pointsource': 'PIC'},
#    {'name': 'P-102 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#     'pointsource': 'PIC'},
#    {'name': 'P-103 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#     'pointsource': 'PIC'}]},
#  {'name': 'HOT-3',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#   'all_streams': [{'name': 'Reboiler Duty',
#     'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead to Feed Flow',
#     'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to VacTower Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Level',
#     'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Bed Differential Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Steam Header Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Midsection temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Section Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Ovhd Condenser Product Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Header Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Discharge E-230',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 3 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#     'pointsource': 'PIC'}]},
#  {'name': 'E-101',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwFT__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDE',
#   'all_streams': [{'name': 'E-102 Shell Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Air Cooler Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#     'pointsource': 'PIC'}]},
#  {'name': 'E-102',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDI',
#   'all_streams': [{'name': 'E-102 Duty',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Heat Transfer Coefficient',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 LMTD',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#     'pointsource': 'PIC'}]},
#  {'name': 'HTR-101',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwDD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcSFRSLTEwMQ',
#   'all_streams': [{'name': 'Heater Charge Flow',
#     'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#     'pointsource': 'PIC'}]},
#  {'name': 'TK-101',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwGD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAx',
#   'all_streams': [{'name': 'Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'P-101 A/B Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Air Cooler Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 1 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#     'pointsource': 'PIC'},
#    {'name': 'P-101A Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#     'pointsource': 'PIC'},
#    {'name': 'P-101B Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#     'pointsource': 'PIC'}]},
#  {'name': 'TK-102',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwDz__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAy',
#   'all_streams': [{'name': 'P-102 Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'P-102 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#     'pointsource': 'PIC'}]},
#  {'name': 'TK-103',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwCT__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAz',
#   'all_streams': [{'name': 'P-103 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#     'pointsource': 'PIC'}]},
#  {'name': 'Bottoms Product',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw_T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcQk9UVE9NUyBQUk9EVUNU',
#   'all_streams': [{'name': 'Bottoms to Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Level',
#     'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#     'pointsource': 'PIC'}]},
#  {'name': 'Energy In',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwAz__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcRU5FUkdZIElO',
#   'all_streams': [{'name': 'Reboiler Duty',
#     'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Steam Header Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#     'pointsource': 'PIC'}]},
#  {'name': 'Energy Out',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwAD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcRU5FUkdZIE9VVA',
#   'all_streams': [{'name': 'Tower Top Section Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Ovhd Condenser Product Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Header Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Discharge E-230',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#     'pointsource': 'PIC'}]},
#  {'name': 'Overhead Product',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw9z7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcT1ZFUkhFQUQgUFJPRFVDVA',
#   'all_streams': [{'name': 'Overhead to Feed Flow',
#     'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to VacTower Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Level',
#     'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Bed Differential Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Midsection temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Section Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Ovhd Condenser Product Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#     'pointsource': 'PIC'}]},
#  {'name': 'Pressure',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw9D7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcUFJFU1NVUkU',
#   'all_streams': [{'name': 'Overhead Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#     'pointsource': 'PIC'}]},
#  {'name': 'T-200',
#   'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw-j7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcVC0yMDA',
#   'all_streams': [{'name': 'Overhead to Feed Flow',
#     'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to VacTower Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Level',
#     'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Bed Differential Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Midsection temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Section Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 3 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#     'pointsource': 'PIC'}]}]

# %%
len(all_elements), all_elements
# Out:
# (14,
#  [{'name': 'HOT-1',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#    'all_streams': [{'name': 'E-102 Duty',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Heat Transfer Coefficient',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 LMTD',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#      'pointsource': 'PIC'},
#     {'name': 'Heater Charge Flow',
#      'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-101 A/B Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 1 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#      'pointsource': 'PIC'},
#     {'name': 'P-101A Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#      'pointsource': 'PIC'},
#     {'name': 'P-101B Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#      'pointsource': 'PIC'},
#     {'name': 'P-103 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#      'pointsource': 'PIC'}]},
#   {'name': 'HOT-3',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#    'all_streams': [{'name': 'Reboiler Duty',
#      'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam Header Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Header Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Discharge E-230',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 3 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#      'pointsource': 'PIC'}]},
#   {'name': 'E-101',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwFT__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDE',
#    'all_streams': [{'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#      'pointsource': 'PIC'}]},
#   {'name': 'E-102',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDI',
#    'all_streams': [{'name': 'E-102 Duty',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Heat Transfer Coefficient',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 LMTD',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#      'pointsource': 'PIC'}]},
#   {'name': 'HTR-101',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwDD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcSFRSLTEwMQ',
#    'all_streams': [{'name': 'Heater Charge Flow',
#      'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#      'pointsource': 'PIC'}]},
#   {'name': 'TK-101',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwGD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAx',
#    'all_streams': [{'name': 'Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'P-101 A/B Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 1 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#      'pointsource': 'PIC'},
#     {'name': 'P-101A Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#      'pointsource': 'PIC'},
#     {'name': 'P-101B Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#      'pointsource': 'PIC'}]},
#   {'name': 'TK-102',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwDz__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAy',
#    'all_streams': [{'name': 'P-102 Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#      'pointsource': 'PIC'}]},
#   {'name': 'TK-103',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwCT__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAz',
#    'all_streams': [{'name': 'P-103 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#      'pointsource': 'PIC'}]},
#   {'name': 'Bottoms Product',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw_T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcQk9UVE9NUyBQUk9EVUNU',
#    'all_streams': [{'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'}]},
#   {'name': 'Energy In',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwAz__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcRU5FUkdZIElO',
#    'all_streams': [{'name': 'Reboiler Duty',
#      'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam Header Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'}]},
#   {'name': 'Energy Out',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwAD__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcRU5FUkdZIE9VVA',
#    'all_streams': [{'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Header Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Discharge E-230',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#      'pointsource': 'PIC'}]},
#   {'name': 'Overhead Product',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw9z7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcT1ZFUkhFQUQgUFJPRFVDVA',
#    'all_streams': [{'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'}]},
#   {'name': 'Pressure',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw9D7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcUFJFU1NVUkU',
#    'all_streams': [{'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#      'pointsource': 'PIC'}]},
#   {'name': 'T-200',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw-j7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcVC0yMDA',
#    'all_streams': [{'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 3 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#      'pointsource': 'PIC'}]}])

# %%
def asset_with_dv(x):
    return True


try:
    exec(config["asset_with_dv"])
    print("ok")
except:
    pass

elements = [e for e in all_elements if asset_with_dv(e["name"])]
len(elements), elements
# Out:
# ok
# asset: HOT-1 DV: True
# asset: HOT-3 DV: True
# asset: E-101 DV: False
# asset: E-102 DV: False
# asset: HTR-101 DV: False
# asset: TK-101 DV: False
# asset: TK-102 DV: False
# asset: TK-103 DV: False
# asset: Bottoms Product DV: False
# asset: Energy In DV: False
# asset: Energy Out DV: False
# asset: Overhead Product DV: False
# asset: Pressure DV: False
# asset: T-200 DV: False
# (2,
#  [{'name': 'HOT-1',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#    'all_streams': [{'name': 'E-102 Duty',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Heat Transfer Coefficient',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 LMTD',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#      'pointsource': 'PIC'},
#     {'name': 'Heater Charge Flow',
#      'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-101 A/B Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 1 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#      'pointsource': 'PIC'},
#     {'name': 'P-101A Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#      'pointsource': 'PIC'},
#     {'name': 'P-101B Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#      'pointsource': 'PIC'},
#     {'name': 'P-103 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#      'pointsource': 'PIC'}]},
#   {'name': 'HOT-3',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#    'all_streams': [{'name': 'Reboiler Duty',
#      'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam Header Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Header Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Discharge E-230',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 3 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#      'pointsource': 'PIC'}]}])

# %%
len(set([i["name"] for i in elements]))
# Out:
# 2

# %%
d = {}
for e in elements:
    d[e["name"]] = e
d.keys()
# Out:
# dict_keys(['HOT-1', 'HOT-3'])

# %%
elements = [d[i] for i in sorted([i for i in d])]
len(elements), elements
# Out:
# (2,
#  [{'name': 'HOT-1',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#    'all_streams': [{'name': 'E-102 Duty',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Heat Transfer Coefficient',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 LMTD',
#      'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#      'pointsource': 'PIC'},
#     {'name': 'Heater Charge Flow',
#      'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'T-101 Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'P-101 A/B Discharge pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Outlet Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Inlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Shell Side Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Air Cooler Outlet Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'H-101 Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 1 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#      'pointsource': 'PIC'},
#     {'name': 'E-101 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#      'pointsource': 'PIC'},
#     {'name': 'P-101A Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#      'pointsource': 'PIC'},
#     {'name': 'P-101B Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#      'pointsource': 'PIC'},
#     {'name': 'P-102 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#      'pointsource': 'PIC'},
#     {'name': 'P-103 Run Status',
#      'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#      'pointsource': 'PIC'}]},
#   {'name': 'HOT-3',
#    'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#    'all_streams': [{'name': 'Reboiler Duty',
#      'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead to Feed Flow',
#      'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms to Feed Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to VacTower Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Flow Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Level',
#      'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Receiver Level Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Bed Differential Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Overhead Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam Header Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Steam to Reboiler Pressure',
#      'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Bottoms Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Feed Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Midsection temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Tower Top Section Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Ovhd Condenser Product Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Header Temperature',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Cooling Water Discharge E-230',
#      'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Mode',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Output',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller PV',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#      'pointsource': 'PIC'},
#     {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#      'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#      'pointsource': 'PIC'},
#     {'name': 'Unit 3 Common Trouble Alarm',
#      'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#      'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#      'pointsource': 'PIC'}]}])

# %%
# Virtual attributes creation
# NOTE: role of virtual attributes is to copy all child element dynamic attributes for which the parent element doesn't
#   have a similar attribute referencing the pipoint. This way all attributes from parent (union of real and virtual)
#   constitute a strict cover of all the pipoints under it. If a pipoint has multiple children referencing, the first one
#   (in element name alphabetical order) is picked for the virtual attribute creation

stream_query = gql(
    """
query Element($name: String!) {
    Element(name: $name) {
        name
        id
        has_attribute(filter: { is_stream: true }) {
          name
          id
          has_dynamic {
            name
            id
            asset_id
          }
        }
        has_element(orderBy: name_asc) {
          name
          id
          has_attribute(filter: { is_stream: true }) {
            name
            id
            has_dynamic {
              name 
              id
              asset_id
            }
          }
        }
    }
}
"""
)

# result = client.execute(stream_query, variable_values={"name": "HOT-1"})
# result

# %%
def attr_to_clone(elem, seen_d, debug=False):
    print(f"...processing {elem['name']}...") if debug else ()
    to_clone = []
    for k, i in enumerate(elem["has_attribute"], 1):
        j = i["has_dynamic"][0]
        if not seen_d.get(j["id"], None):
            # print(k, i["id"], i["name"], j["id"]) if debug else ()
            print(k, i["name"], j["id"]) if debug else ()
            seen_d[j["id"]] = elem["name"]
            to_clone += [i["id"]]
        else:
            print(
                "$$$ exist:",
                seen_d[j["id"]],
                j["name"],
            ) if debug else ()
    return to_clone

# %%
attr_query = gql(
    """
query Attribute($id: ID!) {
  attr: Attribute(id: $id) {
    af_template
    asset_db
    id
    name
    is_stream
    type
    virtual
    parent
    has_dynamic {
        id
    }
  }
}
"""
)

vattr_mutation = gql(
    """
mutation VirtualAttribute(
    $af_template: String!
    $asset_db: String!
    $id: ID!
    $name: String!
    $is_stream: Boolean!
    $type: String!
    $virtual: Boolean!
    $parent: String!
    $pid: ID!
) {
    vattr: MergeAttribute(
        af_template: $af_template
        asset_db: $asset_db
        id: $id
        name: $name
        is_stream: $is_stream
        type: $type
        virtual: $virtual
        parent: $parent
    ) {
        id
    }
    dlink: MergeAttributeHas_dynamic(
        from: {id: $id}
        to: {id: $pid}
    ) {
        from {
            name
            id
        }
        to {
            name
            id
        }
    }
}
"""
)


def clone_attribute_as_virtual(asset_id, ids_to_clone):
    for attr_id in ids_to_clone:
        r = client.execute(attr_query, variable_values={"id": attr_id})
        attr = r["attr"][0]
        s = client.execute(
            vattr_mutation,
            variable_values={
                "af_template": attr["af_template"],
                "asset_db": attr["asset_db"],
                "id": attr["id"] + ":virtual",
                "name": attr["name"],
                "is_stream": attr["is_stream"],
                "type": attr["type"],
                "virtual": True,
                "parent": asset_id,
                "pid": attr["has_dynamic"][0]["id"],
            },
        )

# %% [raw]
# r = client.execute(
#     attr_query,
#     variable_values={
#         "id": "pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwFT__VF8k6xGpdwANOjT1RQ-CCsRRTBRUG_MnZwiOh8CAUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDF8RS0xMDEgUlVOIFNUQVRVUw",
#     },
# )
# r

# %% [raw]
# attr = r["attr"][0]
# s = client.execute(
#     vattr_mutation,
#     variable_values={
#         "af_template": attr["af_template"],
#         "asset_db": attr["asset_db"],
#         "id": attr["id"] + ":virtual",
#         "name": attr["name"],
#         "is_stream": attr["is_stream"],
#         "type": attr["type"],
#         "virtual": True,
#         "parent": "HOT-1",
#         "pid": attr["has_dynamic"][0]["id"],
#     },
# )

# %%
for asset_id in d.keys():
    result = client.execute(stream_query, variable_values={"name": asset_id})
    for e in result["Element"]:
        seen = {}
        ok_ids = attr_to_clone(e, seen)
        ids_to_clone = []
        for i in e["has_element"]:
            ids_to_clone += attr_to_clone(i, seen)
        print(e["name"], len(ids_to_clone), ids_to_clone)
        clone_attribute_as_virtual(asset_id, ids_to_clone)
# Out:
# HOT-1 8 ['pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwFT__VF8k6xGpdwANOjT1RQ-CCsRRTBRUG_MnZwiOh8CAUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDF8RS0xMDEgUlVOIFNUQVRVUw', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQ9MV-t8hWiku0fyTZ8qpGhwUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDJ8RS0xMDIgVFVCRSBTSURFIE9VVExFVCBURU1QRVJBVFVSRSBDT05UUk9MTEVSIE1PREU', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQ5pEj7oSLR0qYb5b063LzOwUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDJ8RS0xMDIgTE1URA', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQ5jGXC9s9k0mDinZlGBpzwQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDJ8RS0xMDIgSEVBVCBUUkFOU0ZFUiBDT0VGRklDSUVOVA', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwEj__VF8k6xGpdwANOjT1RQaSB1Dmmtike-HMbbe4ni8gUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcRS0xMDJ8RS0xMDIgRFVUWQ', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwDD__VF8k6xGpdwANOjT1RQ9l9PGWmyCk-nJyAGoryc8gUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcSFRSLTEwMXxILTEwMSBPVVRMRVQgVEVNUEVSQVRVUkUgQ09OVFJPTExFUiBNT0RF', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwGD__VF8k6xGpdwANOjT1RQ8igQYkrWdEKkOuFZzxkcXQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAxfFQtMTAxIExFVkVMIENPTlRST0xMRVIgTU9ERQ', 'pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwGD__VF8k6xGpdwANOjT1RQFpMQb0kjlU2H5JshdKrFqwUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTFcVEstMTAxfEZFRUQgRkxPVyBDT05UUk9MTEVSIE1PREU']
# HOT-3 1 ['pilot.plant:F1AbEcFWpYyj-GkWKwoVLgdSfpwAz__VF8k6xGpdwANOjT1RQm6fOOxHYUkG5__mjuM6yegUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTNcRU5FUkdZIElOfFJFQk9JTEVSIERVVFk']

# %%
elements[0]
# Out:
# {'name': 'HOT-1',
#  'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#  'all_streams': [{'name': 'E-102 Duty',
#    'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Heat Transfer Coefficient',
#    'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 LMTD',
#    'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#    'pointsource': 'PIC'},
#   {'name': 'Heater Charge Flow',
#    'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'Feed Flow Controller Mode',
#    'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#    'pointsource': 'PIC'},
#   {'name': 'Feed Flow Controller Output',
#    'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#    'pointsource': 'PIC'},
#   {'name': 'Feed Flow Controller PV',
#    'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#    'pointsource': 'PIC'},
#   {'name': 'Feed Flow Controller Setpoint',
#    'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#    'pointsource': 'PIC'},
#   {'name': 'T-101 Level Controller Mode',
#    'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#    'pointsource': 'PIC'},
#   {'name': 'T-101 Level Controller Output',
#    'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#    'pointsource': 'PIC'},
#   {'name': 'T-101 Level Controller PV',
#    'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#    'pointsource': 'PIC'},
#   {'name': 'T-101 Level Controller Setpoint',
#    'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Inlet Pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'P-102 Discharge pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'H-101 Outlet Pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Shell Side Outlet Pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'P-101 A/B Discharge pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Outlet Pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-101 Outlet Pressure',
#    'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Inlet Temperature',
#    'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Shell Side Inlet Temperature',
#    'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Shell Side Outlet Temperature',
#    'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-101 Air Cooler Outlet Temperature',
#    'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#    'pointsource': 'PIC'},
#   {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#    'pointsource': 'PIC'},
#   {'name': 'H-101 Outlet Temperature Controller Mode',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#    'pointsource': 'PIC'},
#   {'name': 'H-101 Outlet Temperature Controller Output',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#    'pointsource': 'PIC'},
#   {'name': 'H-101 Outlet Temperature Controller PV',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#    'pointsource': 'PIC'},
#   {'name': 'H-101 Outlet Temperature Controller Setpoint',
#    'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#    'pointsource': 'PIC'},
#   {'name': 'Unit 1 Common Trouble Alarm',
#    'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#    'pointsource': 'PIC'},
#   {'name': 'E-101 Run Status',
#    'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#    'pointsource': 'PIC'},
#   {'name': 'P-101A Run Status',
#    'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#    'pointsource': 'PIC'},
#   {'name': 'P-101B Run Status',
#    'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#    'pointsource': 'PIC'},
#   {'name': 'P-102 Run Status',
#    'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#    'pointsource': 'PIC'},
#   {'name': 'P-103 Run Status',
#    'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#    'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#    'pointsource': 'PIC'}]}

# %%
elements_info = [
    (
        elements[i]["name"],
        elements[i]["id"],
        [
            stream
            for stream in elements[i]["all_streams"]
            # if j["pointsource"] != "AZURE"
        ],
    )
    for i in range(len(elements))
    # if len(elements[i]["has_attribute"]) > 0
]
elements_info
# Out:
# [('HOT-1',
#   'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#   [{'name': 'E-102 Duty',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_DUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0RVVFk',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Heat Transfer Coefficient',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_HTC',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0hUQw',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 LMTD',
#     'stream_name': 'delmar.DELMAR_UNIT1_E-102_LMTD',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0UtMTAyX0xNVEQ',
#     'pointsource': 'PIC'},
#    {'name': 'Heater Charge Flow',
#     'stream_name': 'delmar.DELMAR_UNIT1_FI-102.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QyC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJLTEwMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QwC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_FIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qki8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0ZJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qui8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'T-101 Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_LIC-101.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX0xJQy0xMDEuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qty8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'P-102 Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-108.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-109.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qky8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTEwOS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-110.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'P-101 A/B Discharge pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-111.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qti8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-112.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Outlet Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT1_PI-113.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1BJLTExMy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-101.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwMS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Inlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-105.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Shell Side Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-106.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNi5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Air Cooler Outlet Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT1_TI-107.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1i8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJLTEwNy5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qry8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qjy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'E-102 Tube Side Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-103.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qsi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDMuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QiS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'H-101 Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT1_TIC-104.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1RJQy0xMDQuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 1 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT1_XA-100',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QzC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hBLTEwMA',
#     'pointsource': 'PIC'},
#    {'name': 'E-101 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q1S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMQ',
#     'pointsource': 'PIC'},
#    {'name': 'P-101A Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101A',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUE',
#     'pointsource': 'PIC'},
#    {'name': 'P-101B Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-101B',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QxS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMUI',
#     'pointsource': 'PIC'},
#    {'name': 'P-102 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-102',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QuC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMg',
#     'pointsource': 'PIC'},
#    {'name': 'P-103 Run Status',
#     'stream_name': 'delmar.DELMAR_UNIT1_XB-103',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQxX1hCLTEwMw',
#     'pointsource': 'PIC'}]),
#  ('HOT-3',
#   'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#   [{'name': 'Reboiler Duty',
#     'stream_name': 'delmar.DELMAR_UNIT3_E-201_REBOILERDUTY',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QoC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0UtMjAxX1JFQk9JTEVSRFVUWQ',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead to Feed Flow',
#     'stream_name': 'delmar.DELMAR_UNIT3_FI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QpS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QrC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms to Feed Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-200.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yMDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to VacTower Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q2y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qji8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qny8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reflux to Vac Tower Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qpi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Flow Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_FIC-275.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QqS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0ZJQy0yNzUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Level',
#     'stream_name': 'delmar.DELMAR_UNIT3_LI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qni8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0S8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q3y8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QnC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Receiver Level Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_LIC-240.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QjS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX0xJQy0yNDAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Bed Differential Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PDI-220.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BESS0yMjAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Overhead Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qiy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Steam Header Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-275.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QsS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI3NS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Steam to Reboiler Pressure',
#     'stream_name': 'delmar.DELMAR_UNIT3_PI-280.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qqi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJLTI4MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qri8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QkC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qmi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'V-240 Receiver Vacuum Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_PIC-250.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qly8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1BJQy0yNTAuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Bottoms Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-200.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qoy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIwMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Feed Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-210.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QmS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Midsection temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-215.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QlC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIxNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Tower Top Section Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-225.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qyy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIyNS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Ovhd Condenser Product Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-230.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTIzMC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Header Temperature',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-260.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QvC8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2MC5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Cooling Water Discharge E-230',
#     'stream_name': 'delmar.DELMAR_UNIT3_TI-265.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6QtS8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJLTI2NS5QVg',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Mode',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.MODE',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Q0C8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuTU9ERQ',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Output',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.OUT',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwi8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuT1VU',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller PV',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.PV',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qxy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuUFY',
#     'pointsource': 'PIC'},
#    {'name': 'Reboiler Outlet Temperature Controller Setpoint',
#     'stream_name': 'delmar.DELMAR_UNIT3_TIC-205.SP',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qwy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1RJQy0yMDUuU1A',
#     'pointsource': 'PIC'},
#    {'name': 'Unit 3 Common Trouble Alarm',
#     'stream_name': 'delmar.DELMAR_UNIT3_XA-200',
#     'id': 'F1DPpjXwPKxU8EWdWQR_TqpF6Qvy8AAAQUNBRC1QSURBLVZNMFxERUxNQVIuREVMTUFSX1VOSVQzX1hBLTIwMA',
#     'pointsource': 'PIC'}])]

# %%
for element, element_id, _ in elements_info:
    mutation = gql(
        """
mutation AssetWithDataView($from: _DatabaseInput!, $to: _ElementInput!) {
    MergeDatabaseAsset_with_dv(
        from: $from,
        to: $to
    ) {
        from {
            name
        }
        to {
            name
        }
    }
}
"""
    )
    # pprint.pprint(mutation)
    reply = client.execute(
        mutation, variable_values={"from": {"id": db_id}, "to": {"id": element_id}}
    )
    print(json.dumps(reply, indent=4))
# Out:
# {
#     "MergeDatabaseAsset_with_dv": {
#         "from": {
#             "name": "Pilot_Plant"
#         },
#         "to": {
#             "name": "HOT-1"
#         }
#     }
# }
# {
#     "MergeDatabaseAsset_with_dv": {
#         "from": {
#             "name": "Pilot_Plant"
#         },
#         "to": {
#             "name": "HOT-3"
#         }
#     }
# }

# %%
def dataview_streams_transaction(dv_id, dv_streams, asset_id):
    if len(dv_streams) == 0:
        print(f"@@ dv_id={dv_id}")
        return
    mutations = []
    for i, stream in enumerate(dv_streams):
        stream_mutation = """
stream{0}: 
    AddDataViewHas_stream(
        from: {{id: "{1}" }}
        to: {{id: "{2}" }}
    ) {{
        from {{
            name
        }}
        to {{
            name
        }}
    }}   
    """.format(
            i, dv_id, stream["id"]
        )
        # print("mutation", i, stream_mutation)
        mutations.append(stream_mutation)

    if asset_id:
        for i, stream in enumerate(dv_streams):
            stream_mutation = """          
stream_asset{0}:
    MergePIPoint(
        id: "{1}"
        asset_id: "HOT-1"
    ) {{
            id
            asset_id
    }}
    """.format(
                i, stream["id"]
            )
            mutations.append(stream_mutation)

    dv_stream_mutation = gql(
        "mutation dataview_streams {\n" + "".join(mutations) + "\n}"
    )

    reply = client.execute(dv_stream_mutation)
    print(f"[add-dv-streams: {dv_id} ({len(json.dumps(reply, indent=4))})]", end="")

# %%
mutation_dv_node = gql(
    """
mutation AssetDataView(
            $asset_db: String!, 
            $asset_id: [String]!, 
            $columns: String!, 
            $description: String, 
            $id: ID!, 
            $name: String!, 
            $ocs_tag: String!) {
    MergeDataView(
        asset_db: $asset_db
        asset_id: $asset_id
        id: $id
        columns: $columns 
        description: $description
        name: $name
        ocs_sync: false
        ocs_tag: $ocs_tag
    ) {
        name
        id 
    }
}
    """
)


mutation_dv_rel = gql(
    """
mutation ElementDataView($from: _ElementInput!, $to: _DataViewInput!) {
    MergeElementHas_dataview(
        from: $from
        to: $to
    ) {
        from {
            name
        }
        to {
            name
            id
        }
    }
}
    """
)


def dataview_id(asset_ids, ocs_tag, multiple=None):
    dv_asset = (
        multiple
        if len(asset_ids) > 1
        else asset_ids[0].lower().replace(" ", ".").replace("/", "__")
    )
    dv_id = f"{dv_id_prefix}-{dv_asset}"
    if ocs_tag != "all_columns":
        dv_id = f"{dv_id}-{ocs_tag}"
    return dv_id


def create_asset_dataview(
    dv_name,
    asset_ids,
    elem_ids,
    all_streams,
    ocs_tag,
    columns,
    ocs_column_key="column_name",
    multiple=None,
):
    dv_id = dataview_id(asset_ids, ocs_tag, multiple)
    asset_desc = (
        f"Asset {asset_ids[0]}" if len(asset_ids) == 1 else f"Assets {multiple.upper()}"
    )
    reply_node = client.execute(
        mutation_dv_node,
        variable_values={
            "asset_db": asset_db,
            "asset_id": asset_ids,
            "columns": str(sorted(columns))
            if len(columns) > 0
            else str(sorted(set([s["name"] for s in all_streams]))),
            "description": f"Hub DV for {asset_desc} - {dv_name}",
            "id": dv_id,
            "name": dv_name,
            "ocs_tag": ocs_tag,
            "ocs_column_key": ocs_column_key,
        },
    )

    for elem_id in elem_ids:
        reply_rel = client.execute(
            mutation_dv_rel,
            variable_values={"from": {"id": elem_id}, "to": {"id": dv_id}},
        )
        # print(json.dumps(reply_rel, indent=4))

    if len(columns) == 0:
        dv_streams = all_streams
    else:
        dv_streams = [s for s in all_streams if s["name"] in columns]

    asset_id = asset_ids[0] if len(asset_ids) == 1 else None
    dataview_streams_transaction(dv_id, dv_streams, asset_id)


element_ids = {}

for dv_name in dv_defs.keys():
    print(f"dv_name={dv_name}")
    ocs_tag, columns, has_custom_dv = dv_defs[dv_name]
    for asset_id, elem_id, all_streams in elements_info:
        if has_no_dv(asset_id):
            continue
        element_ids[asset_id] = elem_id
        # no specialized data view except for fermenter vessels
        if len(columns) > 0 and not has_custom_dv(asset_id):
            continue
        # print(dv_name, [asset_id], all_streams, ocs_tag, columns)
        create_asset_dataview(
            dv_name, [asset_id], [elem_id], all_streams, ocs_tag, columns
        )
# Out:
# dv_name=Default
# [add-dv-streams: pilot.plant-hot-1 (12180)][add-dv-streams: pilot.plant-hot-3 (13054)]

# %%
def extract_columns(asset_ids, ocs_tag):
    query = gql(
        """
    query DataView($id: ID!) {
        DataView(id: $id) {
            columns
      }  
    }
    """
    )
    reply = client.execute(
        query, variable_values={"id": dataview_id([asset_ids[0]], ocs_tag)}
    )
    # print(dataview_id([asset_ids[0]], ocs_tag), reply["DataView"][0]["columns"])
    return sorted(
        [
            i.strip()
            for i in reply["DataView"][0]["columns"][1:-1].replace("'", "").split(",")
        ]
    )


multi_asset_dvs = []
try:
    exec(config["multi_asset_dvs"])
except:
    pass
print(config["multi_asset_dvs"])

for asset_ids, dv_suffix in multi_asset_dvs:
    for dv_name in dv_defs.keys():
        ocs_tag, columns, has_custom_dv = dv_defs[dv_name]
        if len(columns) == 0:
            columns = extract_columns(asset_ids, ocs_tag)
        elem_ids = [element_ids[i] for i in asset_ids]
        create_asset_dataview(
            dv_name + "+", asset_ids, elem_ids, [], ocs_tag, columns, multiple=dv_suffix
        )
# Out:
# # No multi-asset DV

# %% [markdown]
# ### Asset metadata gathering and update, plus geo-data if applicable

# %%
print("db name:", database_name)
meta_query = gql(
    """
query Database($name: String) {
  Database(name: $name) {
    asset_with_dv(orderBy: name_asc) {
      name
      id
      has_attribute(orderBy: name_asc, filter: {is_stream: false}) {
        name
        value
        type
      }
      has_element {
        name
        has_attribute(filter: { is_stream: false }) {
          name
          value
          type
        }
      }
    }
  }
}
"""
)
result = client.execute(meta_query, variable_values={"name": database_name})
result
# Out:
# db name: Pilot_Plant
# {'Database': [{'asset_with_dv': [{'name': 'HOT-1',
#      'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE',
#      'has_attribute': [],
#      'has_element': [{'name': 'TK-103', 'has_attribute': []},
#       {'name': 'TK-102', 'has_attribute': []},
#       {'name': 'TK-101', 'has_attribute': []},
#       {'name': 'HTR-101', 'has_attribute': []},
#       {'name': 'E-102',
#        'has_attribute': [{'name': 'Heat Exchange Area',
#          'value': '23',
#          'type': 'Double'}]},
#       {'name': 'E-101', 'has_attribute': []}]},
#     {'name': 'HOT-3',
#      'id': 'pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM',
#      'has_attribute': [],
#      'has_element': [{'name': 'T-200', 'has_attribute': []},
#       {'name': 'Pressure', 'has_attribute': []},
#       {'name': 'Overhead Product', 'has_attribute': []},
#       {'name': 'Energy Out', 'has_attribute': []},
#       {'name': 'Energy In', 'has_attribute': []},
#       {'name': 'Bottoms Product', 'has_attribute': []}]}]}]}

# %%
def convert2value(s, vtype):
    if vtype == "Double":
        return float(s)
    else:
        return str(s)


def extract_meta(js, sub=False):
    j = js["has_attribute"]
    prefix = "" if not sub else (js["name"].upper() + ".")
    return {f"{prefix}{k['name']}": convert2value(k["value"], k["type"]) for k in j}

# %%
# test
d = extract_meta(result["Database"][0]["asset_with_dv"][0])
d
# Out:
# {}

# %%
meta_mutation = gql(
    """
mutation UpdateMeta($id: ID!, $meta: String) {
  MergeElement(id: $id, asset_metadata: $meta) {
    id
    name
    asset_metadata
  }
}
"""
)

geo_mutation = gql(
    """
mutation UpdateGeo($id: ID!, $lat: Float, $long: Float)  {
    MergeElement(id: $id, latitude: $lat, longitude: $long, location: {latitude: $lat, longitude: $long}) {
        name
        id
        latitude
        longitude
        location {
            latitude
            longitude
        }
    }
}    
"""
)


def update_meta(wid, meta):
    result = client.execute(
        meta_mutation, variable_values={"id": wid, "meta": str(meta)}
    )
    return result


def update_geo(wid, lat, long):
    result = client.execute(
        geo_mutation, variable_values={"id": wid, "lat": lat, "long": long}
    )
    return result

# %%
nb = len(result["Database"][0]["asset_with_dv"])
for i in range(nb):
    dai = result["Database"][0]["asset_with_dv"][i]
    d = extract_meta(dai)
    for j in range(len(dai.get("has_element", []))):
        d.update(extract_meta(dai["has_element"][j], True))
    print(dai["name"], dai["id"], d)
    update_meta(dai["id"], d)
    if config["db"].get("asset_geodata", False):
        update_geo(dai["id"], d.get("Latitude", 0.0), d.get("Longitude", 0.0))
# Out:
# HOT-1 pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpwBj__VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTE {'E-102.Heat Exchange Area': 23.0}
# HOT-3 pilot.plant:F1EmcFWpYyj-GkWKwoVLgdSfpw8T7_VF8k6xGpdwANOjT1RQUElBRi1BQ0FEXFBJTE9UUExBTlRcUExBTlRcUElMT1QgUExBTlRcSE9ULTM {}
