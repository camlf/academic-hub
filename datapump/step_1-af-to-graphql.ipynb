# %% [markdown]
# # Dataset-to-Hub pipeline: reduce Time-to-Publish in onboarding datasets
#
# Goal: from a PI System with associated AF database, publish the dataset through OCS with a set of default asset-centric Data Views.
#
# #### Showcase datasets: Deschutes and UC Davis Facilities. Next: NC State paper machines, USC drill data
#
# ## Step 1: Populate GraphQL-enabled "AF"
#
# #### From an AF path element, collect pipoints/static/etc about all its children elements.
#
# #### This data is then directly accessible through a GraphQL endpoint for Step 1, creation of (graph) data views.

# %%
# import to deal with PIWebAPI
# !pip install httpx
import requests
import json
import time
from time import process_time
import yaml
import asyncio
import httpx

# Neo4J graph database
import py2neo 
from py2neo import Graph
from py2neo import Node, Relationship

# %%
config_file = "config-omf-health.yaml"
# config_file = "config-prod-ucd-v2.yaml"
# config_file = "config-windfarm.yaml"
# config_file = "config-acad-prod-desc-v2.yaml"
# config_file = "config-acad-prod-deschutes.yaml"
#  config_file = "config-acad-prod-ucd.yaml"

# %% [markdown]
# ## Overview
#
# From an anchor element path in AF, generate the Neo4j graph of all (templated) children and their attributes extracted from PIWebAPI
#
# ### Input parameters
#
# * PIWebAPI base URL for asset servers
# * PIWebAPI authentication credentials (basic)
# * Anchor element path

# %%
with open(config_file) as f:
    config = yaml.safe_load(f)
# config

# %%
base_url = config["piwebapi"]["base_url"]
dataserver = config["piwebapi"]["dataserver"]  # "uni-pida-vm0"

auth = (config["piwebapi"]["username"], config["piwebapi"]["password"])
timeout = 45.0

asset_url = base_url + "/assetservers"

print(f"piwebapi={base_url}, dataserver={dataserver}, auth={auth}")

element_roots = config["piwebapi"]["element_roots"]

test_asset = None

ocs_asset_db = config["ocs"]["configuration"]["asset_db"]

EXPAND_LEAF_ELEMENTS = config["piwebapi"]["expand_leaf_elements"]  # False
MAX_LEAF_ELEMENTS = 10000
print(f"roots = {element_roots}, expand leaves: {EXPAND_LEAF_ELEMENTS}")
# Out:
# piwebapi=https://academicpi.osisoft.com/piwebapi, dataserver=acad-pida-vm0, auth=('reader0', 'OSIsoft2017')
# roots = ['\\\\PIAF-ACAD\\Classroom Data\\Source Data'], expand leaves: True

# %% [markdown]
# ### Connect to Neo4J db

# %%
graph = Graph(
    config["neo4j"]["host"],
    auth=(config["neo4j"]["user"], config["neo4j"]["password"]),
    name=config["neo4j"]["database"],
)

# %% [markdown]
# ### Functions to navigate PIWebAPI structure

# %%
def map_webid(webid):
    return webid + f"_{ocs_asset_db}"


# From PIWebAPI asset node, build directory of children links and self WebID
# If extract_key is present, return this directory item
# Otherwise return full dictionary (key is children node name)
async def extract_url(url, key, extract_key=None, debug=False):
    async with httpx.AsyncClient() as client:
        start = process_time()
        print("<", end="")
        r = await client.get(url, auth=auth, timeout=timeout)
        # print(f"[{process_time() - start:.2f}:{url}]")
        if r.status_code != 200:
            print(f"@error  code={r.status_code}, url={url}")
            return
        js = r.json()
        if debug:
            print(f"js={js}")
        d = {
            i["Name"]: (
                i["Links"][f"{key}"],
                map_webid(i["WebId"]),
                i.get("TemplateName", ""),
                i.get("Description", ""),
            )
            for i in js["Items"]
        }
        if extract_key:
            result = d.get(extract_key, None)
            if result is None:
                print(
                    f"[@error url={url}, key={key}, extract={extract_key}, d={d}]"
                )  # " r={js}, d={d}")
            return result
        else:
            return d


# Extract static value v2
async def extract_static_value2(attr_info, client):
    return await extract_point_or_value(
        attr_info, client, "Value", "Value", lambda t: t
    )


# Extract point data v2
async def extract_point2(attr_info, client):
    # "Path", lambda t: extract_tag(t)
    return await extract_point_or_value(
        attr_info, client, "Point", "Name", lambda t: f"tag__{t}"
    )


# Extract point or static value from attribute
async def extract_point_or_value(attr_info, client, link_key, value_key, value_f):
    if attr_info["Links"].get(link_key, None) is None:
        return None, None, None, None
    start = process_time()
    print(".", end="")
    r = await client.get(attr_info["Links"][link_key], auth=auth, timeout=timeout)
    # print(f"[{process_time() - start:.2f}:{attr_info['Links'][link_key]}]")
    if r.status_code != 200:
        print(f"@get error code={r.status_code} url={attr_info['Links'][link_key]}")
        return
    js = r.json()
    point_attributes = None
    if link_key == "Point":
        r2 = await client.get(js["Links"]["Attributes"], auth=auth, timeout=timeout)
        if r2.status_code != 200:
            print(f"@get error code={r.status_code} url2={js['Links']['Attributes']}")
            return
        point_attributes = r2.json()["Items"]
    return attr_info, value_f(js[value_key]), js, point_attributes


def create_or_update_node(
    node_type, name, webid, template="", asset_db="", parent=None
):
    query = f"MATCH (node) WHERE node.id = '{webid}' RETURN node"

    nodes = [i["node"] for i in graph.run(query).data()]
    if len(nodes) == 1:
        print("@", end="")
        return nodes[0]
    node = Node(node_type, "Node", name=name)
    node.update(id=webid, af_template=template, asset_db=asset_db)
    if node_type == "PIPoint":
        node.update(on_ocs=1)
    return node


important_nodes = {}

# Navigate fully AF `path` in PIWebAPI
# If `graph` is not null, update it while traversing tree
# (graph at this point is a list of Node and Relationship)
async def elements_of(url, path, lgraph=None):
    path_components = enumerate([i for i in path.split("\\") if len(i) > 0])
    # url = base_url
    parent = None
    asset_db = ""
    for i, component in path_components:
        # url, webid, template, description
        result = await extract_url(
            url, "Databases" if i == 0 else "Elements", component
        )
        if result is None:
            print(f"[@@@error: url={url}, i={i}, component={component}]")
            continue
        url, webid, template, description = result
        if lgraph is not None:
            node_type = "Server" if i == 0 else ("Database" if i == 1 else "Element")
            if node_type == "Database":
                important_nodes[node_type] = webid

            rel_type = (
                "NOT_POSSIBLE"
                if i == 0
                else ("HAS_DATABASE" if i == 1 else "HAS_ELEMENT")
            )
            if node_type == "Database":
                asset_db = ocs_asset_db  # component
            node = create_or_update_node(
                node_type, component, webid, template, asset_db
            )
            if node_type == "Database":
                node.update(
                    name=config["db"]["database_name"],
                    informationURL=config["db"]["infoURL"],
                    description=config["db"]["description"],
                    namespace=config["ocs"]["configuration"]["namespace"],
                    status="onboarding",
                )
                important_nodes[node_type] = node
            elif node_type == "Element":
                node.update(description=description if description != "" else template)
            if parent:
                lgraph.append(Relationship(parent, rel_type, node))
            lgraph.append(node)
            parent = node

    if important_nodes.get("Element", None) is None:
        important_nodes["Element"] = node
    print(f"important nodes={important_nodes}")
    start = process_time()
    urls_dict = await extract_url(url, "Attributes")
    # print(f"[{process_time() - start:.2f}:extract_url_{url}]")
    return urls_dict, parent


# From an element URL, return a dictionary of attribute and their PIWebAPI JSON info
# PIWebAPI attribute JSON to be parsed and transfered to graph
async def attributes(url):
    async with httpx.AsyncClient() as client:
        start = process_time()
        print(">", end="")
        r = await client.get(url, auth=auth, timeout=timeout)
        # print(f"[{process_time() - start:.2f}:{url}]")
        if r.status_code != 200:
            print("@error")
            return
        js = r.json()
        d = {
            i["Name"]: i for i in js["Items"] if i["DataReferencePlugIn"] == "PI Point"
        }
        for k in d.keys():  # key_list
            # print(f"d-key={k}")
            d[k] = await extract_point2(d[k], client)

        d2 = {i["Name"]: i for i in js["Items"] if i["DataReferencePlugIn"] == ""}
        for k in d2.keys():
            # print(f"d2-key={k}")
            d2[k] = await extract_static_value2(d2[k], client)

        return {**d, **d2}


def convert_config_data(value):
    if type(value) == float:
        if str(value)[-2:] == ".0":
            return int(value)
        else:
            return value
    try:
        return int(value)
    except (ValueError, TypeError):
        try:
            val = value["Name"]
            return val.replace("'", "")  # f"'{val}'"
        except:
            return value.replace("'", "")  # "'{value}'"

# %% [markdown]
# ### Transform linear graph (list of Node and Relationship) into a graph transaction

# %%
def commit_graph(g, debug=True):
    start_time = time.perf_counter()
    tx = graph.begin()
    if debug:
        print(f"\n>> Graph root={g[0]}")
    [tx.create(i) for i in g if i is not None]
    tx.commit()
    if debug:
        print(f">> commit done in {time.perf_counter() - start_time:.2f} secs")

# %% [markdown]
# ### Create all children element nodes of anchor element and their attributes
#
# For attributes, transfer relevent information onto associated graph node

# %%
def reject_element(element_name):
    return any(ss in element_name.lower() for ss in ["_cache", "baseline", "health"])

try:
    exec(config["reject_element"])
except:
    pass

# %%
async def generate_leaf_element_attributes(elements_path):
    lgraph = []
    elem_attr_urls, elem_anchor = await elements_of(
        asset_url, elements_path, lgraph=lgraph
    )
    print(f"\n>> Current anchor: {elem_anchor}")
    # elem_anchor, len(lgraph if lgraph else []), list(elem_attr_urls.keys())
    for element_name in elem_attr_urls.keys():
        # UC Davis + CMU specific
        if reject_element(element_name):
            print(f"@@ rejected: {element_name}")
            continue
        name = element_name
        # print(elem_attr_urls[element_name])
        elem_url, webid, template, description = elem_attr_urls[element_name]
        elem_node = create_or_update_node(
            "Element", name, webid, template, asset_db=elem_anchor["asset_db"]
        )
        elem_node.update(description=description if description != "" else template)
        elem_rel = Relationship(elem_anchor, "HAS_ELEMENT", elem_node)
        attributes_info = await attributes(elem_attr_urls[element_name][0])
        static_attributes = []
        for attr in attributes_info.keys():
            try:
                attr_info, stream_or_val, stream_js, point_attrs = attributes_info[attr]
            except ValueError:
                print(f"attr={attr}  val={attributes_info[attr]}")
                return
            if attr_info is None:
                continue
            if "tag__" not in str(stream_or_val):
                node = create_or_update_node(
                    "Attribute",
                    attr,
                    map_webid(attr_info["WebId"]),
                    template=elem_node["af_template"],
                    asset_db=elem_node["asset_db"],
                )
                node.update(
                    value=convert_config_data(stream_or_val), type=attr_info["Type"]
                )
                rel = Relationship(elem_node, "HAS_ATTRIBUTE", node)
                lgraph.extend([node, rel])
                static_attributes += [attr]
                continue

            stream_name = stream_or_val.replace("tag__", "")
            if "Analysis" in attr:  # NOTE: duplicate tag in attributes for FV
                # skip attribute with duplicate tag
                print("=", end="")
                continue
            if stream_js["Future"]:
                # future tag not transferred by PItoOCS
                print(f"${attr}$", end="")
                continue
            node = create_or_update_node(
                "PIPoint",
                attr,
                map_webid(attr_info["WebId"]),
                elem_node["af_template"],
                elem_node["asset_db"],
            )
            print("+", end="")  # stream_name
            pattributes = {i["Name"]: i["Value"] for i in point_attrs}
            node.update(
                asset_id=name,
                column_name=attr,
                stream_name=stream_name,
                type=attr_info["Type"],
                uom=attr_info["DefaultUnitsName"],
                step=attr_info["Step"],
                categories=attr_info["CategoryNames"],
                description=attr_info["Description"],
                pointsource=pattributes["pointsource"],
                stream_id=f"PI_{config['piwebapi']['dataserver']}_{pattributes['pointid']}",
            )
            if (
                attr_info["Type"] == "EnumerationValue"
                or stream_js["PointType"] == "Digital"
            ):
                # print(f"node={node}, js={stream_js}")
                node.update(digital_set_name=stream_js["DigitalSetName"])
            rel = Relationship(elem_node, "HAS_DYNAMIC", node)
            lgraph.extend([node, rel])
        elem_node.update(static_attributes=static_attributes)
        lgraph.extend([elem_node, elem_rel])
    commit_graph(lgraph)

# %% [markdown]
# ### Generate and commit graphs (one per anchor elements)

# %%
async def build_graphs(roots):
    for elements_path in roots:
        # lgraph = []
        await generate_leaf_element_attributes(elements_path)  # , lgraph)

# %%
print(element_roots)
start_time = time.perf_counter()
await build_graphs(element_roots)
print(f"> runtime {time.perf_counter() - start_time:.2f} secs")
# Out:
# ['\\\\PIAF-ACAD\\Classroom Data\\Source Data']
# <@<<important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <
# >> Current anchor: (:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name: 'Source Data'})
# >>>>>>>>>>>>>
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.08 secs
# > runtime 1.31 secs

# %%
db_node = important_nodes["Database"]
elem_root = important_nodes["Element"]
root_webid = elem_root["id"]
print(elem_root)
# Out:
# (_12279:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name: 'Source Data'})

# %% [markdown]
# ### (Optional) From a test element, produce the list of all attributes
#
# Data Views are created from different subset of this list

# %%
if test_asset:
    asset_id, node_type, af_db = test_asset
    print(asset_id, node_type, af_db)
    result = [
        i["name"]
        for i in graph.run(
            f"MATCH (b:Element)-[:ELEMENT_OF]-(p:{node_type}) WHERE p.name = '{asset_id}' AND p.asset_db='{af_db}' RETURN b.name as name"
        ).data()
    ]
    print(result)
else:
    print("--- no test asset ---")
# Out:
# --- no test asset ---

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i : i + n]


async def gather_func(f, items, ndiv):
    div = (len(items) // ndiv) + 1
    chunk_list = list(chunks(items, div))
    coroutines = [f(chunk_list[i]) for i in range(0, ndiv)]
    start_time = time.perf_counter()
    print("-OK-") if await asyncio.gather(*coroutines) else print("@oops")
    print(f"> runtime {time.perf_counter() - start_time:.2f} secs")

# %%
try:
    exec(config["reject_leaf_element"])
except:
    pass

if EXPAND_LEAF_ELEMENTS:
    ndiv = 3
    root = element_roots[0]
    query = f"MATCH (e:Element) WHERE NOT ((e)-[:HAS_ELEMENT]->()) and e.asset_db='{ocs_asset_db}' RETURN DISTINCT e.name AS name ORDER BY e.name"
    leaf_elements = [i["name"] for i in graph.run(query).data()]
    roots = [root + f"\\{element}" for element in leaf_elements[:MAX_LEAF_ELEMENTS]]
    print(len(roots), roots)
    await gather_func(build_graphs, roots, ndiv)
# Out:
# 13 ['\\\\PIAF-ACAD\\Classroom Data\\Source Data\\MIT', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\New_Haven', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\OPC-UA', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\PIWorld_2018', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\Refinery', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\TAMU', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\UCLA', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\UC_Davis', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\Utah', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\cmu_unitops1', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\lehigh_unitops', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\osi_unitops1', '\\\\PIAF-ACAD\\Classroom Data\\Source Data\\wvu_unitops']
# <<<@<@<@<@<@<@<@<@<@<@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <
# >> Current anchor: (_12288:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpw6riC3lgx6RGoMgANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFRBTVU_hub.omflistener', name: 'TAMU', static_attributes: []})
# >
# >> Current anchor: (_12281:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwWZTMSV_-6BGoMQANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXExFSElHSF9VTklUT1BT_hub.omflistener', name: 'lehigh_unitops', static_attributes: []})
# @@ rejected: 2 Phase Heat Transfer
# @@ rejected: 2 Phase Heat Transfer2
# @@ rejected: 8 inch Pilot plant distillation column
# @@ rejected: AV Heat Transfer
# @@ rejected: AV Mass Transfer 2
# @@ rejected: AV Mass Transfer 3
# @@ rejected: AV Mass Transfer 4
# @@ rejected: AV Mass Transfer 5
# @@ rejected: AV Mass Transfer6
# @@ rejected: Distillation
# @@ rejected: Dow Closed Loop Control 3
# @@ rejected: Dow Heat Transfer2
# @@ rejected: Dow Relay Feedback 3
# @@ rejected: LCTC 2 CS2
# @@ rejected: LCTC7
# >
# >> Current anchor: (_12282:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpw5_GZZ0Af6RGoMgANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXE1JVA_hub.omflistener', name: 'MIT', static_attributes: []})
# @@ rejected: FRED
# @@ rejected: FRED2
# >..............+++++++>.+++++++@@ rejected: Test
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.06 secs
# <.@<....@<..@<...@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <..
# >> Current anchor: (_12290:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwOg4aavcY6RGoMQANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFVDTEE_hub.omflistener', name: 'UCLA', static_attributes: []})
# @@ rejected: Close_Loop_1
# @@ rejected: Close_Loop_2
# @@ rejected: Open_Loop
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.01 secs
# <+++++++@@ rejected: Temperature_test
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.06 secs
# <.@<@<+++++++>@<.@<.@<@<.@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <.@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <.
# >> Current anchor: (_12289:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwaJLxxe3w6RGoNAANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFVDX0RBVklT_hub.omflistener', name: 'UC_Davis', static_attributes: []})
# @@ rejected: Armfield_Distillation
# @@ rejected: Armfield_Distillation2
# @@ rejected: Armfield_Distillation3
# @@ rejected: Armfield_Distillation4
# @@ rejected: Armfield_Distillation5
# @@ rejected: TEST
# >.
# >> Current anchor: (_12283:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwzW2Z-lBz6RGoNAANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXE5FV19IQVZFTg_hub.omflistener', name: 'New_Haven', static_attributes: []})
# @@ rejected: asset
# @@ rejected: EvapTest1
# >...+++++++>..................+++++++
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.07 secs
# <+++++++>.@<.@<.+++++++>.@<...@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <....
# >> Current anchor: (_12291:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwWPE5pxhJ6hGpbwANOjJQ4gUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFVUQUg_hub.omflistener', name: 'Utah', static_attributes: []})
# @@ rejected: DPHX
# @@ rejected: DPHX_HT_CALCS
# @@ rejected: DPHX_wCalcs
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.01 secs
# <..@<+++++++>.@<..+++++++>@<..@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <.....
# >> Current anchor: (_12280:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpw3eu3vXz56BGoMAANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXENNVV9VTklUT1BTMQ_hub.omflistener', name: 'cmu_unitops1', static_attributes: []})
# @@ rejected: CMU_controls_hxer_steptest
# >....+++++++>......+++++++>............+++++++>....+++++++@@ rejected: no data
# @@ rejected: PleaseWork
# @@ rejected: Sampletest1
# @@ rejected: Test1017test1actual
# @@ rejected: test2
# @@ rejected: testing123
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.16 secs
# <..@<..+++++++@@ rejected: PSA Exp (Pressure Swing Adsorption)
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.27 secs
# <@<.@<.@<.@<.@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <@<+++++++>
# >> Current anchor: (_12284:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwFqUQX8od6RGpVQANOjJQ4gUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXE9QQy1VQQ_hub.omflistener', name: 'OPC-UA', static_attributes: []})
# @@ rejected: Rose-Hulman
# @@ rejected: Testing
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.01 secs
# <@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <.@<.@<.
# >> Current anchor: (_12285:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpw2lK2J0v46BGoMAANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXE9TSV9VTklUT1BTMQ_hub.omflistener', name: 'osi_unitops1', static_attributes: []})
# @@ rejected: Armfield_Distillation
# @@ rejected: cmu_test1
# @@ rejected: hub_dan_signals
# @@ rejected: js_sample_signals
# @@ rejected: MinesE1
# @@ rejected: mit_temp_v2
# @@ rejected: mit_temp_v3
# @@ rejected: my_asset_name
# @@ rejected: newhaven_double_effect_evap_1
# @@ rejected: signals_with_note_v1
# >.@<...@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <....
# >> Current anchor: (_12286:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwFhO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFBJV09STERfMjAxOA_hub.omflistener', name: 'PIWorld_2018', static_attributes: []})
# @@ rejected: hub_dan_signals
# @@ rejected: hub_sample_signals6
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.01 secs
# <+++++++>.@<..@<+++++++>@<..@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <..
# >> Current anchor: (_12287:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpwsGcppoYl6RGoMgANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFJFRklORVJZ_hub.omflistener', name: 'Refinery', static_attributes: []})
# @@ rejected: 0_model_development
# @@ rejected: Heat_Exchanger
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.01 secs
# .........+++++++@@ rejected: F20_PSA_v2
# @@ rejected: F20_wk1_Membrane
# @@ rejected: F20_Wk1_PSA
# @@ rejected: HX Cycle1 F20
# @@ rejected: Membrane
# @@ rejected: wk1_F20
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.19 secs
# .+++++++@@ rejected: uc_osi_test1
# @@ rejected: uc_osi_test2
# @@ rejected: uc_osi_test3
# @@ rejected: ucd_distillation_6
#
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.08 secs
# <@<@<@<@important nodes={'Database': Node('Database', 'Node', af_template='', asset_db='hub.omflistener', description='OMFListener Device Health', id='F1RDcFWpYyj-GkWKwoVLgdSfpwlJzOM9zJAEebSKeNcat3SgUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRB_hub.omflistener', informationURL='https://academicpi.osisoft.com/PIVision/#/Displays/137/Hub_Listeners_All', name='Hub_OMFListeners', namespace='hub_lab_data', status='onboarding'), 'Element': Node('Element', 'Node', af_template='', asset_db='hub.omflistener', description='', id='F1EmcFWpYyj-GkWKwoVLgdSfpwExO-GDD36BGpQwANOlkqWwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRB_hub.omflistener', name='Source Data')}
# <
# >> Current anchor: (_12292:Element:Node {af_template: '', asset_db: 'hub.omflistener', description: '', id: 'F1EmcFWpYyj-GkWKwoVLgdSfpww9KF0icZ6RGoMQANOjL3QwUElBRi1BQ0FEXENMQVNTUk9PTSBEQVRBXFNPVVJDRSBEQVRBXFdWVV9VTklUT1BT_hub.omflistener', name: 'wvu_unitops', static_attributes: []})
# @@ rejected: ChemCad
# @@ rejected: ChemCad Distilation Collumn
# @@ rejected: Convective Spheres
# @@ rejected: Distilation_Column_Test
# @@ rejected: Distillation Collumn Test
# @@ rejected: Distillation Column
# @@ rejected: Dye_Fading
# @@ rejected: Membrane Reactor
# >.......+++++++
# >> Graph root=(_12278:Node:Server {af_template: '', asset_db: '', id: 'F1RScFWpYyj-GkWKwoVLgdSfpwUElBRi1BQ0FE_hub.omflistener', name: 'PIAF-ACAD'})
# >> commit done in 0.07 secs
# -OK-
# > runtime 13.18 secs

# %%
dataserver_urls = (requests.get(base_url + "/dataservers", auth=auth).json())["Items"]
for ds in dataserver_urls:
    if dataserver == ds["Name"]:
        print(ds)
        enums_url = ds["Links"]["EnumerationSets"]
        break
print(enums_url)
enums = requests.get(enums_url, auth=auth)
enums
# Out:
# {'WebId': 'F1DSpjXwPKxU8EWdWQR_TqpF6QQUNBRC1QSURBLVZNMA', 'Id': '3cf035a6-54ac-45f0-9d59-047f4eaa45e9', 'Name': 'acad-pida-vm0', 'Path': '\\\\PIServers[acad-pida-vm0]', 'IsConnected': True, 'ServerVersion': '3.4.405.1198', 'Links': {'Self': 'https://academicpi.osisoft.com/piwebapi/dataservers/F1DSpjXwPKxU8EWdWQR_TqpF6QQUNBRC1QSURBLVZNMA', 'Points': 'https://academicpi.osisoft.com/piwebapi/dataservers/F1DSpjXwPKxU8EWdWQR_TqpF6QQUNBRC1QSURBLVZNMA/points', 'EnumerationSets': 'https://academicpi.osisoft.com/piwebapi/dataservers/F1DSpjXwPKxU8EWdWQR_TqpF6QQUNBRC1QSURBLVZNMA/enumerationsets'}}
# https://academicpi.osisoft.com/piwebapi/dataservers/F1DSpjXwPKxU8EWdWQR_TqpF6QQUNBRC1QSURBLVZNMA/enumerationsets
# <Response [200]>

# %%
# Find all Digital Sets referred to by new graph
graph_enums = [
    i["set"]
    for i in graph.run(
        f"MATCH (p:PIPoint) WHERE EXISTS(p.digital_set_name) AND p.asset_db='{ocs_asset_db}' RETURN DISTINCT p.digital_set_name AS set"
    ).data()
]
graph_enums
# Out:
# ['']

# %%
# Build DigitalState node with all states, add relationship :STATE_FROM from node with values in that DigitalState set
for digital_set in graph_enums:
    d = {}
    for i in (enums.json())["Items"]:
        if i["Name"] == digital_set:
            print(f"==> processing {i}...")
            vals = requests.get(i["Links"]["Values"], auth=auth).json()
            for v in vals["Items"]:
                if v["Name"] != "undefined":
                    # print(f"{v['Value']} - {v['Name']}")
                    d[str(v["Value"])] = v["Name"]
            node = create_or_update_node(
                "DigitalState", digital_set, map_webid(i["WebId"]), asset_db=ocs_asset_db
            )
            node.update(states=str(d))
            lgraph = [node]
            points = [
                i["p"]
                for i in graph.run(
                    f"MATCH (p:PIPoint) WHERE p.digital_set_name = '{digital_set}' RETURN p"
                ).data()
            ]
            for p in points:
                rel = Relationship(p, "STATE_FROM", node)
                lgraph.extend([rel])
            commit_graph(lgraph)
            break
